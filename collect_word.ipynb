# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
url = "https://toiguru.jp/toeic-vocabulary-list"
res = requests.get(url)
soup = BeautifulSoup(res.content, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="ja">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="True" name="HandheldFriendly"/>
# <meta content="320" name="MobileOptimized"/>
# <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
# <meta content="#6bb6ff" name="msapplication-TileColor"/>
# <meta content="#6bb6ff" name="theme-color"/>
# <link href="https://toiguru.jp/xmlrpc.php" rel="pingback"/>
# <title>絶対に覚えたい！TOEIC頻出単語1,000語まとめ</title>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//use.fontawesome.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://toiguru.jp/feed" rel="alternate" title="トイグル » フィード" type="application/rss+xml"/>
# <link href="https://toiguru.jp/comments/feed" rel="alternate" title="トイグル » コメントフィード" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/toiguru.jp\/wp-includes\/js\/wp-emoji-release.min.js"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://toiguru.jp/wp-content/themes/sango-theme/style.css?ver2_0_7" id="sng-stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://toiguru.jp/wp-content/themes/sango-theme/entry-option.css?ver2_0_7" id="sng-option-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Quicksand%3A500%2C700&amp;display=swap" id="sng-googlefonts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://use.fontawesome.com/releases/v5.11.2/css/all.css" id="sng-fontawesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://toiguru.jp/wp-includes/css/dist/block-library/style.min.css" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://toiguru.jp/wp-content/plugins/contact-form-7/includes/css/styles.css" id="contact-form-7-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/themes/redmond/jquery-ui.min.css" id="jquery-ui-theme-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://toiguru.jp/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.css" id="jquery-ui-timepicker-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://toiguru.jp/wp-content/themes/sango-theme-child/style.css" id="child-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://toiguru.jp/wp-content/plugins/amazonjs/css/amazonjs.css" id="amazonjs-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jquery-core-js" src="https://toiguru.jp/wp-includes/js/jquery/jquery.js" type="text/javascript"></script>
# <link href="https://toiguru.jp/wp-json/" rel="https://api.w.org/"/><link href="https://toiguru.jp/wp-json/wp/v2/posts/381" rel="alternate" type="application/json"/><link href="https://toiguru.jp/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://toiguru.jp/toeic-vocabulary-list" rel="canonical"/>
# <link href="https://toiguru.jp/?p=381" rel="shortlink"/>
# <link href="https://toiguru.jp/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftoiguru.jp%2Ftoeic-vocabulary-list" rel="alternate" type="application/json+oembed"/>
# <link href="https://toiguru.jp/wp-json/oembed/1.0/embed?url=https%3A%2F%2Ftoiguru.jp%2Ftoeic-vocabulary-list&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <meta content="絶対に覚えたい！TOEIC頻出単語1,000語まとめ" property="og:title"/>
# <meta content="TOEIC試験でスコアを上げるには、単語力が何よりも重要である。 単語力があればリスニングの聞き取りができるようになる。単語力があれば英文が読めるようになり、リーディングセクションのスコアが上がる。 そこでトイグルでは、 ... " property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://toiguru.jp/toeic-vocabulary-list" property="og:url"/>
# <meta content="https://toiguru.jp/wp-content/uploads/2015/05/thumb_vocab_ver3_001-1024x638.jpeg" property="og:image"/>
# <meta content="https://toiguru.jp/wp-content/uploads/2015/05/thumb_vocab_ver3_001-1024x638.jpeg" name="thumbnail"/>
# <meta content="トイグル" property="og:site_name"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="100001262439549" property="fb:app_id"/> <script>
# 	  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# 	  ga('create', 'UA-108550033-1', 'auto');
# 	  ga('send', 'pageview');
# 	</script>
# <link href="https://toiguru.jp/wp-content/uploads/2015/11/cropped-fb_4-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://toiguru.jp/wp-content/uploads/2015/11/cropped-fb_4-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://toiguru.jp/wp-content/uploads/2015/11/cropped-fb_4-180x180.png" rel="apple-touch-icon"/>
# <meta content="https://toiguru.jp/wp-content/uploads/2015/11/cropped-fb_4-270x270.png" name="msapplication-TileImage"/>
# <style id="wp-custom-css" type="text/css">
# 			/* 必須マーク */
# .must{
# 	color: #fff;
# 	margin-right: 10px;
# 	padding: 6px 10px;
# 	background: #F92931;
# 	border-radius: 20px;
# }
#
# /* 任意マーク */
# .free {
# 	color: #fff;
# 	margin-right: 10px;
# 	padding: 6px 10px;
# 	background: #424242;
# 	border-radius: 20px;
# }
#
# /* 項目名を太字にする */
# form p {
# 	font-weight: 600;
# }
#
# /* 入力項目を見やすくする */
# input.wpcf7-form-control.wpcf7-text,
# textarea.wpcf7-form-control.wpcf7-textarea {
# 	width: 100%;
# 	padding: 8px 15px;
# 	margin-right: 10px;
# 	margin-top: 10px;
# 	border: 1px solid #d0d5d8;
# 	border-radius: 3px;
# }
# textarea.wpcf7-form-control.wpcf7-textarea {
# 	height: 200px;
# }
#
# /* 必須項目の入力欄を黄色にする */
# input.wpcf7-form-control.wpcf7-text.wpcf7-validates-as-required {
# 	background: rgba(255, 255, 142, 0.46);
# }
#
# /* 送信ボタンを見やすくする */
# input.wpcf7-submit {
# 	width: 100%;
# 	height: 80px;
# 	background: #27c038;
# 	color: #fff;
# 	font-size: 20px;
# 	font-weight: 600;
# }
#
# /* エラーメッセージを見やすくする */
# span.wpcf7-not-valid-tip,
# .wpcf7-response-output.wpcf7-validation-errors {
# 	color: red;
# 	font-weight: 600;
# }		</style>
# <style> a{color:#4f96f6}.main-c, .has-sango-main-color{color:#6bb6ff}.main-bc, .has-sango-main-background-color{background-color:#6bb6ff}.main-bdr, #inner-content .main-bdr{border-color:#6bb6ff}.pastel-c, .has-sango-pastel-color{color:#c8e4ff}.pastel-bc, .has-sango-pastel-background-color, #inner-content .pastel-bc{background-color:#c8e4ff}.accent-c, .has-sango-accent-color{color:#ffb36b}.accent-bc, .has-sango-accent-background-color{background-color:#ffb36b}.header, #footer-menu, .drawer__title{background-color:#77b7ef}#logo a{color:#FFF}.desktop-nav li a , .mobile-nav li a, #footer-menu a, #drawer__open, .header-search__open, .copyright, .drawer__title{color:#FFF}.drawer__title .close span, .drawer__title .close span:before{background:#FFF}.desktop-nav li:after{background:#FFF}.mobile-nav .current-menu-item{border-bottom-color:#FFF}.widgettitle{color:#6bb6ff;background-color:#c8e4ff}.footer{background-color:#e0e4eb}.footer, .footer a, .footer .widget ul li a{color:#3c3c3c}#toc_container .toc_title, .entry-content .ez-toc-title-container, #footer_menu .raised, .pagination a, .pagination span, #reply-title:before, .entry-content blockquote:before, .main-c-before li:before, .main-c-b:before{color:#6bb6ff}.searchform__submit, #toc_container .toc_title:before, .ez-toc-title-container:before, .cat-name, .pre_tag > span, .pagination .current, .post-page-numbers.current, #submit, .withtag_list > span, .main-bc-before li:before{background-color:#6bb6ff}#toc_container, #ez-toc-container, h3, .li-mainbdr ul, .li-mainbdr ol{border-color:#6bb6ff}.search-title i, .acc-bc-before li:before{background:#ffb36b}.li-accentbdr ul, .li-accentbdr ol{border-color:#ffb36b}.pagination a:hover, .li-pastelbc ul, .li-pastelbc ol{background:#c8e4ff}body{font-size:100%}@media only screen and (min-width:481px){body{font-size:107%}}@media only screen and (min-width:1030px){body{font-size:107%}}.totop{background:#5ba9f7}.header-info a{color:#FFF;background:linear-gradient(95deg, #f4926e, #eabd83)}.fixed-menu ul{background:#FFF}.fixed-menu a{color:#a2a7ab}.fixed-menu .current-menu-item a, .fixed-menu ul li a.active{color:#6bb6ff}.post-tab{background:#FFF}.post-tab > div{color:#a7a7a7}.post-tab > div.tab-active{background:linear-gradient(45deg, #bdb9ff, #67b8ff)}body{font-family:"Helvetica", "Arial", "Hiragino Kaku Gothic ProN", "Hiragino Sans", YuGothic, "Yu Gothic", "メイリオ", Meiryo, sans-serif;}.dfont{font-family:"Quicksand","Helvetica", "Arial", "Hiragino Kaku Gothic ProN", "Hiragino Sans", YuGothic, "Yu Gothic", "メイリオ", Meiryo, sans-serif;}</style></head>
# <body class="post-template-default single single-post postid-381 single-format-standard fa5">
# <div id="container">
# <header class="header">
# <div class="wrap cf" id="inner-header">
# <div class="header-logo h1 dfont" id="logo">
# <a class="header-logo__link" href="https://toiguru.jp">
# <img alt="トイグル" class="header-logo__img" src="https://toiguru.jp/wp-content/uploads/2018/03/toeic-guru-logo-1_white.png"/>
# </a>
# </div>
# <div class="header-search">
# <label class="header-search__open" for="header-search-input"><i class="fas fa-search"></i></label>
# <input class="header-search__input" id="header-search-input" onclick="document.querySelector('.header-search__modal .searchform__input').focus()" type="checkbox"/>
# <label class="header-search__close" for="header-search-input"></label>
# <div class="header-search__modal">
# <form action="https://toiguru.jp/" class="searchform" id="searchform" method="get" role="search">
# <div>
# <input class="searchform__input" id="s" name="s" placeholder="検索" type="search" value=""/>
# <button class="searchform__submit" id="searchsubmit" type="submit"><i class="fas fa-search"></i></button>
# </div>
# </form> </div>
# </div> <nav class="desktop-nav clearfix"><ul class="menu" id="menu-%e3%83%98%e3%83%83%e3%83%80%e3%83%bc%e3%83%a1%e3%83%8b%e3%83%a5%e3%83%bc"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-23710" id="menu-item-23710"><a href="https://toiguru.jp/toiguru-service">サービス一覧</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-23711" id="menu-item-23711"><a href="https://toiguru.jp/toiguru-author">プロフィール</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-23709" id="menu-item-23709"><a href="https://toiguru.jp/case">TOEIC®スコアアップ事例集</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-23713" id="menu-item-23713"><a href="https://toiguru.jp/all-exam-preps">TOEIC®勉強法</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-23712" id="menu-item-23712"><a href="https://toiguru.jp/learning-english">英語勉強法</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-23714" id="menu-item-23714"><a href="https://toiguru.jp/english-grammar">英文法</a></li>
# </ul></nav></div>
# </header>
# <div class="one-column" id="content">
# <div class="wrap cf" id="inner-content">
# <main class="m-all t-2of3 d-5of7 cf" id="main">
# <article class="cf post-381 post type-post status-publish format-standard has-post-thumbnail category-articles" id="entry">
# <header class="article-header entry-header">
# <nav class="breadcrumb" id="breadcrumb"><ul itemscope="" itemtype="http://schema.org/BreadcrumbList"><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a href="https://toiguru.jp" itemprop="item"><span itemprop="name">ホーム</span></a><meta content="1" itemprop="position"/></li><li itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><a href="https://toiguru.jp/category/articles" itemprop="item"><span itemprop="name">トイグル記事</span></a><meta content="2" itemprop="position"/></li></ul></nav> <h1 class="entry-title single-title">絶対に覚えたい！TOEIC頻出単語1,000語まとめ</h1>
# <div class="entry-meta vcard">
# <time class="pubdate entry-time" datetime="2015-05-28" itemprop="datePublished">2015年5月28日</time><time class="updated entry-time" datetime="2019-06-28" itemprop="dateModified">2019年6月28日</time> </div>
# <p class="post-thumbnail"><img alt="" class="attachment-thumb-940 size-thumb-940 wp-post-image" height="585" loading="lazy" sizes="(max-width: 940px) 100vw, 940px" src="https://toiguru.jp/wp-content/uploads/2015/05/thumb_vocab_ver3_001-940x585.jpeg" srcset="https://toiguru.jp/wp-content/uploads/2015/05/thumb_vocab_ver3_001-940x585.jpeg 940w, https://toiguru.jp/wp-content/uploads/2015/05/thumb_vocab_ver3_001-300x187.jpeg 300w, https://toiguru.jp/wp-content/uploads/2015/05/thumb_vocab_ver3_001-768x478.jpeg 768w, https://toiguru.jp/wp-content/uploads/2015/05/thumb_vocab_ver3_001-1024x638.jpeg 1024w, https://toiguru.jp/wp-content/uploads/2015/05/thumb_vocab_ver3_001.jpeg 1400w" width="940"/></p>
# </header>
# <section class="entry-content cf">
# <p>TOEIC試験でスコアを上げるには、単語力が何よりも重要である。</p>
# <p>単語力があればリスニングの聞き取りができるようになる。単語力があれば英文が読めるようになり、リーディングセクションのスコアが上がる。</p>
# <p>そこでトイグルでは、<strong>TOEIC試験によく出る英単語1,000語</strong>をまとめた。</p>
# <p>単語リストはTOEICをはじめて学ぶ方から、ハイスコアを目指す上級者まで使えるよう5段階に分けている。</p>
# <p>本記事を活用してTOEICスコアを上げていってほしい。</p>
# <p class="has-small-font-size">(この記事は2019年2月に内容を全面改訂しました)</p>
# <h2>＊目次</h2>
# <ul><li><a href="#smoothplay0">はじめに: TOEICの単語は優先度順に学ぶ</a></li><li><a href="#smoothplay1">優先順位1: 全受験者が覚えたいTOEIC単語250語</a></li><li><a href="#smoothplay2">優先順位2: 試験によく出るTOEIC単語225語</a></li><li><a href="#smoothplay3">優先順位3: 内容理解に差が出るTOEIC単語225語</a></li><li><a href="#smoothplay4">優先順位4: 速読・速聴に役立つTOEIC単語200語</a></li><li><a href="#smoothplay5">優先順位5: ハイスコアを狙う上級者向けTOEIC単語100語</a></li></ul>
# <h2 id="smoothplay0">＊TOEICの単語は優先度順に学ぶ</h2>
# <p>TOEICは初心者から上級者まで、全受験者が同じ設問を解く試験である。難易度の低い語句から高い語句まで、幅広い語彙が出現するのが特徴だ。</p>
# <p>TOEICを受験するにあたり、すべての語句を覚えることは難しいし、その必要もない。大切なのは目標スコアに合わせて、覚えるべき単語とそうでない単語の<strong>優先順位</strong>をつけることである。</p>
# <p>もしあなたがTOEIC600点を目指すなら、試験によく出る単語を優先して学ぼう。あなたが800点以上を目指す上級者であれば、頻出単語に加えて高難易度の語句を学ぶと良い。</p>
# <p>トイグルでは、TOEICによく出る1,000語を5段階の優先度で区分した。各優先度順の単語を紹介していこう。</p>
# <figure class="wp-block-image"><img alt="" class="wp-image-16660" height="768" loading="lazy" sizes="(max-width: 1024px) 100vw, 1024px" src="https://toiguru.jp/wp-content/uploads/2019/02/vocab_ver3_180219.002-1024x768.jpeg" srcset="https://toiguru.jp/wp-content/uploads/2019/02/vocab_ver3_180219.002-1024x768.jpeg 1024w, https://toiguru.jp/wp-content/uploads/2019/02/vocab_ver3_180219.002-300x225.jpeg 300w, https://toiguru.jp/wp-content/uploads/2019/02/vocab_ver3_180219.002-768x576.jpeg 768w, https://toiguru.jp/wp-content/uploads/2019/02/vocab_ver3_180219.002-940x705.jpeg 940w, https://toiguru.jp/wp-content/uploads/2019/02/vocab_ver3_180219.002.jpeg 1200w" width="1024"/></figure>
# <h2 id="smoothplay1">優先順位1: 全受験者が覚えたいTOEIC単語250語</h2>
# <table class="wp-block-table has-fixed-layout"><tbody><tr><td>survey<br/>調査</td><td>interview<br/>面接</td></tr><tr><td>exhibition<br/>展示</td><td>conference<br/>会議</td></tr><tr><td>available<br/>利用できる</td><td>annual<br/>年1回の</td></tr><tr><td>equipment<br/>備品／器具</td><td>department<br/>部署</td></tr><tr><td>refund<br/>払い戻す</td><td>receipt<br/>領収書</td></tr><tr><td>schedule<br/>予定, 計画</td><td>meeting<br/>会議</td></tr><tr><td>customer<br/>客</td><td>employee<br/>従業員</td></tr><tr><td>actually<br/>実際は</td><td>according to<br/>〜によれば</td></tr><tr><td>change<br/>変える／つり銭</td><td>contact<br/>連絡を取る</td></tr><tr><td>purchase<br/>購入する</td><td>provide<br/>提供する</td></tr><tr><td>building<br/>建物</td><td>probably<br/>おそらく</td></tr><tr><td>delay<br/>遅れ</td><td>opportunity<br/>機会</td></tr><tr><td>agree<br/>賛成する</td><td>invoice<br/>請求書</td></tr><tr><td>appointment<br/>予約／約束</td><td>increase<br/>増加／増える</td></tr><tr><td>piece<br/>作品</td><td>participate in<br/>参加する</td></tr><tr><td>collect<br/>集める</td><td>once<br/>いったん…すると</td></tr><tr><td>currently<br/>現在のところ</td><td>process<br/>過程／処理をする</td></tr><tr><td>problem<br/>問題</td><td>experience<br/>経験</td></tr><tr><td>tour<br/>旅行／見学</td><td>while<br/>〜している間に／…の一方で</td></tr><tr><td>center<br/>中心地／センター</td><td>supervisor<br/>監督者</td></tr><tr><td>suggestion<br/>提案</td><td>coupon<br/>クーポン</td></tr><tr><td>receive<br/>受け取る</td><td>participant<br/>参加者</td></tr><tr><td>note that<br/>ご注意ください</td><td>confirm<br/>確認する</td></tr><tr><td>meet<br/>会う</td><td>reduce<br/>減らす</td></tr><tr><td>concern<br/>心配</td><td>way<br/>方法／道</td></tr><tr><td>special<br/>特別</td><td>prepare<br/>用意する</td></tr><tr><td>renovation<br/>改装</td><td>early<br/>早い</td></tr><tr><td>view<br/>意見／眺め</td><td>return<br/>戻る／返す</td></tr><tr><td>approve<br/>承認する</td><td>budget<br/>予算</td></tr><tr><td>team<br/>チーム</td><td>recently<br/>最近</td></tr><tr><td>shop<br/>買い物をする</td><td>fine<br/>素晴らしい</td></tr><tr><td>home<br/>家</td><td>reservation<br/>予約</td></tr><tr><td>additional<br/>追加の</td><td>medical<br/>医学の</td></tr><tr><td>move<br/>動かす／引っ越す</td><td>resource<br/>資源</td></tr><tr><td>show<br/>見せる</td><td>design<br/>デザイン</td></tr><tr><td>total<br/>全部の</td><td>presentation<br/>プレゼンテーション</td></tr><tr><td>bring<br/>持ってくる／もたらす</td><td>improve<br/>改良する</td></tr><tr><td>several<br/>いくつか</td><td>news<br/>知らせ</td></tr><tr><td>service<br/>サービス／点検する</td><td>through<br/>…を通して</td></tr><tr><td>until<br/>…まで</td><td>passenger<br/>乗客</td></tr><tr><td>produce<br/>農作物／製造する</td><td>allow<br/>許す</td></tr><tr><td>representative<br/>代表者</td><td>check<br/>調べる</td></tr><tr><td>leave<br/>去る</td><td>issue<br/>問題／発行する</td></tr><tr><td>price<br/>価格</td><td>last<br/>続く</td></tr><tr><td>promote<br/>促進する</td><td>hold<br/>保有する</td></tr><tr><td>idea<br/>考え</td><td>industry<br/>産業</td></tr><tr><td>feature<br/>特徴</td><td>replacement<br/>取り替え</td></tr><tr><td>pay<br/>支払う</td><td>update<br/>更新する</td></tr><tr><td>director<br/>担当責任者</td><td>hire<br/>雇う</td></tr><tr><td>floor<br/>階</td><td>course<br/>課程</td></tr><tr><td>museum<br/>博物館</td><td>recommend<br/>推薦する</td></tr><tr><td>great<br/>優れた</td><td>install<br/>取り付ける</td></tr><tr><td>member<br/>メンバー</td><td>size<br/>大きさ</td></tr><tr><td>management<br/>経営／管理</td><td>review<br/>見直し／見直す</td></tr><tr><td>sincerely<br/>敬具</td><td>logo<br/>ロゴ</td></tr><tr><td>revise<br/>改める</td><td>corporate<br/>企業の</td></tr><tr><td>construction<br/>建設／工事</td><td>deadline<br/>締め切り</td></tr><tr><td>sign<br/>標識／署名する</td><td>replace<br/>取って代わる</td></tr><tr><td>find<br/>見つける</td><td>register<br/>記録する</td></tr><tr><td>merchandise<br/>商品</td><td>important<br/>重要な</td></tr><tr><td>open<br/>開ける</td><td>facility<br/>施設</td></tr><tr><td>identification<br/>身分証明書</td><td>instead<br/>その代りに</td></tr><tr><td>before<br/>〜よりも前に</td><td>remember<br/>覚えている</td></tr><tr><td>public<br/>公衆の</td><td>submit<br/>提出する</td></tr><tr><td>vacation<br/>休暇</td><td>guest<br/>客</td></tr><tr><td>award<br/>賞</td><td>discuss<br/>話し合う</td></tr><tr><td>cost<br/>費用／費用がかかる</td><td>wait<br/>待つ</td></tr><tr><td>entrance<br ...
# <h2 id="smoothplay2">優先順位2: 試験によく出るTOEIC単語225語</h2>
# <table class="wp-block-table has-fixed-layout"><tbody><tr><td>catering<br/>仕出し業</td><td>ensure<br/>確実にする</td></tr><tr><td>estimate<br/>見積もり／見積もる</td><td>potential<br/>潜在的な</td></tr><tr><td>remind<br/>気づかせる</td><td>intend<br/>…するつもりである</td></tr><tr><td>delighted<br/>大いに喜んで</td><td>despite<br/>…にもかかわらず</td></tr><tr><td>specialize in<br/>…を専門に扱う</td><td>complimentary<br/>無料の</td></tr><tr><td>although<br/>…だけれども</td><td>beverage<br/>水以外の飲み物</td></tr><tr><td>honor<br/>名誉／約束などを遵守する</td><td>mayor<br/>市長</td></tr><tr><td>venue<br/>会場</td><td>immediately<br/>ただちに</td></tr><tr><td>sound<br/>…に思われる</td><td>contemporary<br/>現代の</td></tr><tr><td>badge<br/>バッジ</td><td>appliance<br/>(電気の)器具</td></tr><tr><td>assist<br/>助ける</td><td>inspection<br/>視察</td></tr><tr><td>expire<br/>(有効期限が)切れる</td><td>necessary<br/>必要な</td></tr><tr><td>associate<br/>同僚／関連付ける</td><td>paperwork<br/>文書業務</td></tr><tr><td>Excuse me.<br/>すいません</td><td>Let’s<br/>…しよう</td></tr><tr><td>remain<br/>…のままである</td><td>correct<br/>訂正する／正しい</td></tr><tr><td>continue<br/>続ける</td><td>certainly<br/>確かに</td></tr><tr><td>fabric<br/>布地</td><td>patient<br/>患者</td></tr><tr><td>applicant<br/>応募者</td><td>architect<br/>建築家</td></tr><tr><td>attach<br/>添付する</td><td>variety<br/>いろいろの</td></tr><tr><td>anyway<br/>いずれにせよ</td><td>conversation<br/>会話</td></tr><tr><td>forget<br/>忘れる</td><td>shuttle<br/>シャトル便のバス</td></tr><tr><td>appear<br/>…のように見える</td><td>crew<br/>乗組員</td></tr><tr><td>vote<br/>投票</td><td>busy<br/>忙しい</td></tr><tr><td>coworker<br/>仕事仲間</td><td>excellent<br/>非常に優れた</td></tr><tr><td>grocery<br/>食料品店</td><td>save<br/>たくわえる</td></tr><tr><td>cause<br/>原因／引き起こす</td><td>attract<br/>引き寄せる</td></tr><tr><td>launch<br/>開始する</td><td>status<br/>地位／状態</td></tr><tr><td>procedure<br/>手順</td><td>invitation<br/>招待</td></tr><tr><td>lobby<br/>玄関ホール</td><td>realize<br/>よくわかる／実現する</td></tr><tr><td>effort<br/>努力</td><td>mainly<br/>主に</td></tr><tr><td>campaign<br/>キャンペーン</td><td>key<br/>手がかり</td></tr><tr><td>proposal<br/>提案</td><td>greet<br/>挨拶をする</td></tr><tr><td>negotiate<br/>…と交渉する</td><td>quantity<br/>数量</td></tr><tr><td>behind<br/>…の後ろに</td><td>comfortable<br/>快適な</td></tr><tr><td>expensive<br/>値段が高い</td><td>head<br/>長</td></tr><tr><td>appreciate<br/>ありがたく思う</td><td>branch<br/>支店</td></tr><tr><td>investment<br/>投資すること</td><td>deposit<br/>頭金</td></tr><tr><td>difficult<br/>難しい</td><td>temporary<br/>一時の</td></tr><tr><td>protection<br/>保護</td><td>wish<br/>…すればよいのだが</td></tr><tr><td>film<br/>映画</td><td>condition<br/>状態</td></tr><tr><td>device<br/>装置</td><td>personnel<br/>人事部</td></tr><tr><td>professor<br/>教授</td><td>complaint<br/>不満</td></tr><tr><td>multiple<br/>多数の</td><td>exchange<br/>交換する</td></tr><tr><td>manage<br/>どうにかやり遂げる</td><td>favorite<br/>お気に入りの</td></tr><tr><td>quite<br/>とても</td><td>distance<br/>距離</td></tr><tr><td>luggage<br/>手荷物</td><td>admission<br/>入学／入会</td></tr><tr><td>inquire<br/>尋ねる</td><td>ingredient<br/>食材</td></tr><tr><td>technique<br/>テクニック</td><td>attention<br/>注意</td></tr><tr><td>consultant<br/>コンサルタント</td><td>postpone<br/>延期する</td></tr><tr><td>revenue<br/>総収益</td><td>speech<br/>講演</td></tr><tr><td>highly<br/>非常に</td><td>term<br/>学期／専門用語</td></tr><tr><td>agenda<br/>協議事項</td><td>demonstration<br/>実演</td></tr><tr><td>competition<br/>競争</td><td>specific<br/>具体的な</td></tr><tr><td>rather<br/>いくぶん</td><td>impress<br/>感銘を与える</td></tr><tr><td>fact<br/>事実</td><td>signature<br/>署名</td></tr><tr><td>payroll<br/>従業員名簿／賃金台帳</td><td>acknowledge<br/>認める</td></tr><tr><td>win<br/>勝つ／獲得する</td><td>seem<br/>…のように思われる</td></tr><tr><td>trouble<br/>故障／不調</td><td>convention<br/>大会</td></tr><tr><td>task<br/>仕事</td><td>without<br/>…なしで</td></tr><tr><td>reschedule<br/>予定を変更する</td><td>teach<br/>教える</td></tr><tr><td>handle<br/>取り扱う</td><td>distribute<br/>販売する</td></tr><tr><td>suitable<br/>適した</td><td>between<br/>…の間に</td></tr><tr><td>throughout<br/>…の到るところに</td><td>choice<br/>選択</td></tr><tr><td>official<br/>公式の</td><td>region<br/>地域</td></tr><tr><td>notify<br/>知らせる</td><td>exercise<br/>運動／権利を行使する</td></tr><tr><t ...
# <h2 id="smoothplay3">優先順位3: 内容理解に差が出るTOEIC単語225語</h2>
# <table class="wp-block-table has-fixed-layout"><tbody><tr><td>subscribe<br/>購読する</td><td>questionnaire<br/>アンケート</td></tr><tr><td>itinerary<br/>旅行計画</td><td>degree<br/>学位</td></tr><tr><td>certificate<br/>証明書</td><td>enclose<br/>同封する<br/></td></tr><tr><td>deal with<br/>処理する</td><td>highlight<br/>目立たせる</td></tr><tr><td>neighborhood<br/>近所</td><td>prior to<br/>…より前に</td></tr><tr><td>significant<br/>重要な</td><td>prescription<br/>処方箋</td></tr><tr><td>eatery<br/>食堂</td><td>be supposed to<br/>…であると思う</td></tr><tr><td>eligible<br/>適任の</td><td>I’m afraid…<br/>申し訳ありませんが…</td></tr><tr><td>broadcast<br/>放送番組／放送する</td><td>definitely<br/>間違いなく</td></tr><tr><td>implement<br/>実行する</td><td>on behalf of<br/>…を代表して</td></tr><tr><td>finally<br/>ようやく</td><td>exclusive<br/>独占的な</td></tr><tr><td>occur<br/>起こる</td><td>predict<br/>予測する</td></tr><tr><td>terminal<br/>発着ロビー</td><td>in the meantime<br/>それまで</td></tr><tr><td>affordable<br/>値段が手頃な</td><td>ceiling<br/>天井</td></tr><tr><td>major<br/>専攻科目／主要な</td><td>directory<br/>名簿</td></tr><tr><td>regularly<br/>定期的に</td><td>otherwise<br/>さもなければ</td></tr><tr><td>depart<br/>出発する</td><td>introduction<br/>導入</td></tr><tr><td>impact<br/>影響</td><td>worth<br/>…に値する</td></tr><tr><td>decrease<br/>減少する</td><td>beyond<br/>…の向こうに</td></tr><tr><td>whenever<br/>…する時はいつでも</td><td>willing<br/>…してもかまわない</td></tr><tr><td>college<br/>大学</td><td>showcase<br/>ガラスケース</td></tr><tr><td>formal<br/>正式の</td><td>adjust<br/>調整する</td></tr><tr><td>relevant<br/>関連のある</td><td>absolutely<br/>絶対に</td></tr><tr><td>district<br/>地域</td><td>maximum<br/>最大量／最大数</td></tr><tr><td>cuisine<br/>料理</td><td>yield<br/>産出する</td></tr><tr><td>approximate<br/>およそ</td><td>clerk<br/>ホテルなどの係</td></tr><tr><td>fund<br/>基金／資金を提供する</td><td>decline<br/>断る／減少する</td></tr><tr><td>autograph<br/>有名人のサイン</td><td>particular<br/>特定の</td></tr><tr><td>uniform<br/>制服</td><td>apologize<br/>謝罪する</td></tr><tr><td>accessible<br/>行きやすい</td><td>instrument<br/>楽器</td></tr><tr><td>photocopy<br/>コピー</td><td>administrative<br/>管理の</td></tr><tr><td>contribute<br/>提供する／貢献する</td><td>digest<br/>要約／情報を消化する</td></tr><tr><td>classic<br/>見事な／定番の</td><td>equally<br/>等しく</td></tr><tr><td>enroll<br/>入学する</td><td>achievement<br/>達成</td></tr><tr><td>in writing<br/>文字で</td><td>donate<br/>寄付する</td></tr><tr><td>decade<br/>10年間</td><td>temperature<br/>温度</td></tr><tr><td>reflect<br/>映す</td><td>owe<br/>借りている</td></tr><tr><td>normally<br/>ふつうは</td><td>audience<br/>聴衆</td></tr><tr><td>practical<br/>実践的な</td><td>hurry<br/>急ぐ</td></tr><tr><td>unique<br/>独特の</td><td>guarantee<br/>保証する</td></tr><tr><td>undergo<br/>経験する</td><td>institute<br/>機関</td></tr><tr><td>hardly<br/>ほとんど…ない</td><td>outstanding<br/>傑出した／未払いの</td></tr><tr><td>aside from<br/>…は別として</td><td>inside<br/>…の中へ</td></tr><tr><td>baggage<br/>手荷物</td><td>method<br/>方法</td></tr><tr><td>in a row<br/>一列に</td><td>profile<br/>プロフィール</td></tr><tr><td>emphasize<br/>強調する</td><td>handbook<br/>入門書</td></tr><tr><td>satisfaction<br/>満足</td><td>defect<br/>傷</td></tr><tr><td>moment<br/>瞬間</td><td>foundation<br/>基礎</td></tr><tr><td>clarify<br/>明らかにする</td><td>auditorium<br/>講堂</td></tr><tr><td>exit<br/>出口</td><td>recipient<br/>受取人</td></tr><tr><td>progress<br/>進歩</td><td>decorate<br/>飾る</td></tr><tr><td>guess<br/>推測する</td><td>unless<br/>…しない限り</td></tr><tr><td>efficiency<br/>能率</td><td>ladder<br/>はしご</td></tr><tr><td>quick<br/>迅速な</td><td>workplace<br/>仕事場</td></tr><tr><td>durable<br/>耐久性のある</td><td>merger<br/>合併</td></tr><tr><td>priority<br/>優先事項</td><td>primary<br/>主要な</td></tr><tr><td>input<br/>知識などの提供</td><td>monitor<br/>モニター</td></tr><tr><td>entire<br/>全体の</td><td>structure<br/>構造</td></tr><tr><td>individual<br/>個人</td><td>finalize<br/>完結させる</td></tr><tr><td>evidence<br/>証拠</td><td>stack<br/>積み重ねる</td></tr><tr><td>qualify<br/>資格を与える</td><td>regulation<br/>規則</td></tr><tr><td>summary<br/>要約</td><td>compact<br/>小型の</td></tr><tr><td>constant<br/>絶え間なく続く</td><td>gather<br/>集める</td></tr><tr><td>shortly<br/>まもなく</td><td>incorporate<br/>組み入れる</td></tr><tr><td>projector< ...
# <h2 id="smoothplay4">優先順位4: 速読・速聴に役立つTOEIC単語200語</h2>
# <table class="wp-block-table has-fixed-layout"><tbody><tr><td>refreshment<br/>軽食</td><td>incredible<br/>すばらしい</td></tr><tr><td>furthermore<br/>その上に</td><td>municipal<br/>市政の</td></tr><tr><td>overview<br/>概観</td><td>sufficient<br/>十分な</td></tr><tr><td>refill<br/>(飲み物の)おかわり</td><td>talent<br/>才能</td></tr><tr><td>aspect<br/>局面</td><td>nevertheless<br/>それにもかかわらず</td></tr><tr><td>tuition<br/>授業料</td><td>persuade<br/>説得する</td></tr><tr><td>regardless of<br/>…にかまわず</td><td>comprehensive<br/>包括的な</td></tr><tr><td>eliminate<br/>除去する</td><td>enhance<br/>向上させる</td></tr><tr><td>perhaps<br/>おそらく</td><td>premise<br/>建物</td></tr><tr><td>remark<br/>発言</td><td>scheme<br/>計画</td></tr><tr><td>generate<br/>生み出す</td><td>conclude<br/>結論を下す</td></tr><tr><td>adjacent to<br/>隣接した</td><td>likewise<br/>同様に</td></tr><tr><td>prospect<br/>見通し</td><td>capability<br/>能力</td></tr><tr><td>enormous<br/>巨大な</td><td>checkup<br/>健康診断／点検</td></tr><tr><td>substitute<br/>代用品</td><td>failure<br/>失敗</td></tr><tr><td>massive<br/>巨大な</td><td>enlarge<br/>拡大する</td></tr><tr><td>moderate<br/>適度の</td><td>reject<br/>拒絶する</td></tr><tr><td>interruption<br/>中断</td><td>fluctuate<br/>変動する</td></tr><tr><td>generous<br/>気前の良い</td><td>consecutive<br/>連続した</td></tr><tr><td>intermediate<br/>中級の</td><td>aisle<br/>通路</td></tr><tr><td>deserve<br/>…に値する</td><td>sightseeing<br/>観光</td></tr><tr><td>readability<br/>読みさすさ</td><td>meanwhile<br/>同時に／一方では</td></tr><tr><td>majority<br/>大多数</td><td>postal<br/>郵便の</td></tr><tr><td>voice<br/>意見</td><td>foreign<br/>外国の</td></tr><tr><td>fieldwork<br/>現地調査</td><td>checklist<br/>一覧表</td></tr><tr><td>keynote<br/>基調講演</td><td>minimum<br/>最小限／最小の</td></tr><tr><td>expertise<br/>専門知識</td><td>flaw<br/>傷／欠陥</td></tr><tr><td>token<br/>しるし</td><td>outcome<br/>結果</td></tr><tr><td>enterprise<br/>企業</td><td>prevent<br/>妨げる</td></tr><tr><td>scholarship<br/>奨学金</td><td>import<br/>輸入する</td></tr><tr><td>amazing<br/>すばらしい</td><td>fortunate<br/>運の良い</td></tr><tr><td>illustrate<br/>説明する</td><td>urgency<br/>緊急</td></tr><tr><td>hesitate<br/>ためらう</td><td>represent<br/>代表する</td></tr><tr><td>surpass<br/>優る</td><td>destination<br/>目的地</td></tr><tr><td>behavior<br/>態度</td><td>proficiency<br/>熟練度</td></tr><tr><td>function<br/>機能</td><td>recreation<br/>気晴らし</td></tr><tr><td>recall<br/>回収する</td><td>beforehand<br/>あらかじめ</td></tr><tr><td>downstairs<br/>階下へ</td><td>sustain<br/>維持する</td></tr><tr><td>translate<br/>翻訳する</td><td>transcript<br/>成績証明書</td></tr><tr><td>confident<br/>確信している</td><td>overcome<br/>克服する</td></tr><tr><td>anymore<br/>もはや</td><td>utility<br/>公共設備／実用性</td></tr><tr><td>allocate<br/>割り当てる</td><td>whereas<br/>…だが一方</td></tr><tr><td>accustom<br/>慣れさせる</td><td>forecast<br/>予報</td></tr><tr><td>resign<br/>辞職する</td><td>reasonable<br/>(価格が)手頃な</td></tr><tr><td>incline<br/>…に気が向く</td><td>spokesperson<br/>代弁者</td></tr><tr><td>utensil<br/>台所用具</td><td>accurate<br/>正確な</td></tr><tr><td>bid<br/>入札／値をつける</td><td>prototype<br/>試作品</td></tr><tr><td>fiscal<br/>会計の</td><td>spectator<br/>観客</td></tr><tr><td>inconvenience<br/>不自由</td><td>income<br/>収入</td></tr><tr><td>situation<br/>状況</td><td>moreover<br/>その上</td></tr><tr><td>fantastic<br/>すばらしい</td><td>detour<br/>迂回路</td></tr><tr><td>amateur<br/>アマチュア</td><td>genre<br/>ジャンル</td></tr><tr><td>thus<br/>したがって</td><td>tend to do<br/>…する傾向がある</td></tr><tr><td>overflow<br/>いっぱいになる</td><td>browse<br/>商品を見て回る</td></tr><tr><td>validate<br/>…だ正しいことを証明する</td><td>examine<br/>調査する</td></tr><tr><td>quote<br/>見積額</td><td>reward<br/>報酬</td></tr><tr><td>typical<br/>典型的な</td><td>guidebook<br/>ガイドブック</td></tr><tr><td>mission<br/>任務</td><td>average<br/>平均の</td></tr><tr><td>asset<br/>有用な人／資産</td><td>usage<br/>使い方</td></tr><tr><td>respectively<br/>それぞれに</td><td>instant<br/>即時の</td></tr><tr><td>archive<br/>記録文書</td><td>vacancy<br/>空席</td></tr><tr><td>enthusiastic<br/>熱意のある</td><td>mere<br/>単なる</td></tr><tr><td>seldom<br/>めったに…ない</td><td>workforce<br/>従業員</td></tr><tr><td>occupy<br/>占有する</td><td>competence<br/>能力</td></tr><tr><td>opposite<br/>逆の</td><td>utilize<br ...
# <h2 id="smoothplay5">優先順位5: ハイスコアを狙う上級者向けTOEIC単語100語</h2>
# <table class="wp-block-table has-fixed-layout"><tbody><tr><td>streamline<br/>(仕事を)合理化する</td><td>quota<br/>割当量／ノルマ</td></tr><tr><td>attribute<br/>…に原因があると考える</td><td>forthcoming<br/>今度の</td></tr><tr><td>overwhelming<br/>圧倒的な</td><td>adequate<br/>…するのに十分な</td></tr><tr><td>mandatory<br/>義務的な</td><td>redeem<br/>(現金に)換える</td></tr><tr><td>apprenticeship<br/>見習い期間</td><td>culinary<br/>食事の</td></tr><tr><td>applause<br/>拍手／賞賛</td><td>discard<br/>捨てる</td></tr><tr><td>overlook<br/>見落とす</td><td>proceeds<br/>売上高</td></tr><tr><td>aboard<br/>(船や飛行機に)乗って</td><td>adhere<br/>(忠実に)従う</td></tr><tr><td>commission<br/>手数料</td><td>specification<br/>仕様書</td></tr><tr><td>convince<br/>納得させる</td><td>specify<br/>明細に述べる</td></tr><tr><td>disclosure<br/>公開</td><td>projection<br/>予測／見通し</td></tr><tr><td>outlay<br/>出資金</td><td>prohibit<br/>禁止する</td></tr><tr><td>expedite<br/>促進する</td><td>mentor<br/>助言者</td></tr><tr><td>offset<br/>埋め合わせる</td><td>remodel<br/>改造する</td></tr><tr><td>nursery<br/>園芸店</td><td>resolve<br/>解決する</td></tr><tr><td>dismantle<br/>解体する</td><td>chronicle<br/>年代記</td></tr><tr><td>turnout<br/>出席者</td><td>bulk<br/>大部分</td></tr><tr><td>resume<br/>再開する</td><td>inlay<br/>はめ込む</td></tr><tr><td>obstacle<br/>障害物</td><td>retrieve<br/>検索する</td></tr><tr><td>compliance<br/>法令遵守</td><td>undertake<br/>引き受ける</td></tr><tr><td>endeavor<br/>試み</td><td>unload<br/>荷物をおろす</td></tr><tr><td>adopt<br/>採用する</td><td>adapt<br/>適応させる</td></tr><tr><td>abandon<br/>捨てる</td><td>congestion<br/>混雑</td></tr><tr><td>prestigious<br/>一流の</td><td>acclaim<br/>ほめたたえる</td></tr><tr><td>deliberate<br/>故意の</td><td>designate<br/>指名する</td></tr><tr><td>attest<br/>証明する</td><td>stroll<br/>散歩する</td></tr><tr><td>amend<br/>修正する</td><td>praise<br/>賞賛の言葉</td></tr><tr><td>nominate<br/>推薦する</td><td>retain<br/>保持する</td></tr><tr><td>slate<br/>予定する</td><td>novice<br/>初心者</td></tr><tr><td>alternative<br/>代案</td><td>admire<br/>感心する</td></tr><tr><td>gratitude<br/>感謝の気持ち</td><td>compile<br/>編集する</td></tr><tr><td>duplicate<br/>複製する</td><td>affiliate<br/>系列会社</td></tr><tr><td>tailor<br/>合わせて作る</td><td>aspire<br/>熱望する</td></tr><tr><td>tutor<br/>教師</td><td>alike<br/>同様に</td></tr><tr><td>compensate<br/>補う</td><td>periodic<br/>定期的な</td></tr><tr><td>disturb<br/>邪魔をする</td><td>candid<br/>率直な</td></tr><tr><td>anonymous<br/>匿名の</td><td>assure<br/>保証する</td></tr><tr><td>thoroughly<br/>徹底的に</td><td>imprint<br/>刻み込む</td></tr><tr><td>disrupt<br/>中断させる</td><td>afterward<br/>その後で</td></tr><tr><td>originate<br/>生じる</td><td>versatile<br/>多目的な</td></tr><tr><td>bypass<br/>迂回路</td><td>awning<br/>日よけ</td></tr><tr><td>ample<br/>十分な</td><td>contrast<br/>差異／対比する</td></tr><tr><td>fragile<br/>壊れやすい</td><td>coin<br/>(新語を)造り出す</td></tr><tr><td>promptly<br/>遅延なく</td><td>unconventional<br/>型にはまらない</td></tr><tr><td>conditional<br/>条件付きの</td><td>accountable<br/>責任がある</td></tr><tr><td>landmark<br/>歴史的な建物</td><td>steep<br/>急な／大幅な</td></tr><tr><td>await<br/>待つ</td><td>intermittent<br/>断続的な</td></tr><tr><td>pursue<br/>追求する</td><td>exposition<br/>説明／展示会</td></tr><tr><td>cozy<br/>居心地の良い</td><td>overhaul<br/>改善</td></tr><tr><td>rundown<br/>手短な報告</td><td>roundup<br/>総括</td></tr></tbody></table>
# <h2>まとめ: 最高の単語力を身に着けよう</h2>
# <p>この記事ではTOEIC試験に頻出の単語1,000語を紹介した。</p>
# <p>内容をまとめると次のようになる。</p>
# <ul><li><a href="#smoothplay1">優先順位1: 全受験者が覚えたいTOEIC単語250語</a><br/></li><li><a href="#smoothplay2">優先順位2: 試験によく出るTOEIC単語225語</a><br/></li><li><a href="#smoothplay3">優先順位3: 内容理解に差が出るTOEIC単語225語</a><br/></li><li><a href="#smoothplay4">優先順位4: 速読・速聴に役立つTOEIC単語200語</a><br/></li><li><a href="#smoothplay5">優先順位5: ハイスコアを狙う上級者向けTOEIC単語100語</a></li></ul>
# <p>英単語の暗記は時間がかかる。すぐに成果が現れなくても、学習内容は蓄積されていつか結果にあらわれる。本記事で紹介した方法を使えば効率的に単語を学べるはずだ。</p>
# <p>トイグルでは他にも、TOEIC試験に役立つ記事を多数公開している。ぜひともご覧いただきたい。</p>
# <a class="c_linkto longc_linkto" href="https://toiguru.jp/all-exam-preps">
# <span class="longc_img"><img alt="トイグル試験対策" class="attachment-thumb-520 size-thumb-520 wp-post-image" height="300" loading="lazy" src="https://toiguru.jp/wp-content/uploads/2020/02/thumb_all-exam-preps_ver2-520x300.jpg" width="520"/></span>
# <span class="longc_content c_linkto_text"><time class="pubdate sng-link-time dfont" datetime="2018-04-11" itemprop="datePublished">2018年4月11日</time><span class="longc_title">トイグル式！TOEICスコアを上げる勉強方法と成功事例のすべて</span></span>
# </a>
# <p>Good luck!</p>
# </section><div id="entry-footer-wrapper"></div><div id="comments">
# <div class="comment-respond" id="respond">
# <h3 class="comment-reply-title" id="reply-title">コメントを残す <small><a href="/toeic-vocabulary-list#respond" id="cancel-comment-reply-link" rel="nofollow" style="display:none;">コメントをキャンセル</a></small></h3><form action="https://toiguru.jp/wp-comments-post.php" class="comment-form" id="commentform" method="post" novalidate=""><p class="comment-notes"><span id="email-notes">メールアドレスが公開されることはありません。</span> <span class="required">*</span> が付いている欄は必須項目です</p><p class="comment-form-comment"><label for="comment">コメント</label> <textarea cols="45" id="comment" maxlength="65525" name="comment" required="required" rows="8"></textarea></p><p class="comment-form-author"><label for="author">名前 <span class="required">*</span></label> <input id="author" maxlength="245" name="author" required="required" size="30" type="text" value=""/></p>
# <p class="comment-form-email"><label for="email">メール <span class="required">*</span></label> <input aria-describedby="email-notes" id="email" maxlength="100" name="email" required="required" size="30" type="email" value=""/></p>
# <p class="comment-form-url"><label for="url">サイト</label> <input id="url" maxlength="200" name="url" size="30" type="url" value=""/></p>
# <p class="form-submit"><input class="submit" id="submit" name="submit" type="submit" value="コメントを送信"/> <input id="comment_post_ID" name="comment_post_ID" type="hidden" value="381"/>
# <input id="comment_parent" name="comment_parent" type="hidden" value="0"/>
# </p><p style="display: none;"><input id="akismet_comment_nonce" name="akismet_comment_nonce" type="hidden" value="9dceb21b42"/></p><p style="display: none;"><input id="ak_js" name="ak_js" type="hidden" value="24"/></p></form> </div><!-- #respond -->
# </div><script type="application/ld+json">{"@context":"http://schema.org","@type":"Article","mainEntityOfPage":"https://toiguru.jp/toeic-vocabulary-list","headline":"絶対に覚えたい！TOEIC頻出単語1,000語まとめ","image":{"@type":"ImageObject","url":"https://toiguru.jp/wp-content/uploads/2015/05/thumb_vocab_ver3_001.jpeg","width":1400,"height":872},"datePublished":"2015-05-28T05:58:36+0900","dateModified":"2019-06-28T14:17:48+0900","author":{"@type":"Person","name":"田邉竜彦"},"publisher":{"@type":"Organization","name":"","logo":{"@type":"ImageObject","url":""}},"description":"TOEIC試験でスコアを上げるには、単語力が何よりも重要である。 単語力があればリスニングの聞き取りができるようになる。単語力があれば英文が読めるようになり、リーディングセクションのスコアが上がる。 そこでトイグルでは、 ... "}</script> </article>
# </main>
# </div>
# </div>
# <footer class="footer">
# <div class="inner-footer wrap cf" id="inner-footer">
# <div class="fblock first">
# <div class="widget_text ft_widget widget widget_custom_html"><h4 class="ft_title">カテゴリー</h4><div class="textwidget custom-html-widget"><ul>
# <li><a href="https://toiguru.jp/all-exam-preps">TOEIC勉強法</a></li>
# <li><a href="https://toiguru.jp/learning-english">英語勉強法</a></li>
# <li><a href="https://toiguru.jp/english-grammar">英文法</a></li>
# <li><a href="https://toiguru.jp/case">TOEICスコアアップ事例集</a></li>
# </ul></div></div> </div>
# <div class="fblock">
# <div class="widget_text ft_widget widget widget_custom_html"><h4 class="ft_title">トイグルのサービス</h4><div class="textwidget custom-html-widget"><ul>
# <li><a href="https://toiguru.jp/school">TOEIC対策スクール</a></li>
# <li><a href="https://toiguru.jp/seminar">TOEIC対策セミナー</a></li>
# </ul></div></div> </div>
# <div class="fblock last">
# <div class="widget_text ft_widget widget widget_custom_html"><h4 class="ft_title">トイグルについて</h4><div class="textwidget custom-html-widget"><ul>
# <li><a href="https://toiguru.jp/toiguru-author">運営者情報</a></li>
# <li><a href="https://toiguru.jp/contact">お問い合わせ</a></li>
# <li><a href="https://toiguru.jp/sitemap">全記事一覧</a></li>
# <li><a href="https://toiguru.jp/quote">引用・転載について</a></li>
# <li><a href="https://toiguru.jp/privacy-policy">プライバシーポリシー</a></li>
# </ul></div></div> </div>
# </div>
# <div id="footer-menu">
# <div>
# <a class="footer-menu__btn dfont" href="https://toiguru.jp/"><i class="fas fa-home"></i> HOME</a>
# </div>
# <nav>
# </nav>
# <p class="copyright dfont">
#             © 2020            トイグル            All rights reserved.
#           </p>
# </div>
# </footer>
# </div>
# <script id="contact-form-7-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/toiguru.jp\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"}};
# /* ]]> */
# </script>
# <script id="contact-form-7-js" src="https://toiguru.jp/wp-content/plugins/contact-form-7/includes/js/scripts.js" type="text/javascript"></script>
# <script id="jquery-ui-core-js" src="https://toiguru.jp/wp-includes/js/jquery/ui/core.min.js" type="text/javascript"></script>
# <script id="jquery-ui-datepicker-js" src="https://toiguru.jp/wp-includes/js/jquery/ui/datepicker.min.js" type="text/javascript"></script>
# <script id="jquery-ui-datepicker-js-after" type="text/javascript">
# jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"\u9589\u3058\u308b","currentText":"\u4eca\u65e5","monthNames":["1\u6708","2\u6708","3\u6708","4\u6708","5\u6708","6\u6708","7\u6708","8\u6708","9\u6708","10\u6708","11\u6708","12\u6708"],"monthNamesShort":["1\u6708","2\u6708","3\u6708","4\u6708","5\u6708","6\u6708","7\u6708","8\u6708","9\u6708","10\u6708","11\u6708","12\u6708"],"nextText":"\u6b21","prevText":"\u524d","dayNames":["\u65e5\u66dc\u65e5","\u6708\u66dc\u65e5","\u706b\u66dc\u65e5","\u6c34\u66dc\u65e5","\u6728\u66dc\u65e5","\u91d1\u66dc\u65e5","\u571f\u66dc\u65e5"],"dayNamesShort":["\u65e5","\u6708","\u706b","\u6c34","\u6728","\u91d1","\u571f"],"dayNamesMin":["\u65e5","\u6708","\u706b","\u6c34","\u6728","\u91d1","\u571f"],"dateFormat":"yy\u5e74mm\u6708d\u65e5","firstDay":1,"isRTL":false});});
# </script>
# <script id="jquery-ui-ja-js" src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.4/i18n/datepicker-ja.min.js" type="text/javascript"></script>
# <script id="jquery-ui-timepicker-js" src="https://toiguru.jp/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/jquery-ui-timepicker-addon.min.js" type="text/javascript"></script>
# <script id="jquery-ui-timepicker-ja-js" src="https://toiguru.jp/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-timepicker/i18n/jquery-ui-timepicker-ja.js" type="text/javascript"></script>
# <script id="jquery-ui-widget-js" src="https://toiguru.jp/wp-includes/js/jquery/ui/widget.min.js" type="text/javascript"></script>
# <script id="jquery-ui-mouse-js" src="https://toiguru.jp/wp-includes/js/jquery/ui/mouse.min.js" type="text/javascript"></script>
# <script id="jquery-ui-slider-js" src="https://toiguru.jp/wp-includes/js/jquery/ui/slider.min.js" type="text/javascript"></script>
# <script id="jquery-ui-button-js" src="https://toiguru.jp/wp-includes/js/jquery/ui/button.min.js" type="text/javascript"></script>
# <script id="jquery-ui-slider-access-js" src="https://toiguru.jp/wp-content/plugins/contact-form-7-datepicker/js/jquery-ui-sliderAccess.js" type="text/javascript"></script>
# <script id="wp-embed-js" src="https://toiguru.jp/wp-includes/js/wp-embed.min.js" type="text/javascript"></script>
# <script async="async" id="akismet-form-js" src="https://toiguru.jp/wp-content/plugins/akismet/_inc/form.js" type="text/javascript"></script>
# <script>jQuery(document).ready(function(){jQuery(window).scroll(function(){if(jQuery(this).scrollTop()>700){jQuery('.totop').fadeIn(300)}else{jQuery('.totop').fadeOut(300)}});jQuery('.totop').click(function(event){event.preventDefault();jQuery('html, body').animate({scrollTop:0},300)})});</script><script>jQuery(function(){function fetchEntryFooter(){jQuery.ajax({url:'https://toiguru.jp/wp-admin/admin-ajax.php',dataType:'html',data:{'action':'fetch_entry_footer_content','id':381},success:function(data){jQuery('#entry-footer-wrapper').html(data)}})}setTimeout(function(){fetchEntryFooter()},1500)});</script> <a class="totop" href="#" rel="nofollow"><i class="fa fa-chevron-up"></i></a> </body>
# </html>

# %%
tables = soup.find_all("table")
tables

# %%
word_list_1 = []
for table in tables:
    for td in table.find_all("td"):
        tmp = str(td).split("<br/>")
        if len(tmp) != 2:
#             print(tmp)
            continue
#         print(tmp)
        word = tmp[0][4:]
        meaning = tmp[1][:-5]
#         print(word, meaning)
        word_list_1.append({word:meaning})
word_list_1.append({"neither":"どちらも…でない"})
word_list_1.append({"enclose":"同封する"})
word_list_1
# Out:
# [{'survey': '調査'},
#  {'interview': '面接'},
#  {'exhibition': '展示'},
#  {'conference': '会議'},
#  {'available': '利用できる'},
#  {'annual': '年1回の'},
#  {'equipment': '備品／器具'},
#  {'department': '部署'},
#  {'refund': '払い戻す'},
#  {'receipt': '領収書'},
#  {'schedule': '予定, 計画'},
#  {'meeting': '会議'},
#  {'customer': '客'},
#  {'employee': '従業員'},
#  {'actually': '実際は'},
#  {'according to': '〜によれば'},
#  {'change': '変える／つり銭'},
#  {'contact': '連絡を取る'},
#  {'purchase': '購入する'},
#  {'provide': '提供する'},
#  {'building': '建物'},
#  {'probably': 'おそらく'},
#  {'delay': '遅れ'},
#  {'opportunity': '機会'},
#  {'agree': '賛成する'},
#  {'invoice': '請求書'},
#  {'appointment': '予約／約束'},
#  {'increase': '増加／増える'},
#  {'piece': '作品'},
#  {'participate in': '参加する'},
#  {'collect': '集める'},
#  {'once': 'いったん…すると'},
#  {'currently': '現在のところ'},
#  {'process': '過程／処理をする'},
#  {'problem': '問題'},
#  {'experience': '経験'},
#  {'tour': '旅行／見学'},
#  {'while': '〜している間に／…の一方で'},
#  {'center': '中心地／センター'},
#  {'supervisor': '監督者'},
#  {'suggestion': '提案'},
#  {'coupon': 'クーポン'},
#  {'receive': '受け取る'},
#  {'participant': '参加者'},
#  {'note that': 'ご注意ください'},
#  {'confirm': '確認する'},
#  {'meet': '会う'},
#  {'reduce': '減らす'},
#  {'concern': '心配'},
#  {'way': '方法／道'},
#  {'special': '特別'},
#  {'prepare': '用意する'},
#  {'renovation': '改装'},
#  {'early': '早い'},
#  {'view': '意見／眺め'},
#  {'return': '戻る／返す'},
#  {'approve': '承認する'},
#  {'budget': '予算'},
#  {'team': 'チーム'},
#  {'recently': '最近'},
#  {'shop': '買い物をする'},
#  {'fine': '素晴らしい'},
#  {'home': '家'},
#  {'reservation': '予約'},
#  {'additional': '追加の'},
#  {'medical': '医学の'},
#  {'move': '動かす／引っ越す'},
#  {'resource': '資源'},
#  {'show': '見せる'},
#  {'design': 'デザイン'},
#  {'total': '全部の'},
#  {'presentation': 'プレゼンテーション'},
#  {'bring': '持ってくる／もたらす'},
#  {'improve': '改良する'},
#  {'several': 'いくつか'},
#  {'news': '知らせ'},
#  {'service': 'サービス／点検する'},
#  {'through': '…を通して'},
#  {'until': '…まで'},
#  {'passenger': '乗客'},
#  {'produce': '農作物／製造する'},
#  {'allow': '許す'},
#  {'representative': '代表者'},
#  {'check': '調べる'},
#  {'leave': '去る'},
#  {'issue': '問題／発行する'},
#  {'price': '価格'},
#  {'last': '続く'},
#  {'promote': '促進する'},
#  {'hold': '保有する'},
#  {'idea': '考え'},
#  {'industry': '産業'},
#  {'feature': '特徴'},
#  {'replacement': '取り替え'},
#  {'pay': '支払う'},
#  {'update': '更新する'},
#  {'director': '担当責任者'},
#  {'hire': '雇う'},
#  {'floor': '階'},
#  {'course': '課程'},
#  {'museum': '博物館'},
#  {'recommend': '推薦する'},
#  {'great': '優れた'},
#  {'install': '取り付ける'},
#  {'member': 'メンバー'},
#  {'size': '大きさ'},
#  {'management': '経営／管理'},
#  {'review': '見直し／見直す'},
#  {'sincerely': '敬具'},
#  {'logo': 'ロゴ'},
#  {'revise': '改める'},
#  {'corporate': '企業の'},
#  {'construction': '建設／工事'},
#  {'deadline': '締め切り'},
#  {'sign': '標識／署名する'},
#  {'replace': '取って代わる'},
#  {'find': '見つける'},
#  {'register': '記録する'},
#  {'merchandise': '商品'},
#  {'important': '重要な'},
#  {'open': '開ける'},
#  {'facility': '施設'},
#  {'identification': '身分証明書'},
#  {'instead': 'その代りに'},
#  {'before': '〜よりも前に'},
#  {'remember': '覚えている'},
#  {'public': '公衆の'},
#  {'submit': '提出する'},
#  {'vacation': '休暇'},
#  {'guest': '客'},
#  {'award': '賞'},
#  {'discuss': '話し合う'},
#  {'cost': '費用／費用がかかる'},
#  {'wait': '待つ'},
#  {'entrance': '入り口'},
#  {'program': '番組'},
#  {'read': '読む'},
#  {'choose': '選ぶ'},
#  {'however': 'しかしながら'},
#  {'free': '無料の／自由な'},
#  {'ticket': '入場券'},
#  {'expand': '拡大する'},
#  {'application': '申し込み'},
#  {'item': '項目／品目'},
#  {'résumé': '履歴書'},
#  {'vehicle': '乗り物'},
#  {'park': '公園／駐車する'},
#  {'council': '議会'},
#  {'book': '予約する'},
#  {'candidate': '志願者'},
#  {'complete': '完成させる'},
#  {'discount': '割引'},
#  {'quality': '質'},
#  {'payment': '支払い'},
#  {'arrange': '取り決める／並べる'},
#  {'different': '異なった'},
#  {'project': 'プロジェクト'},
#  {'few': 'ほとんどない'},
#  {'after': '〜の後で'},
#  {'subject': '表題'},
#  {'already': '既に'},
#  {'require': '必要とする'},
#  {'due': '支払い期限のきた'},
#  {'consider': 'よく考える'},
#  {'ship': '船／配送する'},
#  {'possible': '可能な'},
#  {'local': '地元の'},
#  {'area': '地域'},
#  {'into': '…の中に'},
#  {'delivery': '配達'},
#  {'professional': '専門的な'},
#  {'buy': '買う'},
#  {'carry': '運ぶ'},
#  {'belong': '…に付属する'},
#  {'type': '種類／類型'},
#  {'since': '…以来'},
#  {'colleague': '同僚'},
#  {'request': '要請／依頼'},
#  {'material': '材料／原料'},
#  {'fee': '謝礼'},
#  {'each': 'それぞれの'},
#  {'benefit': '利益'},
#  {'furniture': '家具'},
#  {'again': '再び'},
#  {'set': '配置する'},
#  {'during': '…の間に'},
#  {'sorry': 'すまなく思って'},
#  {'financial': '財政上の'},
#  {'be interested in': '…に興味を持っている'},
#  {'attend': '出席する'},
#  {'maintenance': '整備'},
#  {'supply': '供給する'},
#  {'welcome': '歓迎'},
#  {'conduct': '行う'},
#  {'report': '報告書／報告する'},
#  {'begin': '始める'},
#  {'whether': '…かどうか'},
#  {'upcoming': 'まもなくやって来る'},
#  {'purpose': '目的／意図'},
#  {'research': '研究'},
#  {'large': '大きい／広い'},
#  {'encourage': '励ます'},
#  {'finish': '…を終える'},
#  {'send': '送る'},
#  {'charge': '料金／請求する'},
#  {'decision': '決定'},
#  {'inventory': '在庫'},
#  {'publish': '出版する'},
#  {'think': '…と思う'},
#  {'reception': '受付'},
#  {'display': '陳列'},
#  {'both': '両方の'},
#  {'advance': '事前の'},
#  {'always': '常に'},
#  {'plan': '計画'},
#  {'ready': '用意ができた'},
#  {'visit': '訪問する'},
#  {'document': '文書／記録する'},
#  {'successful': '成功した'},
#  {'class': 'クラス／種類'},
#  {'library': '図書館'},
#  {'seminar': '研究会'},
#  {'sell': '売る'},
#  {'close': '近い'},
#  {'expect': '予期する'},
#  {'arrive': '到着する'},
#  {'remove': '取り去る'},
#  {'position': '位置'},
#  {'talk': '話す'},
#  {'describe': '説明する'},
#  {'flight': '飛行'},
#  {'repair': '修理する'},
#  {'training': '訓練'},
#  {'a lot of': 'たくさんの'},
#  {'learn': '学ぶ／知る'},
#  {'unfortunately': '残念ながら'},
#  {'people': '人々'},
#  {'cancel': '取り消す'},
#  {'include': '含む'},
#  {'location': '場所'},
#  {'client': '顧客'},
#  {'place': '場所／設置する'},
#  {'travel': '行く'},
#  {'though': 'けれども／たとえ…しても'},
#  {'board': '役員会'},
#  {'write': '書く'},
#  {'feedback': 'フィードバック'},
#  {'performance': '公演'},
#  {'soon': 'すぐ後'},
#  {'per': '…につき'},
#  {'catering': '仕出し業'},
#  {'ensure': '確実にする'},
#  {'estimate': '見積もり／見積もる'},
#  {'potential': '潜在的な'},
#  {'remind': '気づかせる'},
#  {'intend': '…するつもりである'},
#  {'delighted': '大いに喜んで'},
#  {'despite': '…にもかかわらず'},
#  {'specialize in': '…を専門に扱う'},
#  {'complimentary': '無料の'},
#  {'although': '…だけれども'},
#  {'beverage': '水以外の飲み物'},
#  {'honor': '名誉／約束などを遵守する'},
#  {'mayor': '市長'},
#  {'venue': '会場'},
#  {'immediately': 'ただちに'},
#  {'sound': '…に思われる'},
#  {'contemporary': '現代の'},
#  {'badge': 'バッジ'},
#  {'appliance': '(電気の)器具'},
#  {'assist': '助ける'},
#  {'inspection': '視察'},
#  {'expire': '(有効期限が)切れる'},
#  {'necessary': '必要な'},
#  {'associate': '同僚／関連付ける'},
#  {'paperwork': '文書業務'},
#  {'Excuse me.': 'すいません'},
#  {'Let’s': '…しよう'},
#  {'remain': '…のままである'},
#  {'correct': '訂正する／正しい'},
#  {'continue': '続ける'},
#  {'certainly': '確かに'},
#  {'fabric': '布地'},
#  {'patient': '患者'},
#  {'applicant': '応募者'},
#  {'architect': '建築家'},
#  {'attach': '添付する'},
#  {'variety': 'いろいろの'},
#  {'anyway': 'いずれにせよ'},
#  {'conversation': '会話'},
#  {'forget': '忘れる'},
#  {'shuttle': 'シャトル便のバス'},
#  {'appear': '…のように見える'},
#  {'crew': '乗組員'},
#  {'vote': '投票'},
#  {'busy': '忙しい'},
#  {'coworker': '仕事仲間'},
#  {'excellent': '非常に優れた'},
#  {'grocery': '食料品店'},
#  {'save': 'たくわえる'},
#  {'cause': '原因／引き起こす'},
#  {'attract': '引き寄せる'},
#  {'launch': '開始する'},
#  {'status': '地位／状態'},
#  {'procedure': '手順'},
#  {'invitation': '招待'},
#  {'lobby': '玄関ホール'},
#  {'realize': 'よくわかる／実現する'},
#  {'effort': '努力'},
#  {'mainly': '主に'},
#  {'campaign': 'キャンペーン'},
#  {'key': '手がかり'},
#  {'proposal': '提案'},
#  {'greet': '挨拶をする'},
#  {'negotiate': '…と交渉する'},
#  {'quantity': '数量'},
#  {'behind': '…の後ろに'},
#  {'comfortable': '快適な'},
#  {'expensive': '値段が高い'},
#  {'head': '長'},
#  {'appreciate': 'ありがたく思う'},
#  {'branch': '支店'},
#  {'investment': '投資すること'},
#  {'deposit': '頭金'},
#  {'difficult': '難しい'},
#  {'temporary': '一時の'},
#  {'protection': '保護'},
#  {'wish': '…すればよいのだが'},
#  {'film': '映画'},
#  {'condition': '状態'},
#  {'device': '装置'},
#  {'personnel': '人事部'},
#  {'professor': '教授'},
#  {'complaint': '不満'},
#  {'multiple': '多数の'},
#  {'exchange': '交換する'},
#  {'manage': 'どうにかやり遂げる'},
#  {'favorite': 'お気に入りの'},
#  {'quite': 'とても'},
#  {'distance': '距離'},
#  {'luggage': '手荷物'},
#  {'admission': '入学／入会'},
#  {'inquire': '尋ねる'},
#  {'ingredient': '食材'},
#  {'technique': 'テクニック'},
#  {'attention': '注意'},
#  {'consultant': 'コンサルタント'},
#  {'postpone': '延期する'},
#  {'revenue': '総収益'},
#  {'speech': '講演'},
#  {'highly': '非常に'},
#  {'term': '学期／専門用語'},
#  {'agenda': '協議事項'},
#  {'demonstration': '実演'},
#  {'competition': '競争'},
#  {'specific': '具体的な'},
#  {'rather': 'いくぶん'},
#  {'impress': '感銘を与える'},
#  {'fact': '事実'},
#  {'signature': '署名'},
#  {'payroll': '従業員名簿／賃金台帳'},
#  {'acknowledge': '認める'},
#  {'win': '勝つ／獲得する'},
#  {'seem': '…のように思われる'},
#  {'trouble': '故障／不調'},
#  {'convention': '大会'},
#  {'task': '仕事'},
#  {'without': '…なしで'},
#  {'reschedule': '予定を変更する'},
#  {'teach': '教える'},
#  {'handle': '取り扱う'},
#  {'distribute': '販売する'},
#  {'suitable': '適した'},
#  {'between': '…の間に'},
#  {'throughout': '…の到るところに'},
#  {'choice': '選択'},
#  {'official': '公式の'},
#  {'region': '地域'},
#  {'notify': '知らせる'},
#  {'exercise': '運動／権利を行使する'},
#  {'brochure': '小冊子'},
#  {'recognize': '認識する'},
#  {'similar': '…と似ている'},
#  {'usual': 'いつもの'},
#  {'artwork': '芸術作品'},
#  {'secure': '安定した'},
#  {'lease': '賃貸借契約'},
#  {'excite': 'わくわくさせる'},
#  {'damage': '損害'},
#  {'environment': '環境／状況'},
#  {'except': '…を除いて'},
#  {'famous': '有名な'},
#  {'nearly': 'ほとんど'},
#  {'renew': '再開する'},
#  {'manual': '説明書／手作業の'},
#  {'exceed': '…を超える'},
#  {'worry': '心配する'},
#  {'mind': '気にする'},
#  {'figure': '数／考える'},
#  {'analysis': '分析'},
#  {'search': '検索する'},
#  {'ability': '能力'},
#  {'ideal': '理想的な'},
#  {'industrial': '産業の'},
#  {'advise': '助言する'},
#  {'hard': '難しい'},
#  {'transfer': '移す／転任する'},
#  {'expo': '博覧会'},
#  {'landscape': '景色'},
#  {'initiative': '主導権'},
#  {'dining': '食事をすること'},
#  {'laboratory': '実験室'},
#  {'traditional': '伝統的な'},
#  {'accommodate': '収容する'},
#  {'title': '表題'},
#  {'further': 'それ以上に'},
#  {'vendor': '供給メーカー'},
#  {'specialist': '専門家'},
#  {'raise': '上げる／集める'},
#  {'spend': '費やす'},
#  {'consumer': '消費者'},
#  {'gain': '獲得する'},
#  {'various': 'さまざまな'},
#  {'often': 'たびたび'},
#  {'convenient': '便利な'},
#  {'wear': '…を着ている'},
#  {'previous': '以前の'},
#  {'fix': '修理する'},
#  {'standard': '基準'},
#  {'solution': '解決策'},
#  {'else': 'その他に'},
#  {'understand': '理解する'},
#  {'tier': '階層'},
#  {'together': '一緒に'},
#  {'committee': '委員会'},
#  {'congratulations': '祝いの言葉'},
#  {'extend': '延長する'},
#  {'avoid': '避ける'},
#  {'strategy': '戦略'},
#  {'inform': '知らせる'},
#  {'especially': 'とりわけ'},
#  {'mistake': '誤り'},
#  {'commercial': '営利的な'},
#  {'therefore': 'したがって'},
#  {'recruit': '新入社員／採用する'},
#  {'topic': '話題'},
#  {'contain': '含む'},
#  {'organization': '組織'},
#  {'responsible': '責任を負うべき／原因である'},
#  {'bill': '請求書'},
#  {'either': 'いずれか／どちらかの'},
#  {'prefer': '好む'},
#  {'interior': '内側'},
#  {'involve': '含む'},
#  {'executive': '重役'},
#  {'traffic': '交通'},
#  {'assign': '割り当てる'},
#  {'far from': '…から遠くに'},
#  {'warranty': '保証'},
#  {'seek': '捜す'},
#  {'nearby': '近くの'},
#  {'effective': '効果的な'},
#  {'permit': '許可証／許可する'},
#  {'attempt': '試みる'},
#  {'example': '例'},
#  {'properly': 'きちんと'},
#  {'base': '基礎／活動の中心を置く'},
#  {'clear': '明快な'},
#  {'under': '…の下に'},
#  {'response': '反響'},
#  {'surprise': '驚かす'},
#  {'verify': '…が正しいと確認する'},
#  {'better': 'より良い'},
#  {'reliable': '信頼できる'},
#  {'subscribe': '購読する'},
#  {'questionnaire': 'アンケート'},
#  {'itinerary': '旅行計画'},
#  {'degree': '学位'},
#  {'certificate': '証明書'},
#  {'deal with': '処理する'},
#  {'highlight': '目立たせる'},
#  {'neighborhood': '近所'},
#  {'prior to': '…より前に'},
#  {'significant': '重要な'},
#  {'prescription': '処方箋'},
#  {'eatery': '食堂'},
#  {'be supposed to': '…であると思う'},
#  {'eligible': '適任の'},
#  {'I’m afraid…': '申し訳ありませんが…'},
#  {'broadcast': '放送番組／放送する'},
#  {'definitely': '間違いなく'},
#  {'implement': '実行する'},
#  {'on behalf of': '…を代表して'},
#  {'finally': 'ようやく'},
#  {'exclusive': '独占的な'},
#  {'occur': '起こる'},
#  {'predict': '予測する'},
#  {'terminal': '発着ロビー'},
#  {'in the meantime': 'それまで'},
#  {'affordable': '値段が手頃な'},
#  {'ceiling': '天井'},
#  {'major': '専攻科目／主要な'},
#  {'directory': '名簿'},
#  {'regularly': '定期的に'},
#  {'otherwise': 'さもなければ'},
#  {'depart': '出発する'},
#  {'introduction': '導入'},
#  {'impact': '影響'},
#  {'worth': '…に値する'},
#  {'decrease': '減少する'},
#  {'beyond': '…の向こうに'},
#  {'whenever': '…する時はいつでも'},
#  {'willing': '…してもかまわない'},
#  {'college': '大学'},
#  {'showcase': 'ガラスケース'},
#  {'formal': '正式の'},
#  {'adjust': '調整する'},
#  {'relevant': '関連のある'},
#  {'absolutely': '絶対に'},
#  {'district': '地域'},
#  {'maximum': '最大量／最大数'},
#  {'cuisine': '料理'},
#  {'yield': '産出する'},
#  {'approximate': 'およそ'},
#  {'clerk': 'ホテルなどの係'},
#  {'fund': '基金／資金を提供する'},
#  {'decline': '断る／減少する'},
#  {'autograph': '有名人のサイン'},
#  {'particular': '特定の'},
#  {'uniform': '制服'},
#  {'apologize': '謝罪する'},
#  {'accessible': '行きやすい'},
#  {'instrument': '楽器'},
#  {'photocopy': 'コピー'},
#  {'administrative': '管理の'},
#  {'contribute': '提供する／貢献する'},
#  {'digest': '要約／情報を消化する'},
#  {'classic': '見事な／定番の'},
#  {'equally': '等しく'},
#  {'enroll': '入学する'},
#  {'achievement': '達成'},
#  {'in writing': '文字で'},
#  {'donate': '寄付する'},
#  {'decade': '10年間'},
#  {'temperature': '温度'},
#  {'reflect': '映す'},
#  {'owe': '借りている'},
#  {'normally': 'ふつうは'},
#  {'audience': '聴衆'},
#  {'practical': '実践的な'},
#  {'hurry': '急ぐ'},
#  {'unique': '独特の'},
#  {'guarantee': '保証する'},
#  {'undergo': '経験する'},
#  {'institute': '機関'},
#  {'hardly': 'ほとんど…ない'},
#  {'outstanding': '傑出した／未払いの'},
#  {'aside from': '…は別として'},
#  {'inside': '…の中へ'},
#  {'baggage': '手荷物'},
#  {'method': '方法'},
#  {'in a row': '一列に'},
#  {'profile': 'プロフィール'},
#  {'emphasize': '強調する'},
#  {'handbook': '入門書'},
#  {'satisfaction': '満足'},
#  {'defect': '傷'},
#  {'moment': '瞬間'},
#  {'foundation': '基礎'},
#  {'clarify': '明らかにする'},
#  {'auditorium': '講堂'},
#  {'exit': '出口'},
#  {'recipient': '受取人'},
#  {'progress': '進歩'},
#  {'decorate': '飾る'},
#  {'guess': '推測する'},
#  {'unless': '…しない限り'},
#  {'efficiency': '能率'},
#  {'ladder': 'はしご'},
#  {'quick': '迅速な'},
#  {'workplace': '仕事場'},
#  {'durable': '耐久性のある'},
#  {'merger': '合併'},
#  {'priority': '優先事項'},
#  {'primary': '主要な'},
#  {'input': '知識などの提供'},
#  {'monitor': 'モニター'},
#  {'entire': '全体の'},
#  {'structure': '構造'},
#  {'individual': '個人'},
#  {'finalize': '完結させる'},
#  {'evidence': '証拠'},
#  {'stack': '積み重ねる'},
#  {'qualify': '資格を与える'},
#  {'regulation': '規則'},
#  {'summary': '要約'},
#  {'compact': '小型の'},
#  {'constant': '絶え間なく続く'},
#  {'gather': '集める'},
#  {'shortly': 'まもなく'},
#  {'incorporate': '組み入れる'},
#  {'projector': 'プロジェクター'},
#  {'panel': 'パネル'},
#  {'layout': 'レイアウト'},
#  {'fare': '運賃'},
#  {'determine': '明らかにする'},
#  {'accomplishment': '達成'},
#  {'simple': '単純な'},
#  {'aware': '気づいている'},
#  {'tenant': 'テナント'},
#  {'pleasure': '喜び'},
#  {'demand': '要求／要求する'},
#  {'blueprint': '青写真'},
#  {'advantage': '有利な点'},
#  {'dental': '歯の'},
#  {'metro': '地下鉄'},
#  {'overhead': '頭上の'},
#  {'waterproof': '防水性の'},
#  {'language': '言語'},
#  {'perfect': '完璧な'},
#  {'above': '…の上方に'},
#  {'luck': '幸運'},
#  {'exactly': '正確に／そのとおり'},
#  {'influence': '影響を及ぼす'},
#  {'urgent': '緊急の'},
#  {'valuable': '価値の高い'},
#  {'assess': '評価する'},
#  {'cashier': 'レジ係'},
#  {'dedicate': '専念する'},
#  {'earn': '稼ぐ'},
#  {'from scratch': 'ゼロから'},
#  {'a couple of': '2つの'},
#  {'social': '社会の'},
#  {'connect': '接続する'},
#  {'plenty of': 'たくさん'},
#  {'overnight': '一晩中'},
#  {'clearance': '整理'},
#  {'onto': '…の上へ'},
#  {'sponsorship': '資金援助'},
#  {'flexible': '柔軟な'},
#  {'automatically': '自動的に'},
#  {'alone': 'ただ1人で'},
#  {'nutrition': '栄養'},
#  {'familiar': 'よく知られた'},
#  {'patron': '顧客'},
#  {'entry': '加入'},
#  {'broad': '広範囲の'},
#  {'steady': '着実な'},
#  {'transaction': '取引'},
#  {'delicious': 'とてもおいしい'},
#  {'checkout': 'チェックアウト／レジ'},
#  {'wheelbarrow': '手押し車'},
#  {'explore': '探索する'},
#  {'promise': '約束する'},
#  {'anticipate': '…を予期する'},
#  {'cafeteria': '食堂'},
#  {'society': '社会'},
#  {'anniversary': '記念日'},
#  {'evaluation': '評価'},
#  {'handout': '配布資料'},
#  {'direct': '向ける／直接の'},
#  {'appropriate': '適切な'},
#  {'common': 'ありふれた'},
#  {'general': 'だいたいの'},
#  {'whole': '全体の'},
#  {'proud': '多大な'},
#  {'compare': '比較する'},
#  {'numerous': '多数の'},
#  {'networking': 'ネットワークづくり'},
#  {'acquire': '獲得する'},
#  {'establish': '設立する'},
#  {'overseas': '海外の／海外へ'},
#  {'discover': '発見する'},
#  {'envelope': '封筒'},
#  {'newly': '新たに'},
#  {'expose': 'さらす'},
#  {'means': '手段'},
#  {'quarter': '四半期'},
#  {'internship': 'インターンシップ'},
#  {'walkway': '歩道'},
#  {'medication': '薬剤'},
#  {'format': 'フォーマット／構成'},
#  {'conservation': '保護'},
#  {'below': '…より下に'},
#  {'profit': '利益'},
#  {'volume': '容量'},
#  {'restore': '修復する'},
#  {'satisfy': '満足させる'},
#  {'knowledge': '知識'},
#  {'compliment': 'ほめ言葉'},
#  {'oversee': '監督する'},
#  {'judge': '審査員／判断する'},
#  {'retire': '退職する'},
#  {'huge': '巨大な'},
#  {'frequent': '頻繁に起こる'},
#  {'initial': '頭文字／最初の'},
#  {'expert': '専門家'},
#  {'approach': '手法／近づく'},
#  {'refreshment': '軽食'},
#  {'incredible': 'すばらしい'},
#  {'furthermore': 'その上に'},
#  {'municipal': '市政の'},
#  {'overview': '概観'},
#  {'sufficient': '十分な'},
#  {'refill': '(飲み物の)おかわり'},
#  {'talent': '才能'},
#  {'aspect': '局面'},
#  {'nevertheless': 'それにもかかわらず'},
#  {'tuition': '授業料'},
#  {'persuade': '説得する'},
#  {'regardless of': '…にかまわず'},
#  {'comprehensive': '包括的な'},
#  {'eliminate': '除去する'},
#  {'enhance': '向上させる'},
#  {'perhaps': 'おそらく'},
#  {'premise': '建物'},
#  {'remark': '発言'},
#  {'scheme': '計画'},
#  {'generate': '生み出す'},
#  {'conclude': '結論を下す'},
#  {'adjacent to': '隣接した'},
#  {'likewise': '同様に'},
#  {'prospect': '見通し'},
#  {'capability': '能力'},
#  {'enormous': '巨大な'},
#  {'checkup': '健康診断／点検'},
#  {'substitute': '代用品'},
#  {'failure': '失敗'},
#  {'massive': '巨大な'},
#  {'enlarge': '拡大する'},
#  {'moderate': '適度の'},
#  {'reject': '拒絶する'},
#  {'interruption': '中断'},
#  {'fluctuate': '変動する'},
#  {'generous': '気前の良い'},
#  {'consecutive': '連続した'},
#  {'intermediate': '中級の'},
#  {'aisle': '通路'},
#  {'deserve': '…に値する'},
#  {'sightseeing': '観光'},
#  {'readability': '読みさすさ'},
#  {'meanwhile': '同時に／一方では'},
#  {'majority': '大多数'},
#  {'postal': '郵便の'},
#  {'voice': '意見'},
#  {'foreign': '外国の'},
#  {'fieldwork': '現地調査'},
#  {'checklist': '一覧表'},
#  {'keynote': '基調講演'},
#  {'minimum': '最小限／最小の'},
#  {'expertise': '専門知識'},
#  {'flaw': '傷／欠陥'},
#  {'token': 'しるし'},
#  {'outcome': '結果'},
#  {'enterprise': '企業'},
#  {'prevent': '妨げる'},
#  {'scholarship': '奨学金'},
#  {'import': '輸入する'},
#  {'amazing': 'すばらしい'},
#  {'fortunate': '運の良い'},
#  {'illustrate': '説明する'},
#  {'urgency': '緊急'},
#  {'hesitate': 'ためらう'},
#  {'represent': '代表する'},
#  {'surpass': '優る'},
#  {'destination': '目的地'},
#  {'behavior': '態度'},
#  {'proficiency': '熟練度'},
#  {'function': '機能'},
#  {'recreation': '気晴らし'},
#  {'recall': '回収する'},
#  {'beforehand': 'あらかじめ'},
#  {'downstairs': '階下へ'},
#  {'sustain': '維持する'},
#  {'translate': '翻訳する'},
#  {'transcript': '成績証明書'},
#  {'confident': '確信している'},
#  {'overcome': '克服する'},
#  {'anymore': 'もはや'},
#  {'utility': '公共設備／実用性'},
#  {'allocate': '割り当てる'},
#  {'whereas': '…だが一方'},
#  {'accustom': '慣れさせる'},
#  {'forecast': '予報'},
#  {'resign': '辞職する'},
#  {'reasonable': '(価格が)手頃な'},
#  {'incline': '…に気が向く'},
#  {'spokesperson': '代弁者'},
#  {'utensil': '台所用具'},
#  {'accurate': '正確な'},
#  {'bid': '入札／値をつける'},
#  {'prototype': '試作品'},
#  {'fiscal': '会計の'},
#  {'spectator': '観客'},
#  {'inconvenience': '不自由'},
#  {'income': '収入'},
#  {'situation': '状況'},
#  {'moreover': 'その上'},
#  {'fantastic': 'すばらしい'},
#  {'detour': '迂回路'},
#  {'amateur': 'アマチュア'},
#  {'genre': 'ジャンル'},
#  {'thus': 'したがって'},
#  {'tend to do': '…する傾向がある'},
#  {'overflow': 'いっぱいになる'},
#  {'browse': '商品を見て回る'},
#  {'validate': '…だ正しいことを証明する'},
#  {'examine': '調査する'},
#  {'quote': '見積額'},
#  {'reward': '報酬'},
#  {'typical': '典型的な'},
#  {'guidebook': 'ガイドブック'},
#  {'mission': '任務'},
#  {'average': '平均の'},
#  {'asset': '有用な人／資産'},
#  {'usage': '使い方'},
#  {'respectively': 'それぞれに'},
#  {'instant': '即時の'},
#  {'archive': '記録文書'},
#  {'vacancy': '空席'},
#  {'enthusiastic': '熱意のある'},
#  {'mere': '単なる'},
#  {'seldom': 'めったに…ない'},
#  {'workforce': '従業員'},
#  {'occupy': '占有する'},
#  {'competence': '能力'},
#  {'opposite': '逆の'},
#  {'utilize': '利用する'},
#  {'intensive': '短期集中的な'},
#  {'insight': '理解／見識'},
#  {'skip': '省く'},
#  {'explanation': '説明'},
#  {'devote': 'ささげる'},
#  {'discontinue': '中止する'},
#  {'truly': '本当に'},
#  {'kickoff': '開始'},
#  {'entertainment': '娯楽'},
#  {'neutral': '中立の'},
#  {'biography': '伝記'},
#  {'precise': '正確な'},
#  {'factor': '要因'},
#  {'conform': '従う'},
#  {'eventually': '結局'},
#  {'reputation': '評判'},
#  {'curb': '縁石／抑制する'},
#  {'innovative': '刷新的な'},
#  {'malfunction': '不調'},
#  {'crucial': '重大な'},
#  {'prerequisite': '必須条件'},
#  {'reluctant': 'いやに思う'},
#  {'principle': '原理／原則'},
#  {'perceive': '理解する'},
#  {'cooperation': '協力'},
#  {'controversial': '物議をかもす'},
#  {'reinforce': '強化する'},
#  {'worldwide': '世界中の'},
#  {'empty': '空の'},
#  {'fundamental': '基本的な／必須の'},
#  {'heritage': '文化的遺産'},
#  {'sensitive': '敏感な'},
#  {'execute': '実行する'},
#  {'gradually': 'だんだんと'},
#  {'declare': '宣言する'},
#  {'beside': '…のそばに'},
#  {'struggle': '…しようと努力する'},
#  {'domestic': '国内の'},
#  {'duration': '期間'},
#  {'complicated': '複雑な'},
#  {'maintain': '維持する'},
#  {'origin': '起源'},
#  {'infrastructure': '社会基盤'},
#  {'dramatic': '劇的な'},
#  {'engagement': '約束／関与'},
#  {'calculate': '計算する'},
#  {'installment': '(分割払いの)支払い'},
#  {'population': '人口'},
#  {'manuscript': '原稿'},
#  {'imagine': '想像する'},
#  {'encounter': '直面する／経験する'},
#  {'milestone': '段階'},
#  {'concept': '概念／コンセプト'},
#  {'reimburse': '返済する'},
#  {'freelance': 'フリーランス'},
#  {'useful': '役に立つ'},
#  {'excessive': '過度の'},
#  {'absence': '欠席／欠如'},
#  {'reply': '返信／返事をする'},
#  {'shortage': '不足'},
#  {'scope': '範囲'},
#  {'landlord': '家主'},
#  {'background': '背景'},
#  {'bargain': 'バーゲン品／交渉する'},
#  {'invaluable': '貴重な'},
#  {'remote': '遠い'},
#  {'cite': '(理由や例を)挙げる'},
#  {'coincidence': '偶然の一致'},
#  {'rapid': '速い'},
#  {'feasible': '実行可能な'},
#  {'streamline': '(仕事を)合理化する'},
#  {'quota': '割当量／ノルマ'},
#  {'attribute': '…に原因があると考える'},
#  {'forthcoming': '今度の'},
#  {'overwhelming': '圧倒的な'},
#  {'adequate': '…するのに十分な'},
#  {'mandatory': '義務的な'},
#  {'redeem': '(現金に)換える'},
#  {'apprenticeship': '見習い期間'},
#  {'culinary': '食事の'},
#  {'applause': '拍手／賞賛'},
#  {'discard': '捨てる'},
#  {'overlook': '見落とす'},
#  {'proceeds': '売上高'},
#  {'aboard': '(船や飛行機に)乗って'},
#  {'adhere': '(忠実に)従う'},
#  {'commission': '手数料'},
#  {'specification': '仕様書'},
#  {'convince': '納得させる'},
#  {'specify': '明細に述べる'},
#  {'disclosure': '公開'},
#  {'projection': '予測／見通し'},
#  {'outlay': '出資金'},
#  {'prohibit': '禁止する'},
#  {'expedite': '促進する'},
#  {'mentor': '助言者'},
#  {'offset': '埋め合わせる'},
#  {'remodel': '改造する'},
#  {'nursery': '園芸店'},
#  {'resolve': '解決する'},
#  {'dismantle': '解体する'},
#  {'chronicle': '年代記'},
#  {'turnout': '出席者'},
#  {'bulk': '大部分'},
#  {'resume': '再開する'},
#  {'inlay': 'はめ込む'},
#  {'obstacle': '障害物'},
#  {'retrieve': '検索する'},
#  {'compliance': '法令遵守'},
#  {'undertake': '引き受ける'},
#  {'endeavor': '試み'},
#  {'unload': '荷物をおろす'},
#  {'adopt': '採用する'},
#  {'adapt': '適応させる'},
#  {'abandon': '捨てる'},
#  {'congestion': '混雑'},
#  {'prestigious': '一流の'},
#  {'acclaim': 'ほめたたえる'},
#  {'deliberate': '故意の'},
#  {'designate': '指名する'},
#  {'attest': '証明する'},
#  {'stroll': '散歩する'},
#  {'amend': '修正する'},
#  {'praise': '賞賛の言葉'},
#  {'nominate': '推薦する'},
#  {'retain': '保持する'},
#  {'slate': '予定する'},
#  {'novice': '初心者'},
#  {'alternative': '代案'},
#  {'admire': '感心する'},
#  {'gratitude': '感謝の気持ち'},
#  {'compile': '編集する'},
#  {'duplicate': '複製する'},
#  {'affiliate': '系列会社'},
#  {'tailor': '合わせて作る'},
#  {'aspire': '熱望する'},
#  {'tutor': '教師'},
#  {'alike': '同様に'},
#  {'compensate': '補う'},
#  {'periodic': '定期的な'},
#  {'disturb': '邪魔をする'},
#  {'candid': '率直な'},
#  {'anonymous': '匿名の'},
#  {'assure': '保証する'},
#  {'thoroughly': '徹底的に'},
#  {'imprint': '刻み込む'},
#  {'disrupt': '中断させる'},
#  {'afterward': 'その後で'},
#  {'originate': '生じる'},
#  {'versatile': '多目的な'},
#  {'bypass': '迂回路'},
#  {'awning': '日よけ'},
#  {'ample': '十分な'},
#  {'contrast': '差異／対比する'},
#  {'fragile': '壊れやすい'},
#  {'coin': '(新語を)造り出す'},
#  {'promptly': '遅延なく'},
#  {'unconventional': '型にはまらない'},
#  {'conditional': '条件付きの'},
#  {'accountable': '責任がある'},
#  {'landmark': '歴史的な建物'},
#  {'steep': '急な／大幅な'},
#  {'await': '待つ'},
#  {'intermittent': '断続的な'},
#  {'pursue': '追求する'},
#  {'exposition': '説明／展示会'},
#  {'cozy': '居心地の良い'},
#  {'overhaul': '改善'},
#  {'rundown': '手短な報告'},
#  {'roundup': '総括'},
#  {'neither': 'どちらも…でない'},
#  {'enclose': '同封する'}]

# %%
len(word_list)
# Out:
# 1000

# %%
url = "https://englishlevelup.net/toeic-word-list/"
res = requests.get(url)
soup = BeautifulSoup(res.content, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="ja"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport"/><meta content="BU3H5NCI3GmIy91M4GuANK5cl9X1OLD91SUd8Gm68wQ" name="google-site-verification"/><link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/><link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/><link href="//ajax.googleapis.com" rel="preconnect dns-prefetch"/><link href="//cdnjs.cloudflare.com" rel="preconnect dns-prefetch"/><link href="//pagead2.googlesyndication.com" rel="preconnect dns-prefetch"/><link href="//googleads.g.doubleclick.net" rel="preconnect dns-prefetch"/><link href="//tpc.googlesyndication.com" rel="preconnect dns-prefetch"/><link href="//ad.doubleclick.net" rel="preconnect dns-prefetch"/><link href="//www.gstatic.com" rel="preconnect dns-prefetch"/><link href="//cse.google.com" rel="preconnect dns-prefetch"/><link href="//fonts.gstatic.com" rel="preconnect dns-prefetch"/><link href="//fonts.googleapis.com" rel="preconnect dns-prefetch"/><link href="//cms.quantserve.com" rel="preconnect dns-prefetch"/><link href="//secure.gravatar.com" rel="preconnect dns-prefetch"/><link href="//cdn.syndication.twimg.com" rel="preconnect dns-prefetch"/><link href="//cdn.jsdelivr.net" rel="preconnect dns-prefetch"/><link href="//images-fe.ssl-images-amazon.com" rel="preconnect dns-prefetch"/><link href="//completion.amazon.com" rel="preconnect dns-prefetch"/><link href="//m.media-amazon.com" rel="preconnect dns-prefetch"/><link href="//i.moshimo.com" rel="preconnect dns-prefetch"/><link href="//aml.valuecommerce.com" rel="preconnect dns-prefetch"/><link href="//dalc.valuecommerce.com" rel="preconnect dns-prefetch"/><link href="//dalb.valuecommerce.com" rel="preconnect dns-prefetch"/><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-5RCQSJG');</script><title>TOEIC頻出単語一覧｜絶対に出る2000語！まずこれを覚えよう | 英語上達法の【英語バナナ】</title><meta content="article" property="og:type"/><meta content="TOEICにおいて単語は最初に乗り越えなくてはならないものです。語彙力をつけるとリスニング問題もリーディング問題も得点力が大幅に変わってきます。当サイト英語バナナでは過去の出題データからTOEICの頻出単語一覧としてTOEICによく出る単語" property="og:description"/><meta content="TOEIC頻出単語一覧｜絶対に出る2000語！まずこれを覚えよう" property="og:title"/><meta content="https://englishlevelup.net/toeic-word-list/" property="og:url"/><meta content="https://englishlevelup.net/wp-content/uploads/2019/10/toeic-tango-ichiran-eyecatch.jpg" property="og:image"/><meta content="英語上達法の【英語バナナ】" property="og:site_name"/><meta content="ja_JP" property="og:locale"/><meta content="2019-10-08T11:38:35+09:00" property="article:published_time"/><meta content="2020-06-17T14:57:28+09:00" property="article:modified_time"/><meta content="TOEIC勉強法" property="article:section"/><meta content="summary_large_image" name="twitter:card"/><meta content="TOEICにおいて単語は最初に乗り越えなくてはならないものです。語彙力をつけるとリスニング問題もリーディング問題も得点力が大幅に変わってきます。当サイト英語バナナでは過去の出題データからTOEICの頻出単語一覧としてTOEICによく出る単語" property="twitter:description"/><meta content="TOEIC頻出単語一覧｜絶対に出る2000語！まずこれを覚えよう" property="twitter:title"/><meta content="https://englishlevelup.net/toeic-word-list/" property="twitter:url"/><meta content="https://englishlevelup.net/wp-content/uploads/2019/10/toeic-tango-ichiran-eyecatch.jpg" name="twitter:image"/><meta content="englishlevelup.net" name="twitter:domain"/><link href="//webfonts.xserver.jp" rel="dns-prefetch"/><link href="//ajax.googleapis.com" rel="dns-prefetch"/><link href="//cdnjs.cloudflare.com" rel="dns-prefetch"/><link href="//polyfill.io" rel="dns-prefetch"/><link href="//www.google.com" rel="dns-prefetch"/><link href="//s.w.org" rel="dns-prefetch"/><link href="https://englishlevelup.net/feed/" rel="alternate" title="英語上達法の【英語バナナ】 » フィード" type="application/rss+xml"/><link href="https://englishlevelup.net/comments/feed/" rel="alternate" title="英語上達法の【英語バナナ】 » コメントフィード" type="application/rss+xml"/><script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js?ver=1.12.4"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-migrate/1.4.1/jquery-migrate.min.js?ver=1.4.1"></script><script src="//webfonts.xserver.jp/js/xserver.js?ver=1.2.1"></script><script src="https://polyfill.io/v3/polyfill.min.js?features=Array.prototype.findIndex%2CCustomEvent%2CElement.prototype.closest%2CElement.prototype.dataset%2CEvent%2CXMLHttpRequest%2CMutationObserver&amp;flags=gated&amp;ver=5.4.4"></script><script async="" defer="" src="https://www.google.com/recaptcha/api.js?hl=ja&amp;render=explicit&amp;ver=5.4.4"></script><link href="https://englishlevelup.net/?p=394" rel="shortlink"/><link href="https://englishlevelup.net/toeic-word-list/" rel="canonical"/><meta content="TOEICにおいて単語は最初に乗り越えなくてはならないものです。語彙力をつけるとリスニング問題もリーディング問題も得点力が大幅に変わってきます。当サイト英語バナナでは過去の出題データからTOEICの頻出単語一覧としてTOEICによく出る単語" name="description"/><meta content="TOEIC勉強法" name="keywords"/><meta content="https://englishlevelup.net/wp-content/uploads/2019/10/toeic-tango-ichiran-eyecatch.jpg" name="thumbnail"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"Article","mainEntityOfPage":{"@type":"WebPage","@id":"https://englishlevelup.net/toeic-word-list/"},"headline":"TOEIC頻出単語一覧｜絶対に出る2000語！まずこれを覚えよう","image":{"@type":"ImageObject","url":"https://englishlevelup.net/wp-content/uploads/2019/10/toeic-tango-ichiran-eyecatch.jpg","width":1055,"height":703},"datePublished":"2019-10-08T11:38:35+09:00","dateModified":"2020-06-17T14:57:28+09:00","author":{"@type":"Person","name":"松本 まなみ"},"publisher":{"@type":"Organization","name":"英語上達法の【英語バナナ】","logo":{"@type":"ImageObject","url":"https://englishlevelup.net/wp-content/themes/cocoon-master/images/no-amp-logo.png","width":206,"height":60}},"description":"TOEICにおいて単語は最初に乗り越えなくてはならないものです。語彙力をつけるとリスニング問題もリーディング問題も得点力が大幅に変わってきます。当サイト英語バナナでは過去の出題データからTOEICの頻出単語一覧としてTOEICによく出る単語…"}</script ...
# function loadWebFont(url){var webfont=url;var createLink=function(href){var link=document.createElement('link');link.rel='stylesheet';link.href=href;document.head.appendChild(link)};var raf=requestAnimationFrame||mozRequestAnimationFrame||webkitRequestAnimationFrame||msRequestAnimationFrame;if(raf){raf(function(){createLink(webfont)})}else{window.addEventListener('load',function(){createLink(webfont)})}}</script><script>loadWebFont("https://englishlevelup.net/wp-content/themes/cocoon-master/webfonts/fontawesome/css/font-awesome.min.css");loadWebFont("https://englishlevelup.net/wp-content/themes/cocoon-master/webfonts/icomoon/style.css");</script><script>(function(window,document){'use strict'; if('IntersectionObserver' in window&&'IntersectionObserverEntry' in window&&'intersectionRatio' in window.IntersectionObserverEntry.prototype){if(!('isIntersecting' in window.IntersectionObserverEntry.prototype)){Object.defineProperty(window.IntersectionObserverEntry.prototype,'isIntersecting',{get:function(){return this.intersectionRatio>0}})}return}var registry=[];function IntersectionObserverEntry(entry){this.time=entry.time;this.target=entry.target;this.rootBounds=entry.rootBounds;this.boundingClientRect=entry.boundingClientRect;this.intersectionRect=entry.intersectionRect||getEmptyRect();this.isIntersecting=!!entry.intersectionRect;var targetRect=this.boundingClientRect;var targetArea=targetRect.width*targetRect.height;var intersectionRect=this.intersectionRect;var intersectionArea=intersectionRect.width*intersectionRect.height;if(targetArea){this.intersectionRatio=Number((intersectionArea/targetArea).toFixed(4))}else{this.intersectionRatio=this.isIntersecting?1:0}}function IntersectionObserver(callback,opt_options){var options=opt_options||{};if(typeof callback!='function'){throw new Error('callback must be a function')}if(options.root&&options.root.nodeType!=1){throw new Error('root must be an Element')}this._checkForIntersections=throttle(this._checkForIntersections.bind(this),this.THROTTLE_TIMEOUT);this._callback=callback;this._observationTargets=[];this._queuedEntries=[];this._rootMarginValues=this._parseRootMargin(options.rootMargin);this.thresholds=this._initThresholds(options.threshold);this.root=options.root||null;this.rootMargin=this._rootMarginValues.map(function(margin){return margin.value+margin.unit}).join(' ')}IntersectionObserver.prototype.THROTTLE_TIMEOUT=100;IntersectionObserver.prototype.POLL_INTERVAL=null;IntersectionObserver.prototype.USE_MUTATION_OBSERVER=!0;IntersectionObserver.prototype.observe=function(target){var isTargetAlreadyObserved=this._observationTargets.some(function(item){return item.element==target});if(isTargetAlreadyObserved){return}if(!(target&&target.nodeType==1)){throw new Error('target must be an Element')}this._registerInstance();this._observationTargets.push({element:target,entry:null});this._monitorIntersections();this._checkForIntersections()};IntersectionObserver.prototype.unobserve=function(target){this._observationTargets=this._observationTargets.filter(function(item){return item.element!=target});if(!this._observationTargets.length){this._unmonitorIntersections();this._unregisterInstance()}};IntersectionObserver.prototype.disconnect=function(){this._observationTargets=[];this._unmonitorIntersections();this._unregisterInstance()};IntersectionObserver.prototype.takeRecords=function(){var records=this._queuedEntries.slice();this._queuedEntries=[];return records};IntersectionObserver.prototype._initThresholds=function(opt_threshold){var threshold=opt_threshold||[0];if(!Array.isArray(threshold))threshold=[threshold];return threshold.sort().filter(function(t,i,a){if(typeof t!='number'||isNaN(t)||t<0||t>1){throw new Error('threshold must be a number between 0 and 1 inclusively')}return t!==a[i-1]})};IntersectionObserver.prototype._parseRootMargin=function(opt_rootMargin){var marginString=opt_rootMargin||'0px';var margins=marginString.split(/\s+/).map(function(margin){var parts=/^(-?\d*\.?\d ...
# var cocoon_localize_script_options={"is_lazy_load_enable":"1","is_fixed_mobile_buttons_enable":"","is_google_font_lazy_load_enable":"1"};</script><script>(function($){var prevScrollTop=-1;var $window=$(window);$window.scroll(function(){var scrollTop=$window.scrollTop();var threashold=600;var s1=(prevScrollTop>threashold);var s2=(scrollTop>threashold);if(s1 ^ s2){if(s2){$('.go-to-top').fadeIn('slow')}else{$('.go-to-top').fadeOut('slow')}}prevScrollTop=scrollTop});$('.go-to-top-common').click(function(){$('body,html').animate({scrollTop:1},800)});$('.go-to-toc-common').click(function(){$('body,html').animate({scrollTop:$('.entry-content .toc').offset().top},800)});$('#search-menu-input').change(function(e){var searchEdit=$('#search-menu-content .search-edit').first();if(e.target.checked){searchEdit.focus()}else{searchEdit.blur()}});var adminMenu=$("#admin-panel");var adminHeight=adminMenu.outerHeight();var adminStartPos=0;$(window).scroll(function(){var adminCurrentPos=$(this).scrollTop();if(adminCurrentPos>adminStartPos){if(adminCurrentPos>=200){adminMenu.css("bottom","-"+adminHeight+"px")}}else{adminMenu.css("bottom",0)}adminStartPos=adminCurrentPos});if(cocoon_localize_script_options.is_fixed_mobile_buttons_enable!=1){var headerMenu=$('.mobile-header-menu-buttons');var headerHight=headerMenu.outerHeight();var headerStartPos=0;$(window).scroll(function(){var headerCurrentPos=$(this).scrollTop();if(headerCurrentPos>headerStartPos){if(headerCurrentPos>=100){headerMenu.css('top','-'+headerHight+'px')}}else{headerMenu.css('top',0)}headerStartPos=headerCurrentPos});var footerMenu=$(".mobile-footer-menu-buttons");var footerHeight=footerMenu.outerHeight();var footerStartPos=0;$(window).scroll(function(){var footerCurrentPos=$(this).scrollTop();if(footerCurrentPos>footerStartPos){if(footerCurrentPos>=100){footerMenu.css("bottom","-"+footerHeight+"px")}}else{footerMenu.css("bottom",0)}footerStartPos=footerCurrentPos});var headerButtons=$(".mobile-header-menu-buttons");var footerButtons=$(".mobile-footer-menu-buttons");headerButtons.click(function(){headerButtons.css("z-index","3");footerButtons.css("z-index","2")});footerButtons.click(function(){headerButtons.css("z-index","2");footerButtons.css("z-index","3")})}$('#comment-reply-btn, .comment-reply-link').click(function(){$('#comment-reply-btn').slideUp();$('#respond').slideDown()});$('.carousel').fadeIn(1000);$('.sbtn').click(function(){var w=$(this).prev('.sform').text();if(w)window.open('https://www.google.co.jp/search?q='+encodeURIComponent(w),'_blank')});$('.sidebar-menu-content .widget_archive select').change(function(){document.location.href=this.options[this.selectedIndex].value});$('.sidebar-menu-content .widget_categories select').change(function(){if(this.options[this.selectedIndex].value>0){this.parentNode.submit()}});function drawerCloser(selecter,checkbox){$(selecter).click(function(){href=$(this).attr('href');url=location.href;url=url.replace(/#.*$/,'');if((href.indexOf(url)!=-1)&&href.match(/#/)){$(checkbox).prop('checked',!1)}})}drawerCloser('.menu-drawer .menu-item a','#navi-menu-input');drawerCloser('#slide-in-sidebar a','#sidebar-menu-input');$('.mobile-menu-buttons').each(function(){if($(this).has('.logo-menu-button').length){$(this).addClass('has-logo-button')}})})(jQuery);(function(){var f=document.querySelectorAll(".video-click");for(var i=0;i<f.length;++i){f[i].onclick=function(){var iframe=this.getAttribute("data-iframe");this.parentElement.innerHTML='<div class="video"'+'>'+iframe+'</div'+'>'}}})();</script><script></script><script></script><script>
# var wpcf7={"apiSettings":{"root":"https:\/\/englishlevelup.net\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"}};</script><script>(function($){'use strict';if(typeof wpcf7==='undefined'||wpcf7===null){return}wpcf7=$.extend({cached:0,inputs:[]},wpcf7);$(function(){wpcf7.supportHtml5=(function(){var features={};var input=document.createElement('input');features.placeholder='placeholder' in input;var inputTypes=['email','url','tel','number','range','date'];$.each(inputTypes,function(index,value){input.setAttribute('type',value);features[value]=input.type!=='text'});return features})();$('div.wpcf7> form').each(function(){var $form=$(this);wpcf7.initForm($form);if(wpcf7.cached){wpcf7.refill($form)}})});wpcf7.getId=function(form){return parseInt($('input[name="_wpcf7"]',form).val(),10)};wpcf7.initForm=function(form){var $form=$(form);wpcf7.setStatus($form,'init');$form.submit(function(event){if(!wpcf7.supportHtml5.placeholder){$('[placeholder].placeheld',$form).each(function(i,n){$(n).val('').removeClass('placeheld')})}if(typeof window.FormData==='function'){wpcf7.submit($form);event.preventDefault()}});$('.wpcf7-submit',$form).after('<span class="ajax-loader"></span>');wpcf7.toggleSubmit($form);$form.on('click','.wpcf7-acceptance',function(){wpcf7.toggleSubmit($form)});$('.wpcf7-exclusive-checkbox',$form).on('click','input:checkbox',function(){var name=$(this).attr('name');$form.find('input:checkbox[name="'+name+'"]').not(this).prop('checked',!1)});$('.wpcf7-list-item.has-free-text',$form).each(function(){var $freetext=$(':input.wpcf7-free-text',this);var $wrap=$(this).closest('.wpcf7-form-control');if($(':checkbox, :radio',this).is(':checked')){$freetext.prop('disabled',!1)}else{$freetext.prop('disabled',!0)}$wrap.on('change',':checkbox, :radio',function(){var $cb=$('.has-free-text',$wrap).find(':checkbox, :radio');if($cb.is(':checked')){$freetext.prop('disabled',!1).focus()}else{$freetext.prop('disabled',!0)}})});if(!wpcf7.supportHtml5.placeholder){$('[placeholder]',$form).each(function(){$(this).val($(this).attr('placeholder'));$(this).addClass('placeheld');$(this).focus(function(){if($(this).hasClass('placeheld')){$(this).val('').removeClass('placeheld')}});$(this).blur(function(){if(''===$(this).val()){$(this).val($(this).attr('placeholder'));$(this).addClass('placeheld')}})})}if(wpcf7.jqueryUi&&!wpcf7.supportHtml5.date){$form.find('input.wpcf7-date[type="date"]').each(function(){$(this).datepicker({dateFormat:'yy-mm-dd',minDate:new Date($(this).attr('min')),maxDate:new Date($(this).attr('max'))})})}if(wpcf7.jqueryUi&&!wpcf7.supportHtml5.number){$form.find('input.wpcf7-number[type="number"]').each(function(){$(this).spinner({min:$(this).attr('min'),max:$(this).attr('max'),step:$(this).attr('step')})})}wpcf7.resetCounter($form);$form.on('change','.wpcf7-validates-as-url',function(){var val=$.trim($(this).val());if(val&&!val.match(/^[a-z][a-z0-9.+-]*:/i)&&-1!==val.indexOf('.')){val=val.replace(/^\/+/,'');val='http://'+val}$(this).val(val)})};wpcf7.submit=function(form){if(typeof window.FormData!=='function'){return}var $form=$(form);$('.ajax-loader',$form).addClass('is-active');wpcf7.clearResponse($form);var formData=new FormData($form.get(0));var detail={id:$form.closest('div.wpcf7').attr('id'),status:'init',inputs:[],formData:formData};$.each($form.serializeArray(),function(i,field){if('_wpcf7'==field.name){detail.contactFormId=field.value}else if('_wpcf7_version'==field.name){detail.pluginVersion=field.value}else if('_wpcf7_locale'==field.name){detail.contactFormLocale=field.value}else if('_wpcf7_unit_tag'==field.name){detail.unitTag=field.value}else if('_wpcf7_container_post'==field.name){detail.containerPostId=field.value}else if(field.name.match(/^_/)){}else{detail.inputs.push(field)}});wpcf7.triggerEvent($form.closest('div.wpcf7'),'beforesubmit',detail);var ajaxSuccess=function(data,status,xhr,$form){detail.id=$(data.into).attr('id');detail.status=data.status;detail.apiResponse=data;switch(data.status){cas ...
#     $(selector).click(function(event){
#       event.preventDefault();
#       var clipboard=new Clipboard(selector);clipboard.on('success',function(e){$('.copy-info').fadeIn(500).delay(1000).fadeOut(500);e.clearSelection()})})})(jQuery);</script></div></body></html>

# %%
tables = soup.find_all("table")
tables
# Out:
# [<table width="966"><tbody><tr><td width="141">pursue</td><td width="335">追及する、遂行する、続行する</td><td width="124">labor</td><td width="366">（肉体的な）労働</td></tr><tr><td>inform</td><td>知らせる、告げる、影響を与える</td><td>explain</td><td>説明する</td></tr><tr><td>anyway</td><td>とにかく</td><td>experiment</td><td>実験、試み／実験する</td></tr><tr><td>degree</td><td>（大学の）学位、程度</td><td>find out</td><td>発見する、気がつく</td></tr><tr><td>benefit</td><td>利益を得る／特典、福利厚生</td><td>payment</td><td>支払い</td></tr><tr><td>replace</td><td>~を取り替える</td><td>relatively</td><td>相対的に、比較的</td></tr><tr><td>infer</td><td>推察する、考える</td><td>recognize</td><td>認める、見分ける、認識する</td></tr><tr><td>following</td><td>~に続いて／次の、以下の</td><td>individual</td><td>個人の、個別の／個人</td></tr><tr><td>accomplish</td><td>成し遂げる、完遂する、達成する</td><td>contribute</td><td>貢献する、寄付する</td></tr><tr><td>reinforce</td><td>強化する</td><td>budget</td><td>予算／予算に計上する</td></tr><tr><td>demand</td><td>要求する、請求する</td><td>allow</td><td>許す、可能にする</td></tr><tr><td>refer</td><td>参照する、言及する、（人を）紹介する</td><td>demonstrate</td><td>実演する、明示する</td></tr><tr><td>booking</td><td>（ホテルや乗り物の）予約</td><td>exchange</td><td>交換する、両替する</td></tr><tr><td>assemble</td><td>組み立てる、集める</td><td>application</td><td>応募書類、応募、申請</td></tr><tr><td>despite</td><td>~にもかかわらず</td><td>survey</td><td>調査／~を調査する</td></tr><tr><td>cause</td><td>引き起こす、もたらす／原因</td><td>obey</td><td>従う</td></tr><tr><td>available</td><td>入手できる、利用できる、購入できる、</td><td>reward</td><td>報いる、ほうびを与える／報酬、ほうび</td></tr><tr><td>commercial</td><td>商業の、商業的な</td><td>prefer</td><td>~の方を好む</td></tr><tr><td>occupy</td><td>占有する</td><td>contract</td><td>契約、契約書</td></tr><tr><td>compare</td><td>比較する、比べる、例える</td><td>agency</td><td>代理店、取扱店、機関</td></tr><tr><td>inquire</td><td>尋ねる、問い合わせる</td><td>double</td><td>2倍になる、倍増する</td></tr><tr><td>department</td><td>部門、売り場</td><td>release</td><td>発表する、発売する</td></tr><tr><td>describe</td><td>説明する、描写する</td><td>management</td><td>経営（陣）、管理</td></tr><tr><td>a couple of ~</td><td>２、３の</td><td>financial</td><td>金銭上の、財政の、お金の</td></tr><tr><td>remove</td><td>取り除く</td><td>relax</td><td>ゆるめる、和らげる</td></tr><tr><td>conference</td><td>会議、学会</td><td>profitable</td><td>もうかる、利益になる</td></tr><tr><td>decision</td><td>決定、決定事項</td><td>hire</td><td>~を雇う、賃借りする</td></tr><tr><td>introduce</td><td>紹介する、導入する</td><td>performance</td><td>業績、仕事ぶり、性能、公演</td></tr><tr><td>reject</td><td>却下する、拒否する</td><td>charge</td><td>を請求する、を充電する／料金、責任</td></tr><tr><td>destroy</td><td>破壊する</td><td>graduate</td><td>卒業する</td></tr><tr><td>according to</td><td>~によると、~に従って</td><td>reschedule</td><td>予定を変更する</td></tr><tr><td>income</td><td>収入、収益</td><td>postpone</td><td>延期する</td></tr><tr><td>empty</td><td>空にする</td><td>pleased</td><td>喜んで、満足して</td></tr><tr><td>entertain</td><td>もてなす、楽しませる</td><td>argue</td><td>議論する、口論する</td></tr><tr><td>likely</td><td>おそらく／~しそうだ</td><td>lead</td><td>~を導く</td></tr><tr><td>establish</td><td>~を設立する、制定する</td><td>document</td><td>記録する、文書を提供する／文書</td></tr><tr><td>star</td><td>主演する、呼び物にする</td><td>confirm</td><td>確認する</td></tr><tr><td>secure</td><td>~を確保する、固定する／安全な</td><td>illustrate</td><td>説明する、図解する</td></tr><tr><td>state</td><td>述べる、言う</td><td>recommend</td><td>推薦する</td></tr><tr><td>equipment</td><td>機器、装備</td><td>award</td><td>賞／授与する</td></tr><tr><td>basis</td><td>ベース、基準、根拠</td><td>examine</td><td>詳しく調べる、吟味する</td></tr><tr><td>suffer</td><td>被る、受ける</td><td>propose</td><td>提案する、申し出る</td></tr><tr><td>environmental</td><td>環境の</td><td>clothing</td><td>衣類</td></tr><tr><td>apologize</td><td>おわびをする、謝罪する</td><td>pick up</td><td>~を車で拾う、迎えに行く、受け取る</td></tr><tr><td>provide</td><td>提供する</td><td>carry</td><td>扱う、運ぶ、所有する</td></tr><tr><td>browse</td><td>見て回る、拾い読みする</td><td>display</td><td>展示／展示する</td></tr><tr><td>tradition</td><td>伝統、しきたり</td><td>conduct</td><td>~を行う、導く、実行する、実施する</td></tr><tr><td>satisfy</td><td>満足させる</td><td>represent</td><td>代表する</td></tr><tr><td>local</td><td>地元の／地元の人</td><td>candidate</td><td>候補者</td></tr><tr><td>facility</td><td>施設、設備</td><td>exclude</td><td>~を除く、排除する</td></tr><tr><td>take part in</td><td>参加する、出場する</td><td>possess</td>< ...
#  <table width="966"><tbody><tr><td width="141">introduction</td><td width="335">（人の）紹介、（物の）導入</td><td width="124">status</td><td width="366">状況、地位</td></tr><tr><td>face</td><td>（~の方を）向く、直面する</td><td>fuel</td><td>燃料</td></tr><tr><td>skill</td><td>技能、スキル</td><td>nearly</td><td>ほとんど、もう少しで</td></tr><tr><td>compliment</td><td>賛辞を述べる、ほめる</td><td>cafeteria</td><td>社員食堂</td></tr><tr><td>convention</td><td>総会、大会</td><td>determine</td><td>決定する、判断する、決心する</td></tr><tr><td>bear</td><td>持つ</td><td>crew</td><td>乗務員、乗組員</td></tr><tr><td>temporarily</td><td>一時的に</td><td>raise</td><td>を引き上げる、を持ち上げる</td></tr><tr><td>preserve</td><td>保護する、保存する</td><td>finally</td><td>ついに、最終的に</td></tr><tr><td>forward</td><td>転送する、進める</td><td>because of ~</td><td>~のせいで、~のおかげで</td></tr><tr><td>enough</td><td>十分な／十分に</td><td>important</td><td>重要な、重大な</td></tr><tr><td>vary</td><td>変わる</td><td>suitable</td><td>適した、ふさわしい</td></tr><tr><td>admission</td><td>入場、入場料、入場許可</td><td>qualified</td><td>資格条件を満たした</td></tr><tr><td>prohibit</td><td>禁じる</td><td>coordinate</td><td>（複数の人や物）をまとめる、調整する</td></tr><tr><td>distribution</td><td>流通、配布、分配</td><td>medical</td><td>医療の</td></tr><tr><td>affect</td><td>影響する、作用する</td><td>boost</td><td>~を強化する、増加させる</td></tr><tr><td>take care of ~</td><td>~の世話をする</td><td>gain</td><td>~を得る、獲得する／利益、得ること</td></tr><tr><td>account</td><td>占める、説明する／口座・説明</td><td>constructive</td><td>建設的な、前向きな</td></tr><tr><td>look up</td><td>調べる</td><td>resolve</td><td>解決する</td></tr><tr><td>reimburse</td><td>（払ったお金）を払い戻す</td><td>reason</td><td>理由、動機</td></tr><tr><td>involve</td><td>（人を）巻き込む、伴う、含む</td><td>export</td><td>輸出／~を輸出する</td></tr><tr><td>except</td><td>~を除いて、~を除外して</td><td>attempt</td><td>試み／~を試みる</td></tr><tr><td>finance</td><td>資金を調達する、融資する</td><td>alternative</td><td>代わりの／代案、選択肢</td></tr><tr><td>defend</td><td>~を（攻撃から）守る、（~を）防御する</td><td>consumer</td><td>消費者</td></tr><tr><td>rely on</td><td>~に依存する、頼る</td><td>implication</td><td>影響、暗示、言葉の意味合い</td></tr><tr><td>proportion</td><td>比例、（~に対する）割合、比率</td><td>inovolve</td><td>~を伴う、（人）を巻き込む</td></tr><tr><td>expand</td><td>拡大する</td><td>grant</td><td>（権利など）を与える／助成金</td></tr><tr><td>predict</td><td>予測する</td><td>tip</td><td>アドバイス、秘訣</td></tr><tr><td>alter</td><td>変更する、作り変える</td><td>operation</td><td>操作、運転、事業</td></tr><tr><td>proof</td><td>証拠、証明</td><td>figure</td><td>数字、人物</td></tr><tr><td>seek</td><td>捜し求める</td><td>enthusiasm</td><td>熱中、熱狂</td></tr><tr><td>seriously</td><td>まじめに、深刻に</td><td>imply</td><td>ほのめかす、暗示する</td></tr><tr><td>accompany</td><td>添付する、同行する</td><td>general</td><td>全般的な、一般的な</td></tr><tr><td>vehicle</td><td>乗り物、車両</td><td>settle</td><td>解決する</td></tr><tr><td>stimulate</td><td>刺激する</td><td>correspondence</td><td>（文書などの）やりとり、通信</td></tr><tr><td>found</td><td>設立する、創立する</td><td>point out</td><td>指摘する</td></tr><tr><td>reference</td><td>照会先、照会、参照</td><td>possibility</td><td>可能性</td></tr><tr><td>fill out</td><td>記入する</td><td>convince</td><td>確信させる、納得させる</td></tr><tr><td>determination</td><td>決意すること、決断力の強さ</td><td>inspect</td><td>検査する、点検する</td></tr><tr><td>regret</td><td>残念に思う、悔いる</td><td>discussion</td><td>議論、話し合い</td></tr><tr><td>acquisition</td><td>（企業の）買収、獲得</td><td>adopt</td><td>採用する、導入する</td></tr><tr><td>draw</td><td>引く、描く</td><td>retailer</td><td>小売業者</td></tr><tr><td>break</td><td>休憩、中断、破壊／~を壊す</td><td>book</td><td>予約する</td></tr><tr><td>address</td><td>話す、対処する</td><td>satisfaction</td><td>満足</td></tr><tr><td>last</td><td>続く、待つ</td><td>bring up</td><td>持ち出す、提起する、育てる</td></tr><tr><td>restrict</td><td>~を制限する</td><td>summary</td><td>あらすじ、要約</td></tr><tr><td>develop</td><td>開発する、発達する</td><td>hang</td><td>掛かる</td></tr><tr><td>expectation</td><td>期待、予想</td><td>intend</td><td>意図する</td></tr><tr><td>locate</td><td>所在を探し当てる</td><td>role</td><td>（人の）役割</td></tr><tr><td>decade</td><td>10年、10年間</td><td>match</td><td>調和する、似合う</td></tr><tr><td>prepare</td><td>準備する</td><td>pharmaceutical</td><td>製薬の、調剤の</td></tr><tr><td>interest</td><td>利子、興味／（人）に興味を持たせる</td><td>post</td><td>提示する、投稿する</td></tr><tr><td>spread</td><td>広げる、掛ける< ...
#  <table width="966"><tbody><tr><td width="141">arrival</td><td width="335">到着</td><td width="124">component</td><td width="366">部品</td></tr><tr><td>familiar</td><td>よく知っている、おなじみの</td><td>enjoyable</td><td>楽しい</td></tr><tr><td>ideal</td><td>理想的な</td><td>existing</td><td>従来の、既存の</td></tr><tr><td>landscaping</td><td>造園</td><td>alike</td><td>同様に／よく似た</td></tr><tr><td>occasion</td><td>特別な行事、（何かが起こる）時、好機</td><td>connection</td><td>接続、つながり、関連、乗り継ぎ</td></tr><tr><td>standard</td><td>基準／標準の</td><td>eager</td><td>~したがる、熱望する</td></tr><tr><td>background</td><td>経歴、背景</td><td>fairly</td><td>かなり</td></tr><tr><td>guided</td><td>ガイド付きの</td><td>absolutely</td><td>完全に、間違いなく、まったく</td></tr><tr><td>advanced</td><td>進んだ、上級の、高度な</td><td>atmosphere</td><td>雰囲気</td></tr><tr><td>confident</td><td>確信している、自信がある</td><td>calculate</td><td>計算する</td></tr><tr><td>initial</td><td>初めの、当初の</td><td>contrast</td><td>対照、はっきりした違い／対照的である</td></tr><tr><td>separate</td><td>分かれた、別々の／分ける</td><td>monitor</td><td>監視する／（コンピュータの）モニター</td></tr><tr><td>environment</td><td>環境</td><td>occasionally</td><td>時々</td></tr><tr><td>various</td><td>さまざまな</td><td>serious</td><td>重大な、真剣な、重要な</td></tr><tr><td>brief</td><td>短い、短時間の</td><td>strength</td><td>強さ、強度、（液体等の）重さ</td></tr><tr><td>full-time</td><td>常勤の</td><td>equally</td><td>同じように、均等に</td></tr><tr><td>overall</td><td>全体の／全体として</td><td>informal</td><td>非公式の、カジュアルな</td></tr><tr><td>complex</td><td>複合施設、集合住宅／複雑な</td><td>renowned</td><td>名高い、著名な</td></tr><tr><td>delighted</td><td>とても喜んでいる</td><td>depend on ~</td><td>~次第である、~に頼る</td></tr><tr><td>honor</td><td>称える、（契約等を）守る／名誉</td><td>sudden</td><td>急な、突然の</td></tr><tr><td>properly</td><td>ちゃんと、適切に</td><td>look forward to ~</td><td>~を楽しみにする</td></tr><tr><td>electronic</td><td>電子の、電子的な</td><td>request</td><td>依頼／~を依頼する</td></tr><tr><td>preparation</td><td>準備、用意</td><td>access</td><td>~にアクセスする／アクセス</td></tr><tr><td>duty</td><td>任務、職務、関税</td><td>typical</td><td>典型的な</td></tr><tr><td>willing</td><td>~することを嫌がらない、~する気がある</td><td>security</td><td>安全、無事</td></tr><tr><td>worth</td><td>価値がある</td><td>exception</td><td>例外</td></tr><tr><td>overnight</td><td>一晩の、翌日配送の／一晩</td><td>acceptable</td><td>許容の、受け入れることのできる</td></tr><tr><td>particularly</td><td>特に</td><td>in advance</td><td>事前に</td></tr><tr><td>aspect</td><td>面、局面</td><td>own</td><td>~を所有する／自分の</td></tr><tr><td>involved</td><td>関わった</td><td>worldwide</td><td>世界的な／世界中で</td></tr><tr><td>scholarship</td><td>奨学金</td><td>economical</td><td>経済的な、節約の</td></tr><tr><td>shortly</td><td>じきに、まもなく</td><td>case</td><td>状況、場合</td></tr><tr><td>automobile</td><td>自動車の／自動車</td><td>favorite</td><td>お気に入りの、大好きな</td></tr><tr><td>certainly</td><td>確かに</td><td>staff</td><td>スタッフ</td></tr><tr><td>possibly</td><td>ひょっとすると、もしかすると</td><td>judge</td><td>判断する、裁く、評価する／裁判官</td></tr><tr><td>sufficient</td><td>十分な、満足な</td><td>market</td><td>市場／~を市場で売る</td></tr><tr><td>practical</td><td>実用的な、実践的な</td><td>rise</td><td>増える、上昇する</td></tr><tr><td>sales representaive</td><td>販売員、営業担当者</td><td>concern</td><td>心配事、懸念事項</td></tr><tr><td>medication</td><td>薬、医薬</td><td>salary</td><td>給料</td></tr><tr><td>fulfill</td><td>満たす、果たす</td><td>in the event of ~</td><td>万一~の場合には</td></tr><tr><td>reflection</td><td>熟考、反射</td><td>weigh</td><td>~の重さを量る、~の重さがある</td></tr><tr><td>foundation</td><td>土台、基礎</td><td>development</td><td>開発、発達、発展</td></tr><tr><td>governor</td><td>知事</td><td>quite</td><td>かなり、すっかり</td></tr><tr><td>practice</td><td>習わし、開業、実施</td><td>strict</td><td>（人や規制が）厳しい</td></tr><tr><td>responsibility</td><td>（人や物に対する）責任</td><td>contemporary</td><td>現代の、同時代の</td></tr><tr><td>impressive</td><td>印象的な、素晴らしい</td><td>complimentary</td><td>無料の、称賛する</td></tr><tr><td>coworker</td><td>（仕事の）同僚</td><td>defeat</td><td>（敵）を負かす／敗北、負け</td></tr><tr><td>excessive</td><td>過度の、度を越えた</td><td>establishment</td><td>設立（制定）すること、組織</td></tr><tr><td>favorable</td><td>好都合の、好意的な</td><td>similar</td><td>類似した</td></tr><tr><td>label</td><td>~にラベル［レッテル］を貼る／ラベル</td><td>extra</td><td>余分の、特別の、追加の</td></tr><tr><td>assess</td><t ...
#  <table width="966"><tbody><tr><td width="141">evidence</td><td width="335">証拠、証明</td><td width="124">lean over ~</td><td width="366">~に身を乗り出す</td></tr><tr><td>border</td><td>境、境界線</td><td>element</td><td>（~を構成する）要素、成分</td></tr><tr><td>portrait</td><td>肖像画</td><td>library</td><td>図書館、蔵書、コレクション</td></tr><tr><td>defect</td><td>欠陥、欠点</td><td>unload</td><td>（荷物など）を降ろす</td></tr><tr><td>intersection</td><td>交差点</td><td>minimize</td><td>~を最小限にする</td></tr><tr><td>bulletin</td><td>掲示、公報</td><td>failure</td><td>失敗、故障</td></tr><tr><td>caution</td><td>注意、警告</td><td>multiple</td><td>複数の</td></tr><tr><td>goods</td><td>商品</td><td>optimistic</td><td>楽観的な</td></tr><tr><td>exam</td><td>試験</td><td>revenue</td><td>収支、歳入</td></tr><tr><td>mission</td><td>使命、任務</td><td>recent</td><td>最近の</td></tr><tr><td>participant</td><td>参加者、関係者</td><td>suppose</td><td>（~を真実だと）思う</td></tr><tr><td>aim</td><td>目標、狙い／目指す、狙う</td><td>plumbing</td><td>配管（工事）</td></tr><tr><td>wage</td><td>賃金、給料</td><td>comprehensive</td><td>総合的な、包括的な、理解力のある</td></tr><tr><td>investigation</td><td>調査</td><td>purpose</td><td>目的、目標</td></tr><tr><td>feature</td><td>特集、特徴</td><td>actual</td><td>実際の、現実の</td></tr><tr><td>takeoff</td><td>離陸、出発</td><td>employment</td><td>雇用</td></tr><tr><td>statement</td><td>明細書、声明</td><td>upset</td><td>動揺した／~を動揺させる</td></tr><tr><td>field</td><td>分野、競技場</td><td>advantage</td><td>有利、利点、強み</td></tr><tr><td>audience</td><td>聴衆、観客</td><td>product</td><td>製品、生産物</td></tr><tr><td>adjustment</td><td>調整、調節</td><td>theme</td><td>テーマ、論題</td></tr><tr><td>lighthouse</td><td>灯台</td><td>summarize</td><td>要約する</td></tr><tr><td>remark</td><td>言葉、コメント、意見</td><td>slight</td><td>ほんのわずかの</td></tr><tr><td>fountain</td><td>噴水</td><td>enroll</td><td>登録する、入会する、入学する</td></tr><tr><td>improvement</td><td>改善、向上</td><td>routine</td><td>所定の、日常的に行われる</td></tr><tr><td>shelf</td><td>棚</td><td>oppointment</td><td>会う約束、アポイントメント</td></tr><tr><td>item</td><td>項目、品物</td><td>mortgage</td><td>抵当／~を抵当に入れる</td></tr><tr><td>couple</td><td>二つ、一対</td><td>outstanding</td><td>傑出した、未払いの</td></tr><tr><td>reception</td><td>歓迎会、パーティー、受領</td><td>certain</td><td>特定の、確かで</td></tr><tr><td>commuter</td><td>通勤者</td><td>solid</td><td>固い、堅実な、まじめな</td></tr><tr><td>recession</td><td>後退</td><td>deserted</td><td>人の気配がない、さびれた</td></tr><tr><td>sealed</td><td>密封された</td><td>current</td><td>現在の</td></tr><tr><td>acting</td><td>代理の、事実上の</td><td>culinary</td><td>料理の</td></tr><tr><td>primary</td><td>主な、本来の</td><td>dominant</td><td>支配的な、圧倒的な、主要な</td></tr><tr><td>independent</td><td>独立した、自主性のある</td><td>viable</td><td>実行可能な</td></tr><tr><td>capable</td><td>能力がある、~できる</td><td>attractive</td><td>魅力的な</td></tr><tr><td>satisfactory</td><td>満足な</td><td>determined</td><td>断固とした、決定した</td></tr><tr><td>physical</td><td>身体的な、物質的な</td><td>principal</td><td>主な、第一の</td></tr><tr><td>domestic</td><td>国内の</td><td>mobile</td><td>移動式の</td></tr><tr><td>functional</td><td>機能的な、実用的な</td><td>round-trip</td><td>往復旅行の</td></tr><tr><td>rewarding</td><td>やりがいのある、実りの多い</td><td>tight</td><td>きつい、ぎっしり詰まった</td></tr><tr><td>out of order</td><td>故障して</td><td>nearby</td><td>近くの</td></tr><tr><td>whole</td><td>全体の</td><td>respectful</td><td>礼儀正しい、丁寧な</td></tr><tr><td>protective</td><td>保護用の</td><td>another</td><td>もう一つの、別の</td></tr><tr><td>seated</td><td>座った、座らせられた</td><td>abroad</td><td>海外で、国外へ</td></tr><tr><td>athletic</td><td>運動好きな、運動選手用の</td><td>greatly</td><td>大いに、非常に</td></tr><tr><td>price</td><td>価格、値段／~に値段をつける</td><td>on average</td><td>平均して</td></tr><tr><td>schedule</td><td>~を予定する／予定、スケジュール</td><td>accordingly</td><td>したがって、それに応じて</td></tr><tr><td>trustworthy</td><td>信頼できる、信用できる</td><td>promptly</td><td>すばやく、きっかりに、即座に</td></tr><tr><td>superior</td><td>優れた、上等の</td><td>consistently</td><td>常に、変わらず</td></tr><tr><td>registration</td><td>登録、記名</td><td>otherwise</td><td>さもなければ</td></tr><tr><td>specification</td><td>仕様書</td><td>proudly</td><td>誇らしげに、堂々と</td></tr><tr><td>rejection</td><td>拒絶、断ること</td><td>formally</td><td>正式に、フォーマルに</td></tr><tr><td>preference</td><td>好み ...
#  <table width="966"><tbody><tr><td width="141">familiarize</td><td width="335">慣らす、習熟させる</td><td width="124">tailor</td><td width="366">仕立屋、テーラー</td></tr><tr><td>outfit</td><td>装備する</td><td>coverage</td><td>報道、（保険の）補償</td></tr><tr><td>catering</td><td>仕出し、出前、ケータリング</td><td>flaw</td><td>欠陥、欠点</td></tr><tr><td>serve as</td><td>~としての機能を果たす</td><td>prescription</td><td>処方箋</td></tr><tr><td>stem</td><td>起因する</td><td>poll</td><td>世論調査、投票</td></tr><tr><td>neglect</td><td>~を怠る、放置する</td><td>refreshment</td><td>軽い飲食物</td></tr><tr><td>wildlife</td><td>野生動物</td><td>witness</td><td>目撃者</td></tr><tr><td>inclined to</td><td>~する傾向がある</td><td>timepiece</td><td>時計</td></tr><tr><td>put off</td><td>延期する</td><td>invantory</td><td>在庫、在庫品、棚卸</td></tr><tr><td>precede</td><td>先行する</td><td>reliable</td><td>信頼できる、頼りになる</td></tr><tr><td>assign</td><td>割り当てる、任命する</td><td>remedy</td><td>改善策、治療薬</td></tr><tr><td>specify</td><td>明記する</td><td>commerce</td><td>商業</td></tr><tr><td>complement</td><td>合う、補完する</td><td>pillar</td><td>柱、大黒柱</td></tr><tr><td>enforce</td><td>施行する、実行する</td><td>carrier</td><td>運輸業者</td></tr><tr><td>banquet</td><td>夕食会、宴会</td><td>identification</td><td>身分証明</td></tr><tr><td>rinse</td><td>すすぐ</td><td>collaboration</td><td>協力、共同制作</td></tr><tr><td>audit</td><td>会計監査する</td><td>physician</td><td>医者</td></tr><tr><td>keep up with</td><td>遅れないようについていく</td><td>conservation</td><td>保護、保存</td></tr><tr><td>valid</td><td>有効な</td><td>voucher</td><td>引換券、割引券</td></tr><tr><td>upgrade</td><td>品質（性能）を良くする／改良</td><td>carpenter</td><td>大工</td></tr><tr><td>capture</td><td>記録する、捉える</td><td>textile</td><td>織物</td></tr><tr><td>fasten</td><td>結ぶ、留める</td><td>mechanic</td><td>機械工</td></tr><tr><td>certificate</td><td>認定証、修了証</td><td>legislation</td><td>法律、法律制定</td></tr><tr><td>consume</td><td>消費する</td><td>measurement</td><td>寸法、測定</td></tr><tr><td>integrate</td><td>統合する</td><td>fund-raising</td><td>資金調達のための、慈善の</td></tr><tr><td>admit</td><td>~を認める、入院させる</td><td>accomplished</td><td>熟達した、スキルの高い</td></tr><tr><td>orientation</td><td>新入社員向け説明会</td><td>critic</td><td>評論家、批評家</td></tr><tr><td>house</td><td>収容する</td><td>highlight</td><td>強調する、スポットを当てる／見どころ</td></tr><tr><td>compensate</td><td>補償する</td><td>cleaner’s</td><td>クリーニング屋</td></tr><tr><td>remodel</td><td>改築する</td><td>profile</td><td>人物紹介する／プロフィール</td></tr><tr><td>ingredient</td><td>（料理の）材料</td><td>precision</td><td>正確さ</td></tr><tr><td>attend to</td><td>対応する</td><td>archive</td><td>公文書保管所、書庫</td></tr><tr><td>drop off</td><td>~を（車から）降ろす</td><td>utensil</td><td>台所用品</td></tr><tr><td>look into</td><td>吟味する、詳しく調べる</td><td>subscription</td><td>定期購読</td></tr><tr><td>storage</td><td>保管、貯蔵</td><td>counterpart</td><td>相当する人（物）</td></tr><tr><td>commend</td><td>ほめる</td><td>incident</td><td>偶然の出来事</td></tr><tr><td>commence</td><td>始まる</td><td>stapler</td><td>ホチキス</td></tr><tr><td>redeen</td><td>~を回復する、取り戻す、~を現金に換える</td><td>surrounding</td><td>周辺の</td></tr><tr><td>beverage</td><td>飲料</td><td>conclusion</td><td>結論</td></tr><tr><td>acquire</td><td>買収する、得る、獲得する</td><td>outcome</td><td>結果</td></tr><tr><td>mount</td><td>取り付ける、登る</td><td>perspective</td><td>視点</td></tr><tr><td>execute</td><td>実行する</td><td>anticipated</td><td>待ち望まれた</td></tr><tr><td>prior</td><td>前の</td><td>assessment</td><td>評価、見積もり</td></tr><tr><td>dissolve</td><td>溶ける</td><td>aircraft</td><td>航空機</td></tr><tr><td>consult</td><td>相談する</td><td>advocate</td><td>提唱者、支持者／提唱する</td></tr><tr><td>escort</td><td>付き添う、送り届ける</td><td>dairy</td><td>乳製品、酪農場、酪農業／牛乳の、乳製品の</td></tr><tr><td>merger</td><td>合併、統合</td><td>librarian</td><td>図書館員</td></tr><tr><td>cite</td><td>引用する、引き合いに出す、言及する</td><td>principle</td><td>原理、原則</td></tr><tr><td>screen</td><td>選別する</td><td>trademark</td><td>商標</td></tr><tr><td>inherit</td><td>引き継ぐ</td><td>phase</td><td>段階</td></tr><tr><td>inn</td><td>宿、ホテル</td><td>limitation</td><td>弱点</td></tr><tr><td>engage</td><td>参加する、従事する</td><td>custodian</td><td>管理人、守衛</td></tr><tr><td>specialize</td><td>専門にする</td><td>transit</td><td>輸送、通過</td></tr><tr><td>acknowledg ...
#  <table width="966"><tbody><tr><td width="141">politician</td><td width="335">政治家</td><td width="124">to date</td><td width="366">今まで</td></tr><tr><td>afterwards</td><td>その後で</td><td>moderate</td><td>ほどほどの、適度な</td></tr><tr><td>wholesale</td><td>卸売りの</td><td>exceptionally</td><td>並外れて、非常に</td></tr><tr><td>inclusive</td><td>すべてを含んだ、含めて</td><td>repeatedly</td><td>繰り返し</td></tr><tr><td>generally</td><td>おおむね、通常、一般的に</td><td>after all</td><td>結局</td></tr><tr><td>regional</td><td>地域の</td><td>precisely</td><td>正確に</td></tr><tr><td>subsequent</td><td>それに続く</td><td>prominently</td><td>目立って、傑出して</td></tr><tr><td>costly</td><td>費用のかかる、高価な</td><td>reportedly</td><td>伝えられるところでは</td></tr><tr><td>occupied</td><td>（部屋、座席、ベッド等が）使われている</td><td>on commission</td><td>歩合制で</td></tr><tr><td>knowledgeable</td><td>知識豊富な</td><td>concentrated</td><td>集中的な、濃縮された</td></tr><tr><td>confidential</td><td>機密の、秘密の</td><td>on track</td><td>軌道に乗って</td></tr><tr><td>in question</td><td>問題になっている</td><td>informally</td><td>くだけて、非公式に</td></tr><tr><td>circumstance</td><td>状況</td><td>intentionally</td><td>意図的に</td></tr><tr><td>abundant</td><td>豊富な、十分な</td><td>ample</td><td>十分な、あり余るほどの</td></tr><tr><td>considerate</td><td>思いやりがある、理解がある</td><td>roughly</td><td>おおよそ</td></tr><tr><td>splendid</td><td>素晴らしい</td><td>swiftly</td><td>すばやく、迅速に</td></tr><tr><td>panel</td><td>グループ、パネル</td><td>consequently</td><td>結果として</td></tr><tr><td>doubtful</td><td>疑わしい</td><td>given</td><td>~を考慮すると、~と仮定すると</td></tr><tr><td>proficient</td><td>堪能な、熟達した</td><td>courtesy of</td><td>~の好意により</td></tr><tr><td>noticeable</td><td>容易に気付く</td><td>whereas</td><td>~の一方で</td></tr><tr><td>portion</td><td>部分、一人分の食事</td><td>controversial</td><td>議論を引き起こす、議論の的になる</td></tr><tr><td>prospective</td><td>見込みのある、将来の</td><td>instrumental</td><td>重要な役割を果たす</td></tr><tr><td>last-minute</td><td>間際での</td><td>scope</td><td>範囲、余地</td></tr><tr><td>immense</td><td>非常に大きな、巨大な</td><td>speculation</td><td>推測、推量</td></tr><tr><td>commonly</td><td>一般に、通常、ふつうに</td><td>supplement</td><td>補う／付録、付記、栄養補助食品</td></tr><tr><td>agreeable</td><td>快適な、心地良い</td><td>understaffed</td><td>人手不足の</td></tr><tr><td>evident</td><td>明らかな</td><td>rarely</td><td>めったに~しない、まれに</td></tr><tr><td>prsuasive</td><td>説得力のある</td><td>logical</td><td>妥当な、論理的な、筋の通った</td></tr><tr><td>securely</td><td>しっかりと、安全に</td><td>lumber</td><td>材木、製材</td></tr><tr><td>noted</td><td>有名な</td><td>commemorate</td><td>祝う、記念する</td></tr><tr><td>unpredictable</td><td>予測できない、法外な</td><td>voluntary</td><td>自主的な、任意の</td></tr><tr><td>conscious</td><td>意識している、自覚している</td><td>deprive</td><td>奪う</td></tr><tr><td>timeline</td><td>予定表</td><td>dismiss</td><td>解雇する</td></tr><tr><td>demanding</td><td>要求の厳しい</td><td>rafting</td><td>（いかだやゴムボートでの）川下り</td></tr><tr><td>simultaneous</td><td>同時に起こる</td><td>consolidate</td><td>統合する</td></tr><tr><td>tidy</td><td>きちんとした、整頓された</td><td>fabric</td><td>生地、織物</td></tr><tr><td>diverse</td><td>多種多様な、たくさんの種類の</td><td>syndicate</td><td>複数の新聞に同時に配給する</td></tr><tr><td>outdated</td><td>時代遅れの</td><td>revert</td><td>戻る</td></tr><tr><td>pilot</td><td>試験的な</td><td>showcase</td><td>披露する／お披露目の場、ショーケース</td></tr><tr><td>beneficial</td><td>有益な</td><td>oversee</td><td>監督する</td></tr><tr><td>essential</td><td>最も重要な、必要不可欠な、本質的な</td><td>freight</td><td>貨物、輸送、輸送料／輸送する</td></tr><tr><td>aggressive</td><td>攻撃的な、積極的な</td><td>accommodate</td><td>満たす、合わせる</td></tr><tr><td>majority</td><td>大多数、大部分</td><td>endorse</td><td>支持する</td></tr><tr><td>adjacent</td><td>~に隣接した</td><td>discontinued</td><td>（製造・販売が）終了した</td></tr><tr><td>joint</td><td>合併の、共同の</td><td>pertain</td><td>該当する</td></tr><tr><td>prestigious</td><td>権威のある、誉れ高い</td><td>mentoring</td><td>メンター制度</td></tr><tr><td>liable</td><td>責任を負った</td><td>spill</td><td>こぼす、こぼれる</td></tr><tr><td>vast</td><td>非常に大きな、莫大な</td><td>carry out</td><td>行う、実行する</td></tr><tr><td>investigate</td><td>調査する</td><td>personalized</td><td>個人に合わせた、名前入りの</td></tr><tr><td>subtle</td><td>気付きづらい、見つけにくい</td><td>diversify</td><td>多様化する</td></tr><tr><td>inactive</td><td>怠惰な、 ...
#  <table width="966"><tbody><tr><td width="141">premium</td><td width="335">保険料</td><td width="124">accrued</td><td width="366">未収の</td></tr><tr><td>tutorial</td><td>指導書、個別指導</td><td>commensurate</td><td>釣り合った、比例した、見合った</td></tr><tr><td>discard</td><td>捨てる</td><td>pointless</td><td>無意味な</td></tr><tr><td>overwhelmingly</td><td>圧倒的に</td><td>anonymous</td><td>匿名の</td></tr><tr><td>novice</td><td>初心者</td><td>stringent</td><td>厳しい</td></tr><tr><td>anecdote</td><td>逸話</td><td>integral</td><td>重要な</td></tr><tr><td>fertilizer</td><td>肥料</td><td>admirable</td><td>称賛に値する</td></tr><tr><td>proofread</td><td>校正する</td><td>mandatory</td><td>義務の、強制の</td></tr><tr><td>incorporate</td><td>取り入れる、組み込む</td><td>cozy</td><td>居心地のよい</td></tr><tr><td>surplus</td><td>余分な／余り</td><td>exempt</td><td>免除された</td></tr><tr><td>aspiring</td><td>~志望の、~になろうとする</td><td>internal</td><td>内部の</td></tr><tr><td>assorted</td><td>詰め合わせの</td><td>obligatory</td><td>義務的な</td></tr><tr><td>interoffice</td><td>社内の、オフィス間の</td><td>supplementary</td><td>付加的な</td></tr><tr><td>mutually</td><td>互いに、相互に</td><td>obsolete</td><td>古式の</td></tr><tr><td>periodically</td><td>定期的に</td><td>prohibitive</td><td>高額な、法外な</td></tr><tr><td>obstruct</td><td>（通路や視界を）ふさぐ、さえぎる</td><td>sluggish</td><td>停滞した、不景気な、のろい</td></tr><tr><td>fierce</td><td>熾烈な、荒々しい</td><td>stagnant</td><td>停滞気味の</td></tr><tr><td>solely</td><td>唯一、一人で、単独で</td><td>insufficient</td><td>不十分な</td></tr><tr><td>devise</td><td>考案する、立案する</td><td>negligent</td><td>無頓着な</td></tr><tr><td>foster</td><td>促進する、養う</td><td>exclusive</td><td>限定の、独占的な</td></tr><tr><td>insight</td><td>洞察、洞察力</td><td>resounding</td><td>際だった</td></tr><tr><td>hypothesis</td><td>仮説</td><td>correspondingly</td><td>それに応じて</td></tr><tr><td>predecessor</td><td>前任者、前機種</td><td>tentatively</td><td>仮に、試験的に</td></tr><tr><td>adoption</td><td>採用</td><td>rightfully</td><td>正しく、正当に</td></tr><tr><td>heritage</td><td>伝統、遺産</td><td>emphatically</td><td>断固として、きっぱりと</td></tr><tr><td>accelerate</td><td>加速させる、拍車をかける</td><td>customarily</td><td>習慣的に</td></tr><tr><td>outage</td><td>停止</td><td>thereby</td><td>それにより</td></tr><tr><td>condiment</td><td>調味料</td><td>incidentally</td><td>たまたま、ついでに言えば</td></tr><tr><td>appraisal</td><td>査定、評価</td><td>comparatively</td><td>比較的</td></tr><tr><td>detour</td><td>迂回路</td><td>inadvertently</td><td>不注意に、うっかり</td></tr><tr><td>distraction</td><td>気を散らすもの、注意の妨げになるもの</td><td>eloquently</td><td>雄弁に</td></tr><tr><td>newlywed</td><td>新婚者</td><td>contractually</td><td>契約により</td></tr><tr><td>association</td><td>協会</td><td>literally</td><td>文字通り</td></tr><tr><td>deduct</td><td>控除する</td><td>thoroughly</td><td>徹底的に</td></tr><tr><td>delegation</td><td>代表団、委譲</td><td>in keeping with</td><td>~に沿って、準拠して</td></tr><tr><td>synthetic</td><td>合成の</td><td>in accordance with</td><td>~に従って、~と一致させて</td></tr><tr><td>proceeds</td><td>収益</td><td>amid</td><td>~に囲まれて</td></tr><tr><td>query</td><td>質問、疑念</td><td>in light of</td><td>~を考慮すると</td></tr><tr><td>patiently</td><td>根気よく、我慢強く</td><td>pending</td><td>~を待つ間、~まで</td></tr><tr><td>resumption</td><td>再開、回復</td><td>thoughtfully</td><td>深く考えて、思慮深く、配慮して</td></tr><tr><td>ratio</td><td>比率</td><td>abridged</td><td>要約された、短縮された</td></tr><tr><td>turnover</td><td>離職率</td><td>carpool</td><td>相乗りする／相乗り</td></tr><tr><td>qualification</td><td>資格</td><td>compatible</td><td>相性が良い、互換性がある、共存できる</td></tr><tr><td>dietary</td><td>食事の</td><td>explicit</td><td>明白な、明確な</td></tr><tr><td>objection</td><td>反対</td><td>keenly</td><td>痛烈に、鋭く</td></tr><tr><td>persuasive</td><td>説得力のある</td><td>plaque</td><td>盾</td></tr><tr><td>masterpiece</td><td>名作</td><td>centerpiece</td><td>中心に置かれる装備品、中心になるもの</td></tr><tr><td>outing</td><td>外出、ピクニック</td><td>privileged</td><td>光栄な</td></tr><tr><td>vessel</td><td>船</td><td>recur</td><td>再発する</td></tr><tr><td>respondent</td><td>回答者</td><td>skeptical</td><td>懐疑的な、疑い深い</td></tr><tr><td>quota</td><td>販売ノルマ</td><td>artifact</td><td>（歴史的・文化的価値のある）工芸品、手工品</td></tr><tr><td>conjecture</td><td>推測、憶測</td><td>breathtaking</td><td>息をのむほどの、驚くべき</t ...

# %%
word_list_2 = []
for table in tables:
    for i, td in enumerate(table.find_all("td")):
#         print(i, td.text)
        if i % 2 == 0:
            k = td.text
        else:
            word_list_2.append({k:td.text})
word_list_2
# Out:
# [{'pursue': '追及する、遂行する、続行する'},
#  {'labor': '（肉体的な）労働'},
#  {'inform': '知らせる、告げる、影響を与える'},
#  {'explain': '説明する'},
#  {'anyway': 'とにかく'},
#  {'experiment': '実験、試み／実験する'},
#  {'degree': '（大学の）学位、程度'},
#  {'find out': '発見する、気がつく'},
#  {'benefit': '利益を得る／特典、福利厚生'},
#  {'payment': '支払い'},
#  {'replace': '~を取り替える'},
#  {'relatively': '相対的に、比較的'},
#  {'infer': '推察する、考える'},
#  {'recognize': '認める、見分ける、認識する'},
#  {'following': '~に続いて／次の、以下の'},
#  {'individual': '個人の、個別の／個人'},
#  {'accomplish': '成し遂げる、完遂する、達成する'},
#  {'contribute': '貢献する、寄付する'},
#  {'reinforce': '強化する'},
#  {'budget': '予算／予算に計上する'},
#  {'demand': '要求する、請求する'},
#  {'allow': '許す、可能にする'},
#  {'refer': '参照する、言及する、（人を）紹介する'},
#  {'demonstrate': '実演する、明示する'},
#  {'booking': '（ホテルや乗り物の）予約'},
#  {'exchange': '交換する、両替する'},
#  {'assemble': '組み立てる、集める'},
#  {'application': '応募書類、応募、申請'},
#  {'despite': '~にもかかわらず'},
#  {'survey': '調査／~を調査する'},
#  {'cause': '引き起こす、もたらす／原因'},
#  {'obey': '従う'},
#  {'available': '入手できる、利用できる、購入できる、'},
#  {'reward': '報いる、ほうびを与える／報酬、ほうび'},
#  {'commercial': '商業の、商業的な'},
#  {'prefer': '~の方を好む'},
#  {'occupy': '占有する'},
#  {'contract': '契約、契約書'},
#  {'compare': '比較する、比べる、例える'},
#  {'agency': '代理店、取扱店、機関'},
#  {'inquire': '尋ねる、問い合わせる'},
#  {'double': '2倍になる、倍増する'},
#  {'department': '部門、売り場'},
#  {'release': '発表する、発売する'},
#  {'describe': '説明する、描写する'},
#  {'management': '経営（陣）、管理'},
#  {'a couple of ~': '２、３の'},
#  {'financial': '金銭上の、財政の、お金の'},
#  {'remove': '取り除く'},
#  {'relax': 'ゆるめる、和らげる'},
#  {'conference': '会議、学会'},
#  {'profitable': 'もうかる、利益になる'},
#  {'decision': '決定、決定事項'},
#  {'hire': '~を雇う、賃借りする'},
#  {'introduce': '紹介する、導入する'},
#  {'performance': '業績、仕事ぶり、性能、公演'},
#  {'reject': '却下する、拒否する'},
#  {'charge': 'を請求する、を充電する／料金、責任'},
#  {'destroy': '破壊する'},
#  {'graduate': '卒業する'},
#  {'according to': '~によると、~に従って'},
#  {'reschedule': '予定を変更する'},
#  {'income': '収入、収益'},
#  {'postpone': '延期する'},
#  {'empty': '空にする'},
#  {'pleased': '喜んで、満足して'},
#  {'entertain': 'もてなす、楽しませる'},
#  {'argue': '議論する、口論する'},
#  {'likely': 'おそらく／~しそうだ'},
#  {'lead': '~を導く'},
#  {'establish': '~を設立する、制定する'},
#  {'document': '記録する、文書を提供する／文書'},
#  {'star': '主演する、呼び物にする'},
#  {'confirm': '確認する'},
#  {'secure': '~を確保する、固定する／安全な'},
#  {'illustrate': '説明する、図解する'},
#  {'state': '述べる、言う'},
#  {'recommend': '推薦する'},
#  {'equipment': '機器、装備'},
#  {'award': '賞／授与する'},
#  {'basis': 'ベース、基準、根拠'},
#  {'examine': '詳しく調べる、吟味する'},
#  {'suffer': '被る、受ける'},
#  {'propose': '提案する、申し出る'},
#  {'environmental': '環境の'},
#  {'clothing': '衣類'},
#  {'apologize': 'おわびをする、謝罪する'},
#  {'pick up': '~を車で拾う、迎えに行く、受け取る'},
#  {'provide': '提供する'},
#  {'carry': '扱う、運ぶ、所有する'},
#  {'browse': '見て回る、拾い読みする'},
#  {'display': '展示／展示する'},
#  {'tradition': '伝統、しきたり'},
#  {'conduct': '~を行う、導く、実行する、実施する'},
#  {'satisfy': '満足させる'},
#  {'represent': '代表する'},
#  {'local': '地元の／地元の人'},
#  {'candidate': '候補者'},
#  {'facility': '施設、設備'},
#  {'exclude': '~を除く、排除する'},
#  {'take part in': '参加する、出場する'},
#  {'possess': '所有する'},
#  {'institute': '制定する、始める'},
#  {'exhibit': '展示物、展示会／展示する'},
#  {'resume': '再開する'},
#  {'invest': '投資する、注ぎ込む'},
#  {'opening': '空き、開店、就職口'},
#  {'overlook': '見逃す'},
#  {'notify': '知らせる'},
#  {'session': '時間、集まり'},
#  {'maintain': '維持する、メンテナンスする'},
#  {'purchase': '購入する／購入品'},
#  {'host': '主催する、接待する'},
#  {'transform': '変える、変容させる'},
#  {'construction': '建設'},
#  {'note': '注意する、述べる／メモ'},
#  {'notice': 'お知らせ／~に気づく'},
#  {'ship': '出荷する、発送する'},
#  {'instruct': '指示する、教える'},
#  {'dispute': '異議を唱える'},
#  {'deliver': '（商品など）を届ける'},
#  {'process': '処理する／プロセス、過程、処理'},
#  {'participate': '参加する、関与する'},
#  {'simulate': 'まねる、模倣する'},
#  {'tour': '見学する、旅行する／見学、旅行'},
#  {'apply': '応募する、応用する'},
#  {'subscribe': '購読する、加入する'},
#  {'instruction': '説明書、説明、指示'},
#  {'correct': '修正する、訂正する'},
#  {'report': '報告する、直属する'},
#  {'merchandise': '商品'},
#  {'membership': '会員、会員資格、会員数'},
#  {'loosen': 'ゆるめる'},
#  {'based': '拠点のある、基づく'},
#  {'research': '研究、調査／研究する、調査する'},
#  {'advance': '先行した、事前の／進歩、前進'},
#  {'focus': '集中させる、照準を合わせる'},
#  {'committee': '委員会'},
#  {'result': '結果／（結果的に）生じる'},
#  {'successful': '成功した、うまく行く'},
#  {'mail': '郵送する'},
#  {'excellent': '素晴らしい'},
#  {'attend': '出席する、参加する'},
#  {'industry': '産業、業界'},
#  {'fine': '（天気が）晴れた、素晴らしい'},
#  {'fee': '料金'},
#  {'shift': '移す、変更する'},
#  {'accept': '受け入れる、受け付ける'},
#  {'admiration': '感心、称賛'},
#  {'upcoming': '今度の'},
#  {'gather': '集まる'},
#  {'latest': '最新の'},
#  {'delivery': '配達（物）'},
#  {'submit': '提出する'},
#  {'availability': '手に入ること、利用できること'},
#  {'transportation': '輸送手段'},
#  {'announce': '発表する、知らせる、公表する'},
#  {'résumé': '履歴書'},
#  {'set up': '設置する'},
#  {'executive': '重役、取締役／重役（用）の、高級な'},
#  {'recently': '最近'},
#  {'previous': '前の、以前の'},
#  {'regularly': '定期的に'},
#  {'proposal': '提案、提案書'},
#  {'blame': '~のせいにする、非難する'},
#  {'supply': '必需品／供給する'},
#  {'workforce': '全従業員、労働力'},
#  {'enclose': '同封する、囲む'},
#  {'require': '要求する、義務付ける'},
#  {'policy': '規定、方針'},
#  {'indicate': '示す'},
#  {'register': '登録する／レジ'},
#  {'impression': '（心に残る）印象'},
#  {'arrange': '手配する、並べる'},
#  {'struggle': '奮闘する、もがく、苦心する'},
#  {'bill': '請求書、紙幣／請求書を送る'},
#  {'employee': '社員、従業員'},
#  {'approve': '承認する、賛成する'},
#  {'fund': '資金を与える'},
#  {'opportunity': '機会、チャンス'},
#  {'additional': '付加的な、追加の'},
#  {'deadline': '締め切り、期限'},
#  {'shuttle': '往復運転で運ぶ'},
#  {'corporate': '企業の、法人の'},
#  {'depart': '（~を）出発する'},
#  {'warranty': '保証、保証書'},
#  {'sweep': '掃く、掃除する'},
#  {'necessary': '必要な'},
#  {'review': '検討する、論評する／検討、論評'},
#  {'reserve': '予約する、確保する／蓄え'},
#  {'appear': '~のように見える、現れる'},
#  {'resident': '住民、住人'},
#  {'offer': '申し出る、提供する'},
#  {'create': '創造する、作り出す'},
#  {'go over ~': '~をじっくりと調べる'},
#  {'mention': '述べる、言及する／言及'},
#  {'load': '荷物を積む'},
#  {'appreciate': '感謝する、高く評価する'},
#  {'production': '生産、作品'},
#  {'replacement': '交換、交換品、後任'},
#  {'favor': '善意の行為／~の方を好む'},
#  {'significant': 'かなりの、大幅な、重要な'},
#  {'earn': '得る、稼ぐ'},
#  {'employer': '雇用主'},
#  {'fire': '解雇する'},
#  {'valuable': '貴重な'},
#  {'located': '位置して'},
#  {'profitability': '利益率、利益性'},
#  {'analyze': '~を分析する'},
#  {'publication': '出版物'},
#  {'commute': '通勤する'},
#  {'customer': '顧客、客'},
#  {'generous': '気前のよい、寛大な'},
#  {'stock': '株式、在庫（品）／（物）を蓄える'},
#  {'import': '輸入する'},
#  {'information': '情報、インフォメーション'},
#  {'detail': '詳細／詳しく述べる'},
#  {'downtoun': '中心街の／中心街に［で］／中心街'},
#  {'attain': '~を実現する、達成する'},
#  {'treat': '~を取り扱う、処理する'},
#  {'direct': '向ける、管理する、監督する'},
#  {'graduation': '卒業（式）'},
#  {'relationship': '関係（性）'},
#  {'emphasize': '~を強調する'},
#  {'turn in': '提出する、返却する'},
#  {'corporation': '法人'},
#  {'repair': '修理／修理する'},
#  {'regarding': '~に関して'},
#  {'recover': '取り戻す、回復する'},
#  {'article': '記事、（契約書など）の条項、品物'},
#  {'contribution': '貢献、寄付金'},
#  {'renovate': '改装する、修理する'},
#  {'confess': '告白する'},
#  {'prevent': '防ぐ、阻む'},
#  {'increase': '増加／増える、増やす'},
#  {'contain': '含む、所有する'},
#  {'growth': '成長、発展'},
#  {'considerable': '（量や程度が）かなりの'},
#  {'update': '更新する、改訂する'},
#  {'sign up for': '申し込む'},
#  {'quantity': '量、分量'},
#  {'reduction': '減少、削減'},
#  {'regard': 'みなす、考える'},
#  {'delay': '遅らせる、延期する'},
#  {'include': '含む'},
#  {'remain': '残る、そのままでいる'},
#  {'cost': '費用がかかる（費用）'},
#  {'fix': 'を修理する、~を固定する'},
#  {'greet': '挨拶する、出迎える'},
#  {'negotiate': '交渉する、協議する'},
#  {'consider': '考える、検討する'},
#  {'solve': '~を解く、解決する'},
#  {'currently': '現在は'},
#  {'pass out': '配る'},
#  {'activity': '活動、アクティビティー'},
#  {'consecutive': '連続した'},
#  {'refuse': '拒む、断る'},
#  {'print': '活字体で書く'},
#  {'subject': '科目、（議論などの）題目'},
#  {'authorize': '公認する、権限を与える'},
#  {'assign': '割り当てる、配属する'},
#  {'counsel': '助言する、相談する'},
#  {'advertising': '広告（業）、宣伝（活動）'},
#  {'reflect': '映し出す、反射する'},
#  {'vacancy': '空き室'},
#  {'achievement': '成果、業績'},
#  {'stop by': '立ち寄る'},
#  {'advise': '助言する、意見する、忠告する'},
#  {'correctly': '正しく、正確に'},
#  {'damage': '損害／~に損害を与える'},
#  {'stack': '積み重ねる'},
#  {'adjust': '調整する'},
#  {'expect': '予期する、予定する'},
#  {'appliance': '電化製品'},
#  {'connect': '接続する、つなぐ'},
#  {'improve': '改善する'},
#  {'saving': '節約、値引き'},
#  {'estimate': '見積もり／~を見積もる'},
#  {'water': '水をやる'},
#  {'prove': 'わかる、証明する'},
#  {'firm': '会社'},
#  {'rank': '位置する'},
#  {'attract': '~をひきつける、魅了する'},
#  {'feedback': 'フィードバック、反応'},
#  {'pour': '注ぐ'},
#  {'datermine': '決定する、決意する'},
#  {'profit': '利益'},
#  {'analysis': '分析'},
#  {'lay off': '解雇する'},
#  {'hesitate': 'ためらう、躊躇する'},
#  {'client': '顧客、クライアント、取引先'},
#  {'selection': '選ぶこと、選択'},
#  {'attention': '注意、留意'},
#  {'vote': '投票する、票決する'},
#  {'feed': '食べさせる、餌を与える'},
#  {'ladder': 'はしご'},
#  {'present': '与える、提示する'},
#  {'object': '反対する、異議を唱える'},
#  {'annual': '年に1度の、毎年恒例の、年間の'},
#  {'retire': '退職する、引退する'},
#  {'introduction': '（人の）紹介、（物の）導入'},
#  {'status': '状況、地位'},
#  {'face': '（~の方を）向く、直面する'},
#  {'fuel': '燃料'},
#  {'skill': '技能、スキル'},
#  {'nearly': 'ほとんど、もう少しで'},
#  {'compliment': '賛辞を述べる、ほめる'},
#  {'cafeteria': '社員食堂'},
#  {'convention': '総会、大会'},
#  {'determine': '決定する、判断する、決心する'},
#  {'bear': '持つ'},
#  {'crew': '乗務員、乗組員'},
#  {'temporarily': '一時的に'},
#  {'raise': 'を引き上げる、を持ち上げる'},
#  {'preserve': '保護する、保存する'},
#  {'finally': 'ついに、最終的に'},
#  {'forward': '転送する、進める'},
#  {'because of ~': '~のせいで、~のおかげで'},
#  {'enough': '十分な／十分に'},
#  {'important': '重要な、重大な'},
#  {'vary': '変わる'},
#  {'suitable': '適した、ふさわしい'},
#  {'admission': '入場、入場料、入場許可'},
#  {'qualified': '資格条件を満たした'},
#  {'prohibit': '禁じる'},
#  {'coordinate': '（複数の人や物）をまとめる、調整する'},
#  {'distribution': '流通、配布、分配'},
#  {'medical': '医療の'},
#  {'affect': '影響する、作用する'},
#  {'boost': '~を強化する、増加させる'},
#  {'take care of ~': '~の世話をする'},
#  {'gain': '~を得る、獲得する／利益、得ること'},
#  {'account': '占める、説明する／口座・説明'},
#  {'constructive': '建設的な、前向きな'},
#  {'look up': '調べる'},
#  {'resolve': '解決する'},
#  {'reimburse': '（払ったお金）を払い戻す'},
#  {'reason': '理由、動機'},
#  {'involve': '（人を）巻き込む、伴う、含む'},
#  {'export': '輸出／~を輸出する'},
#  {'except': '~を除いて、~を除外して'},
#  {'attempt': '試み／~を試みる'},
#  {'finance': '資金を調達する、融資する'},
#  {'alternative': '代わりの／代案、選択肢'},
#  {'defend': '~を（攻撃から）守る、（~を）防御する'},
#  {'consumer': '消費者'},
#  {'rely on': '~に依存する、頼る'},
#  {'implication': '影響、暗示、言葉の意味合い'},
#  {'proportion': '比例、（~に対する）割合、比率'},
#  {'inovolve': '~を伴う、（人）を巻き込む'},
#  {'expand': '拡大する'},
#  {'grant': '（権利など）を与える／助成金'},
#  {'predict': '予測する'},
#  {'tip': 'アドバイス、秘訣'},
#  {'alter': '変更する、作り変える'},
#  {'operation': '操作、運転、事業'},
#  {'proof': '証拠、証明'},
#  {'figure': '数字、人物'},
#  {'seek': '捜し求める'},
#  {'enthusiasm': '熱中、熱狂'},
#  {'seriously': 'まじめに、深刻に'},
#  {'imply': 'ほのめかす、暗示する'},
#  {'accompany': '添付する、同行する'},
#  {'general': '全般的な、一般的な'},
#  {'vehicle': '乗り物、車両'},
#  {'settle': '解決する'},
#  {'stimulate': '刺激する'},
#  {'correspondence': '（文書などの）やりとり、通信'},
#  {'found': '設立する、創立する'},
#  {'point out': '指摘する'},
#  {'reference': '照会先、照会、参照'},
#  {'possibility': '可能性'},
#  {'fill out': '記入する'},
#  {'convince': '確信させる、納得させる'},
#  {'determination': '決意すること、決断力の強さ'},
#  {'inspect': '検査する、点検する'},
#  {'regret': '残念に思う、悔いる'},
#  {'discussion': '議論、話し合い'},
#  {'acquisition': '（企業の）買収、獲得'},
#  {'adopt': '採用する、導入する'},
#  {'draw': '引く、描く'},
#  {'retailer': '小売業者'},
#  {'break': '休憩、中断、破壊／~を壊す'},
#  {'book': '予約する'},
#  {'address': '話す、対処する'},
#  {'satisfaction': '満足'},
#  {'last': '続く、待つ'},
#  {'bring up': '持ち出す、提起する、育てる'},
#  {'restrict': '~を制限する'},
#  {'summary': 'あらすじ、要約'},
#  {'develop': '開発する、発達する'},
#  {'hang': '掛かる'},
#  {'expectation': '期待、予想'},
#  {'intend': '意図する'},
#  {'locate': '所在を探し当てる'},
#  {'role': '（人の）役割'},
#  {'decade': '10年、10年間'},
#  {'match': '調和する、似合う'},
#  {'prepare': '準備する'},
#  {'pharmaceutical': '製薬の、調剤の'},
#  {'interest': '利子、興味／（人）に興味を持たせる'},
#  {'post': '提示する、投稿する'},
#  {'spread': '広げる、掛ける'},
#  {'comfortably': '快適に、楽に'},
#  {'organize': '計画する、組織する'},
#  {'trust': '信用／~を信用する'},
#  {'efficiency': '効率の良さ'},
#  {'decline': '断る、下降する'},
#  {'encourage': '勧める、促す'},
#  {'complete': '完了する、記入する'},
#  {'challenge': '（能力を試される）課題、挑戦'},
#  {'term': '（契約の）条件、期間'},
#  {'catalog': '目録を作る、分類する'},
#  {'obtain': '取得する、得る'},
#  {'electricity': '電気、電力'},
#  {'permission': '許可、承諾'},
#  {'enable': '可能にする'},
#  {'afford': '~する余裕がある'},
#  {'foreigh': '外国の、異質の'},
#  {'check': '（~を）確認する、チェックする'},
#  {'broadcast': '放送する'},
#  {'proceed': '進む、続行する'},
#  {'transfer': '転勤させる、移す'},
#  {'indispensable': '必須の、絶対必要な'},
#  {'take over': '引き継ぐ'},
#  {'achieve': '達成する'},
#  {'publish': '出版する'},
#  {'sign up': '~に登録する、契約する'},
#  {'find': '気づく、発見する'},
#  {'respectively': 'それぞれ、各々'},
#  {'operate': '操作する、運営する'},
#  {'wave': '手を振る'},
#  {'compete': '競争する'},
#  {'unit': '1個、単位'},
#  {'suspect': '~だろうと思う、疑う'},
#  {'stress': '強調する'},
#  {'explore': '探索する、調査する'},
#  {'arrangement': '手配、準備'},
#  {'translate': '翻訳する'},
#  {'glance': 'チラッと見る'},
#  {'nominate': 'ノミネートする'},
#  {'enhance': '向上させる、強化する'},
#  {'chair': '議長を務める、司会する'},
#  {'evaluate': '評価する'},
#  {'simplify': '~を単純化する、簡素化する'},
#  {'widen': '広げる'},
#  {'administrate': '運営する'},
#  {'promote': '昇進させる、宣伝する'},
#  {'renew': '更新する'},
#  {'discover': '発見する'},
#  {'polish': '磨く'},
#  {'consist': 'から成る、で構成される'},
#  {'place': '置く'},
#  {'reach': '連絡をとる'},
#  {'contact': '連絡をとる'},
#  {'combine': '組み合わせる、結合する'},
#  {'branch': '支店'},
#  {'foresee': '予見する、予測する'},
#  {'lower': '下げる、低くする'},
#  {'divide': '分割する'},
#  {'tie': '結ぶ'},
#  {'admire': '賞賛する、感心する'},
#  {'paid': '有給の、支払い済みの'},
#  {'attach': '添付する、取り付ける'},
#  {'interview': '面接する、会見する'},
#  {'approach': '近づく'},
#  {'observe': '観察する'},
#  {'hold': '開催する'},
#  {'unfortunately': '残念なことに、残念ながら'},
#  {'hand out': '配る'},
#  {'surround': '囲む'},
#  {'expose': 'さらす、触れさせる'},
#  {'conserve': '保存する、保護する'},
#  {'plug': '差し込む、接続する'},
#  {'rent': '家賃／賃貸借する'},
#  {'hang up': '電話を切る'},
#  {'appeal': '懇願する、アピールする'},
#  {'sew': '縫う'},
#  {'entitle': '権利を与える'},
#  {'finalize': '仕上げる、最終的に承認する'},
#  {'memo': '社内文書'},
#  {'praise': 'ほめる、賞賛する'},
#  {'take place': '行われる'},
#  {'lean': '寄りかかる、立て掛ける'},
#  {'ease': '和らげる、容易にする'},
#  {'project': '見積もる、計画する'},
#  {'luggage': '旅行かばん、手荷物'},
#  {'exceed': '超える'},
#  {'distribute': '配布する、分配する'},
#  {'run out': 'が不足する、尽きる'},
#  {'impress': '感心する、感動する'},
#  {'store': '保存する、蓄える、しまっておく'},
#  {'editor': '編集者'},
#  {'identify': '特定する、気づく'},
#  {'paddle': 'パドルで漕ぐ'},
#  {'deserve': '値する'},
#  {'remind': '再確認する、思い出させる'},
#  {'assure': '保証する、確信させる'},
#  {'exhibition': '展示会、展示物、展示'},
#  {'appoint': '任命する、指名する'},
#  {'leading': '首位の、一流の'},
#  {'advertise': '宣伝する'},
#  {'organization': '団体、会社、組織（化）'},
#  {'try on': '試着する'},
#  {'limited': '限られた'},
#  {'public': '一般の人々、公衆'},
#  {'procedure': '手続き、手順'},
#  {'checkout': 'レジ、チェックアウト'},
#  {'experienced': '経験豊富な'},
#  {'entry': '入場、参加'},
#  {'personnel': '社員、人事部'},
#  {'progress': '前進、進行'},
#  {'author': '著作、作者／（本を）書く'},
#  {'issue': '課題、論争点'},
#  {'directly': '直接に、直行して'},
#  {'produce': '農産物、物産'},
#  {'expert': '専門家／専門的な'},
#  {'balance': '残金、バランス'},
#  {'mainly': '主に'},
#  {'relief': '安らぎ、緩和、除去'},
#  {'suggestion': '提案'},
#  {'vase': '花瓶'},
#  {'supplier': '納入業者、供給業者'},
#  {'patio': 'テラス、中庭'},
#  {'representative': '担当者、代表者'},
#  {'line': 'ライン、線'},
#  {'packaging': '梱包、パッケージ'},
#  {'sign': '表れ、徴候'},
#  {'description': '説明、記述、描写'},
#  {'period': '期間'},
#  {'property': '不動産、資産'},
#  {'capacity': '能力、収容力'},
#  {'extension': '内線、延長'},
#  {'celebration': 'お祝い、祝典'},
#  {'highly': '非常に'},
#  {'flyer': 'チラシ、広告'},
#  {'assistance': '支援、援助'},
#  {'cooperation': '協力、協業'},
#  {'laboratory': '研究所、実験室'},
#  {'study': '研究、調査'},
#  {'headquarters': '本社'},
#  {'effect': '効果'},
#  {'device': '機器、装置'},
#  {'cutlery': '食器'},
#  {'intended': '意図された、向けられた'},
#  {'expense': '費用、経費'},
#  {'brochure': 'パンフレット'},
#  {'overseas': '海外の／海外で'},
#  {'response': '返答、返事'},
#  {'satisfied': '満足した'},
#  {'region': '地域'},
#  {'resonable': '（値段が）手ごろな、妥当な'},
#  {'donation': '寄付'},
#  {'unable': '（~することが）できない'},
#  {'quarter': '四半期'},
#  {'legal': '法律に関する、合法の'},
#  {'agreement': '契約（書）、同意（書）、合意・協定'},
#  {'regulation': '規制、規則'},
#  {'potential': '見込みがある、潜在的な／可能性'},
#  {'launch': '開始、発売／開始する、発売する'},
#  {'warehouse': '倉庫'},
#  {'recommendation': '推薦'},
#  {'refund': '返金／返金する'},
#  {'claim': '申し立て、主張、所有権／主張する'},
#  {'immediately': 'すぐに、即座に'},
#  {'insurance': '保険'},
#  {'council': '議会'},
#  {'departure': '出発、逸脱'},
#  {'responsible': '担当している、責任がある'},
#  {'mayor': '町長、市長'},
#  {'avoid': '避ける'},
#  {'district': '地区'},
#  {'effrctive': '効果的な'},
#  {'former': '前の、かつての／前者'},
#  {'invitation': '招待（状）'},
#  {'modern': '現代的な、近代的な'},
#  {'reduce': '（値段を）下げる、減らす'},
#  {'option': '選択肢、オプション'},
#  {'efficient': '効率的な'},
#  {'search': '捜索、検索／探す、検索する'},
#  {'manufacturer': 'メーカー、製造業者'},
#  {'specific': '具体的な、特定の'},
#  {'comfortable': '快適な、楽な、自信がある'},
#  {'agricultural': '農業の'},
#  {'method': '方法'},
#  {'historical': '歴史（上）の'},
#  {'entire': '全体の'},
#  {'helpful': '役立つ、助けになる'},
#  {'range': '範囲'},
#  {'complaint': '苦情、クレーム'},
#  {'setting': '環境'},
#  {'related': '関連した'},
#  {'frequent': '頻繁な'},
#  {'simply': '単純に、単に'},
#  {'promotion': '昇進、販売促進'},
#  {'unique': '他にはない、独自の、特有の'},
#  {'traditional': '伝統的な、従来の'},
#  {'concerning': '~に関する'},
#  {'fit': '合う、入る'},
#  {'reputation': '評判'},
#  {'arrival': '到着'},
#  {'component': '部品'},
#  {'familiar': 'よく知っている、おなじみの'},
#  {'enjoyable': '楽しい'},
#  {'ideal': '理想的な'},
#  {'existing': '従来の、既存の'},
#  {'landscaping': '造園'},
#  {'alike': '同様に／よく似た'},
#  {'occasion': '特別な行事、（何かが起こる）時、好機'},
#  {'connection': '接続、つながり、関連、乗り継ぎ'},
#  {'standard': '基準／標準の'},
#  {'eager': '~したがる、熱望する'},
#  {'background': '経歴、背景'},
#  {'fairly': 'かなり'},
#  {'guided': 'ガイド付きの'},
#  {'absolutely': '完全に、間違いなく、まったく'},
#  {'advanced': '進んだ、上級の、高度な'},
#  {'atmosphere': '雰囲気'},
#  {'confident': '確信している、自信がある'},
#  {'calculate': '計算する'},
#  {'initial': '初めの、当初の'},
#  {'contrast': '対照、はっきりした違い／対照的である'},
#  {'separate': '分かれた、別々の／分ける'},
#  {'monitor': '監視する／（コンピュータの）モニター'},
#  {'environment': '環境'},
#  {'occasionally': '時々'},
#  {'various': 'さまざまな'},
#  {'serious': '重大な、真剣な、重要な'},
#  {'brief': '短い、短時間の'},
#  {'strength': '強さ、強度、（液体等の）重さ'},
#  {'full-time': '常勤の'},
#  {'equally': '同じように、均等に'},
#  {'overall': '全体の／全体として'},
#  {'informal': '非公式の、カジュアルな'},
#  {'complex': '複合施設、集合住宅／複雑な'},
#  {'renowned': '名高い、著名な'},
#  {'delighted': 'とても喜んでいる'},
#  {'depend on ~': '~次第である、~に頼る'},
#  {'honor': '称える、（契約等を）守る／名誉'},
#  {'sudden': '急な、突然の'},
#  {'properly': 'ちゃんと、適切に'},
#  {'look forward to ~': '~を楽しみにする'},
#  {'electronic': '電子の、電子的な'},
#  {'request': '依頼／~を依頼する'},
#  {'preparation': '準備、用意'},
#  {'access': '~にアクセスする／アクセス'},
#  {'duty': '任務、職務、関税'},
#  {'typical': '典型的な'},
#  {'willing': '~することを嫌がらない、~する気がある'},
#  {'security': '安全、無事'},
#  {'worth': '価値がある'},
#  {'exception': '例外'},
#  {'overnight': '一晩の、翌日配送の／一晩'},
#  {'acceptable': '許容の、受け入れることのできる'},
#  {'particularly': '特に'},
#  {'in advance': '事前に'},
#  {'aspect': '面、局面'},
#  {'own': '~を所有する／自分の'},
#  {'involved': '関わった'},
#  {'worldwide': '世界的な／世界中で'},
#  {'scholarship': '奨学金'},
#  {'economical': '経済的な、節約の'},
#  {'shortly': 'じきに、まもなく'},
#  {'case': '状況、場合'},
#  {'automobile': '自動車の／自動車'},
#  {'favorite': 'お気に入りの、大好きな'},
#  {'certainly': '確かに'},
#  {'staff': 'スタッフ'},
#  {'possibly': 'ひょっとすると、もしかすると'},
#  {'judge': '判断する、裁く、評価する／裁判官'},
#  {'sufficient': '十分な、満足な'},
#  {'market': '市場／~を市場で売る'},
#  {'practical': '実用的な、実践的な'},
#  {'rise': '増える、上昇する'},
#  {'sales representaive': '販売員、営業担当者'},
#  {'concern': '心配事、懸念事項'},
#  {'medication': '薬、医薬'},
#  {'salary': '給料'},
#  {'fulfill': '満たす、果たす'},
#  {'in the event of ~': '万一~の場合には'},
#  {'reflection': '熟考、反射'},
#  {'weigh': '~の重さを量る、~の重さがある'},
#  {'foundation': '土台、基礎'},
#  {'development': '開発、発達、発展'},
#  {'governor': '知事'},
#  {'quite': 'かなり、すっかり'},
#  {'practice': '習わし、開業、実施'},
#  {'strict': '（人や規制が）厳しい'},
#  {'responsibility': '（人や物に対する）責任'},
#  {'contemporary': '現代の、同時代の'},
#  {'impressive': '印象的な、素晴らしい'},
#  {'complimentary': '無料の、称賛する'},
#  {'coworker': '（仕事の）同僚'},
#  {'defeat': '（敵）を負かす／敗北、負け'},
#  {'excessive': '過度の、度を越えた'},
#  {'establishment': '設立（制定）すること、組織'},
#  {'favorable': '好都合の、好意的な'},
#  {'similar': '類似した'},
#  {'label': '~にラベル［レッテル］を貼る／ラベル'},
#  {'extra': '余分の、特別の、追加の'},
#  {'assess': '（価値や重要性）を評価する'},
#  {'clerical': '事務の、書記の'},
#  {'institution': '機関、団体'},
#  {'substance': '物質、実体'},
#  {'awareness': '意識、気づいていること'},
#  {'discount': '割引／~を無視する'},
#  {'pile': '積み重ねた山／~を積み重ねる'},
#  {'shipment': '（商品の）発送、船積み'},
#  {'installation': 'インストール、取り付け'},
#  {'occupation': '職業'},
#  {'receipt': 'レシート、領収書'},
#  {'chemical': '薬品、化学物質'},
#  {'pharmacy': '薬局'},
#  {'media': '媒体、マスメディア'},
#  {'railing': '手すり、ガードレール'},
#  {'campaign': 'キャンペーン'},
#  {'transaction': '取引'},
#  {'colleague': '同僚'},
#  {'appropriate': '適切な、適した'},
#  {'influence': '影響、作用'},
#  {'competitive': '競争の、他に負けない、競争力がある'},
#  {'trend': '動向、トレンド'},
#  {'fare': '運賃、乗車料金'},
#  {'diner': '食事客'},
#  {'implement': '（計画や政策）を実行する'},
#  {'microscope': '顕微鏡'},
#  {'exclusively': '限定で、独占的に'},
#  {'stool': '（背もたれのない）いす'},
#  {'recipient': '受領者、受取人'},
#  {'fellow': '仲間'},
#  {'affordable': '手頃な価格の、入手可能な'},
#  {'party': 'グループ、当事者'},
#  {'hospitality': 'おもてなし、接待'},
#  {'bureau': '案内所、事務局'},
#  {'wheelbarrow': '手押し車'},
#  {'leave': '休暇、許可'},
#  {'guidelines': '指針、ガイドライン'},
#  {'series': '連続、シリーズ'},
#  {'tourism': '観光事業、観光客'},
#  {'behavior': '振る舞い、行動'},
#  {'resource': '資源'},
#  {'instrument': '楽器、道具、器具'},
#  {'debate': '議論、討論'},
#  {'concentration': '集中'},
#  {'edition': '版'},
#  {'wealth': '豊富さ、富'},
#  {'minutes': '議事録、分'},
#  {'cashier': 'レジ'},
#  {'journey': '旅行、行程'},
#  {'spectator': '観客'},
#  {'bargain': 'お買い得品、取引'},
#  {'supervisor': '上司、監督者'},
#  {'generation': '世代、代、同時代'},
#  {'draft': '原稿、下書き'},
#  {'completion': '完了、完成'},
#  {'forecast': '予測、予報'},
#  {'board': '板、役員会／登場する'},
#  {'comfort': '快適さ、満足、慰め'},
#  {'savings': '貯蓄、節約'},
#  {'division': '部門、分割、課'},
#  {'kitchenware': '台所用品'},
#  {'task': '仕事、課題'},
#  {'ceiling': '天井'},
#  {'excuse': '弁解、口実'},
#  {'deposit': '頭金、保証金／預け入れる'},
#  {'difficulty': '困難、問題点'},
#  {'measure': '対策、手段'},
#  {'drawing': '抽選会、素描'},
#  {'rate': '割合、料金'},
#  {'presence': '存在感、出席'},
#  {'chief': '長、上司'},
#  {'economy': '経済、節約'},
#  {'output': '生産高、産出'},
#  {'shelter': '避難所、収容施設'},
#  {'asset': '財産、強み'},
#  {'workplace': '職場'},
#  {'alert': '警報、警告／知らせる'},
#  {'professor': '教授'},
#  {'drawer': '引き出し'},
#  {'memorandum': '社内文書、覚え書き'},
#  {'packet': '小包、袋'},
#  {'clerk': '事務員、受付係'},
#  {'productivity': '生産性'},
#  {'plant': '工場'},
#  {'position': '位置、地位、職'},
#  {'cancellation': '取り消し、キャンセル'},
#  {'wing': 'ウイング、ビルの一角'},
#  {'lawn': '芝生'},
#  {'envelope': '封筒'},
#  {'traffic': '交通、通行'},
#  {'copy': '（本・雑誌などの）冊・部、写し'},
#  {'work': '作品、仕事'},
#  {'authority': '権限、権威、当局'},
#  {'amount': '量'},
#  {'solution': '解決策、解決'},
#  {'pedestrian': '歩行者'},
#  {'official': '役人、職員'},
#  {'scale': '規模、目盛り'},
#  {'disease': '病気'},
#  {'shortage': '不足'},
#  {'factor': '要因、要素'},
#  {'venue': '会場、開催地'},
#  {'prospect': '見通し、可能性'},
#  {'suburb': '郊外'},
#  {'priority': '優先順位、重要なこと'},
#  {'distinctive': '独自の、特色となる'},
#  {'tenant': '賃借人、入居者'},
#  {'persuasion': '説得、説得力'},
#  {'reservation': '予約'},
#  {'acceptance': '受諾、受け入れ、採用、合格'},
#  {'slope': '坂、斜面'},
#  {'ensure': '保証する、請け合う'},
#  {'agenda': '議題、議事日程'},
#  {'discretion': '裁量の自由、分別'},
#  {'evaluation': '評価'},
#  {'urgent': '緊急の'},
#  {'lack': '不足、欠乏'},
#  {'analyst': 'アナリスト、専門の分析者'},
#  {'architect': '建築家'},
#  {'sponsor': '~のスポンサーをする／スポンサー'},
#  {'secretary': '秘書'},
#  {'service': '業務、サービス、奉仕'},
#  {'aisle': '通路'},
#  {'manager': 'マネージャー、経営者'},
#  {'medicine': '薬'},
#  {'variety': '多様性'},
#  {'workload': '仕事量'},
#  {'share': '~をシェアする、共有する'},
#  {'negotiation': '交渉'},
#  {'consultant': 'コンサルタント、顧問'},
#  {'faucet': '蛇口、注ぎ口'},
#  {'critical': '批判的な、危機的な、重大な'},
#  {'appointment': '約束、予約'},
#  {'fluent': '流暢な、堪能な'},
#  {'order': '順番、注文'},
#  {'deal': '取引／扱う、~を取引する'},
#  {'checkup': '検査、健康診断'},
#  {'state-of-the-art': '最先端の、最新の'},
#  {'content': '内容、中身／満足している'},
#  {'carefully': '慎重に'},
#  {'anniversary': '~周年、記念日'},
#  {'contrary': '正反対の'},
#  {'automatically': '自動的に'},
#  {'package': '（梱包した）荷物'},
#  {'destination': '目的地、行き先'},
#  {'disposal': '（不要物の）処理、処分'},
#  {'economic': '経済の、経済上の'},
#  {'urge': '強く促す'},
#  {'extremely': 'きわめて、非常に'},
#  {'transport': '~を輸送する'},
#  {'accurate': '正確な'},
#  {'direction': '方向、指示（書）'},
#  {'aware': '気付いて'},
#  {'interruption': '中断、（物事を）遮ること'},
#  {'crowded': '混雑した'},
#  {'due to ~': '~のせいで、~のおかげで'},
#  {'function': '機能／機能する'},
#  {'ability': '能力、才能'},
#  {'impact': '影響'},
#  {'base': '~の本拠地を置く／土台'},
#  {'amazing': '驚くべき'},
#  {'attire': '衣装、服装'},
#  {'popularity': '人気'},
#  {'head': '進む、を率いる'},
#  {'permit': '許可証／許可する'},
#  {'whether': '~かどうか'},
#  {'crop': '作物、収穫量'},
#  {'relative': '相対的な、関係のある／親戚'},
#  {'neighborhood': '近所、地域'},
#  {'both A and B': 'AもBもどちらも'},
#  {'permanent': '常設の、常雇用の、永久の'},
#  {'anticipate': '~を予期する、期待する'},
#  {'slightly': 'わずかに、少し'},
#  {'value': '価値／（物の価値）を評価する'},
#  {'complicated': '複雑な'},
#  {'undergo': '経験する'},
#  {'guarantee': '保証する／保証'},
#  {'excerpt': '抜粋、引用'},
#  {'mechanical': '機械の'},
#  {'dentist': '歯科医'},
#  {'native': '出身の／出身の人'},
#  {'handling': '取り扱い、出荷作業'},
#  {'occur': '起こる、発生する、行われる'},
#  {'column': '柱、コラム'},
#  {'findings': '（研究・調査の）結果、わかったこと'},
#  {'retail': '小売り、販売'},
#  {'exact': '正確な'},
#  {'invoice': '請求書、送り状'},
#  {'closely': '蜜に、注意深く'},
#  {'reminder': '再確認、お知らせ'},
#  {'loyal': '忠実な'},
#  {'record': '記録'},
#  {'promising': '有望な'},
#  {'clearance': '在庫一掃、清算、許可'},
#  {'commission': '委託する、委任する／委員会、歩合'},
#  {'curb': '縁石'},
#  {'committed': '熱心に取り組む、献身的な'},
#  {'receptionist': '受付係'},
#  {'comparison': '比較'},
#  {'pesticide': '殺虫剤'},
#  {'evidence': '証拠、証明'},
#  {'lean over ~': '~に身を乗り出す'},
#  {'border': '境、境界線'},
#  {'element': '（~を構成する）要素、成分'},
#  {'portrait': '肖像画'},
#  {'library': '図書館、蔵書、コレクション'},
#  {'defect': '欠陥、欠点'},
#  {'unload': '（荷物など）を降ろす'},
#  {'intersection': '交差点'},
#  {'minimize': '~を最小限にする'},
#  {'bulletin': '掲示、公報'},
#  {'failure': '失敗、故障'},
#  {'caution': '注意、警告'},
#  {'multiple': '複数の'},
#  {'goods': '商品'},
#  {'optimistic': '楽観的な'},
#  {'exam': '試験'},
#  {'revenue': '収支、歳入'},
#  {'mission': '使命、任務'},
#  {'recent': '最近の'},
#  {'participant': '参加者、関係者'},
#  {'suppose': '（~を真実だと）思う'},
#  {'aim': '目標、狙い／目指す、狙う'},
#  {'plumbing': '配管（工事）'},
#  {'wage': '賃金、給料'},
#  {'comprehensive': '総合的な、包括的な、理解力のある'},
#  {'investigation': '調査'},
#  {'purpose': '目的、目標'},
#  {'feature': '特集、特徴'},
#  {'actual': '実際の、現実の'},
#  {'takeoff': '離陸、出発'},
#  {'employment': '雇用'},
#  {'statement': '明細書、声明'},
#  {'upset': '動揺した／~を動揺させる'},
#  {'field': '分野、競技場'},
#  {'advantage': '有利、利点、強み'},
#  {'audience': '聴衆、観客'},
#  {'product': '製品、生産物'},
#  {'adjustment': '調整、調節'},
#  {'theme': 'テーマ、論題'},
#  {'lighthouse': '灯台'},
#  {'summarize': '要約する'},
#  {'remark': '言葉、コメント、意見'},
#  {'slight': 'ほんのわずかの'},
#  {'fountain': '噴水'},
#  {'enroll': '登録する、入会する、入学する'},
#  {'improvement': '改善、向上'},
#  {'routine': '所定の、日常的に行われる'},
#  {'shelf': '棚'},
#  {'oppointment': '会う約束、アポイントメント'},
#  {'item': '項目、品物'},
#  {'mortgage': '抵当／~を抵当に入れる'},
#  {'couple': '二つ、一対'},
#  {'outstanding': '傑出した、未払いの'},
#  {'reception': '歓迎会、パーティー、受領'},
#  {'certain': '特定の、確かで'},
#  {'commuter': '通勤者'},
#  {'solid': '固い、堅実な、まじめな'},
#  {'recession': '後退'},
#  {'deserted': '人の気配がない、さびれた'},
#  {'sealed': '密封された'},
#  {'current': '現在の'},
#  {'acting': '代理の、事実上の'},
#  {'culinary': '料理の'},
#  {'primary': '主な、本来の'},
#  {'dominant': '支配的な、圧倒的な、主要な'},
#  {'independent': '独立した、自主性のある'},
#  {'viable': '実行可能な'},
#  {'capable': '能力がある、~できる'},
#  {'attractive': '魅力的な'},
#  {'satisfactory': '満足な'},
#  {'determined': '断固とした、決定した'},
#  {'physical': '身体的な、物質的な'},
#  {'principal': '主な、第一の'},
#  {'domestic': '国内の'},
#  {'mobile': '移動式の'},
#  {'functional': '機能的な、実用的な'},
#  {'round-trip': '往復旅行の'},
#  {'rewarding': 'やりがいのある、実りの多い'},
#  {'tight': 'きつい、ぎっしり詰まった'},
#  {'out of order': '故障して'},
#  {'nearby': '近くの'},
#  {'whole': '全体の'},
#  {'respectful': '礼儀正しい、丁寧な'},
#  {'protective': '保護用の'},
#  {'another': 'もう一つの、別の'},
#  {'seated': '座った、座らせられた'},
#  {'abroad': '海外で、国外へ'},
#  {'athletic': '運動好きな、運動選手用の'},
#  {'greatly': '大いに、非常に'},
#  {'price': '価格、値段／~に値段をつける'},
#  {'on average': '平均して'},
#  {'schedule': '~を予定する／予定、スケジュール'},
#  {'accordingly': 'したがって、それに応じて'},
#  {'trustworthy': '信頼できる、信用できる'},
#  {'promptly': 'すばやく、きっかりに、即座に'},
#  {'superior': '優れた、上等の'},
#  {'consistently': '常に、変わらず'},
#  {'registration': '登録、記名'},
#  {'otherwise': 'さもなければ'},
#  ...]

# %%
len(word_list_2)
# Out:
# 2000

# %%
url = "https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/"
res = requests.get(url)
soup = BeautifulSoup(res.content, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="ja" prefix="og: http://ogp.me/ns#">
# <head>
# <!-- anti-flicker snippet (recommended)  -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'async-hide','dataLayer',4000,
# {'OPT-KL8K6T7':true});</script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-126621516-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-126621516-1', { 'optimize_id': 'OPT-KL8K6T7'});
# </script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://english.kohsukenemoto.com/xmlrpc.php" rel="pingback"/>
# <script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
# <script>var et_site_url='https://english.kohsukenemoto.com';var et_post_id='382';function et_core_page_resource_fallback(a,b){"undefined"===typeof b&&(b=a.sheet.cssRules&&0===a.sheet.cssRules.length);b&&(a.onerror=null,a.onload=null,a.href?a.href=et_site_url+"/?et_core_page_resource="+a.id+et_post_id:a.src&&(a.src=et_site_url+"/?et_core_page_resource="+a.id+et_post_id))}
# </script>
# <!-- Search Engine Optimization by Rank Math - https://s.rankmath.com/home -->
# <title>TOEIC頻出英単語一覧【800点取得したい方必見！】</title>
# <meta content="TOEIC頻出英単語を一対一で一覧にまとめました。よくTOEICに出てくるような名詞、形容詞、副詞、動詞をアップしてあります。単語一覧以外にも、単語の見分け方や使い分けなどのポイントも解説しています。800点を目指している方は、チェックしてみてください。" name="description"/>
# <meta content="follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large" name="robots"/>
# <link href="https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/" rel="canonical"/>
# <meta content="ja_JP" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="TOEIC頻出英単語一覧【800点取得したい方必見！】" property="og:title"/>
# <meta content="TOEIC頻出英単語を一対一で一覧にまとめました。よくTOEICに出てくるような名詞、形容詞、副詞、動詞をアップしてあります。単語一覧以外にも、単語の見分け方や使い分けなどのポイントも解説しています。800点を目指している方は、チェックしてみてください。" property="og:description"/>
# <meta content="https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/" property="og:url"/>
# <meta content="EnglishMagazine" property="og:site_name"/>
# <meta content="TOEIC英単語" property="article:section"/>
# <meta content="2019-07-15T02:28:57+09:00" property="og:updated_time"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="TOEIC頻出英単語一覧【800点取得したい方必見！】" name="twitter:title"/>
# <meta content="TOEIC頻出英単語を一対一で一覧にまとめました。よくTOEICに出てくるような名詞、形容詞、副詞、動詞をアップしてあります。単語一覧以外にも、単語の見分け方や使い分けなどのポイントも解説しています。800点を目指している方は、チェックしてみてください。" name="twitter:description"/>
# <script class="rank-math-schema" type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": [
#                 "Person",
#                 "Organization"
#             ],
#             "@id": "https://english.kohsukenemoto.com/#person",
#             "name": "EnglishMagazine",
#             "logo": {
#                 "@type": "ImageObject",
#                 "url": false
#             },
#             "image": {
#                 "@type": "ImageObject",
#                 "url": false
#             }
#         },
#         {
#             "@type": "WebSite",
#             "@id": "https://english.kohsukenemoto.com/#website",
#             "url": "https://english.kohsukenemoto.com",
#             "name": "EnglishMagazine",
#             "publisher": {
#                 "@id": "https://english.kohsukenemoto.com/#person"
#             },
#             "inLanguage": "ja",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": "https://english.kohsukenemoto.com/?s={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             }
#         },
#         {
#             "@type": "BreadcrumbList",
#             "@id": "https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/#breadcrumb",
#             "itemListElement": [
#                 {
#                     "@type": "ListItem",
#                     "position": 1,
#                     "item": {
#                         "@id": "https://english.kohsukenemoto.com",
#                         "name": "\u30db\u30fc\u30e0"
#                     }
#                 },
#                 {
#                     "@type": "ListItem",
#                     "position": 2,
#                     "item": {
#                         "@id": "https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/",
#                         "name": "TOEIC\u983b\u51fa\u82f1\u5358\u8a9e\u4e00\u89a7\u3010800\u70b9\u53d6\u5f97\u3057\u305f\u3044\u65b9\u5fc5\u898b\uff01\u3011"
#                     }
#                 }
#             ]
#         },
#         {
#             "@type": "WebPage",
#             "@id": "https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/#webpage",
#             "url": "https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/",
#             "name": "TOEIC\u983b\u51fa\u82f1\u5358\u8a9e\u4e00\u89a7\u3010800\u70b9\u53d6\u5f97\u3057\u305f\u3044\u65b9\u5fc5\u898b\uff01\u3011",
#             "datePublished": "2019-02-08T17:17:29+09:00",
#             "dateModified": "2019-07-15T02:28:57+09:00",
#             "isPartOf": {
#                 "@id": "https://english.kohsukenemoto.com/#website"
#             },
#             "inLanguage": "ja",
#             "breadcrumb": {
#                 "@id": "https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/#breadcrumb"
#             }
#         },
#         {
#             "@type": "BlogPosting",
#             "headline": "TOEIC\u983b\u51fa\u82f1\u5358\u8a9e\u4e00\u89a7\u3010800\u70b9\u53d6\u5f97\u3057\u305f\u3044\u65b9\u5fc5\u898b\uff01\u3011",
#             "datePublished": "2019-02-08T17:17:29+09:00",
#             "dateModified": "2019-07-15T02:28:57+09:00",
#             "author": {
#                 "@type": "Person",
#                 "name": "\u6839\u672c\u8015\u8f14"
#             },
#             "publisher": {
#                 "@id": "https://english.kohsukenemoto.com/#person"
#             },
#             "description": "TOEIC\u983b\u51fa\u82f1\u5358\u8a9e\u3092\u4e00\u5bfe\u4e00\u3067\u4e00\u89a7\u306b\u307e\u3068\u3081\u307e\u3057\u305f\u3002\u3088\u304fTOEIC\u306b\u51fa\u3066\u304f\u308b\u3088\u3046\u306a\u540d\u8a5e\u3001\u5f62\u5bb9\u8a5e\u3001\u526f\u8a5e\u3001\u52d5\u8a5e\u3092\u30a2\u30c3\u30d7\u3057\u3066\u3042\u308a\u307e\u3059\u3002\u5358\u8a9e\u4e00\u89a7\u4ee5\u5916\u306b\u3082\u3001\u5358\u8a9e\u306e\u898b\u5206\u3051\u65b9\u3084\u4f7f\u3044\u5206\u3051\u306a\u3069\u306e\u30dd\u30a4\u30f3\u30c8\u3082\u89e3\u8aac\u3057\u3066\u3044\u307e\u3059\u3002800\u70b9\u3092\u76ee\u6307\u3057\u3066\u3044\u308b\u65b9\u306f\u3001\u30c1\u30a7\u30c3\u30af\u3057\u3066\u307f\u3066\u304f\u3060\u3055\u3044\u3002",
#             "@id": "https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/#richSnippet",
#             "isPartOf": {
#                 "@id": "https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/#webpage"
#             },
#             "inLanguage": "ja",
#             "mainEntityOfPage": {
#                 "@id": "https://english.kohsukenemoto.com/toeic/toeic-vocabulary/lists/#webpage"
#             }
#         }
#     ]
# }</script>
# <!-- /Rank Math WordPress SEO plugin -->
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://english.kohsukenemoto.com/feed/" rel="alternate" title="EnglishMagazine » フィード" type="application/rss+xml"/>
# <link href="https://english.kohsukenemoto.com/comments/feed/" rel="alternate" title="EnglishMagazine » コメントフィード" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/english.kohsukenemoto.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.5.3"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <meta content="Divi Chile Theme v.1.0" name="generator"/><style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://english.kohsukenemoto.com/wp-includes/css/dist/block-library/style.min.css?ver=5.5.3" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://english.kohsukenemoto.com/wp-content/plugins/table-of-contents-plus/screen.min.css?ver=2002" id="toc-screen-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://english.kohsukenemoto.com/wp-content/themes/Divi/style.css?ver=5.5.3" id="parent-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//fonts.googleapis.com/earlyaccess/notosansjapanese.css" id="et-gf-japanese-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://english.kohsukenemoto.com/wp-content/themes/divi-chile-theme/style.css?ver=4.6.5" id="divi-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://english.kohsukenemoto.com/wp-includes/css/dashicons.min.css?ver=5.5.3" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jquery-core-js" src="https://english.kohsukenemoto.com/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" type="text/javascript"></script>
# <script id="es6-promise-js" src="https://english.kohsukenemoto.com/wp-content/themes/Divi/core/admin/js/es6-promise.auto.min.js?ver=5.5.3" type="text/javascript"></script>
# <script id="et-core-api-spam-recaptcha-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var et_core_api_spam_recaptcha = {"site_key":"","page_action":{"action":"lists"}};
# /* ]]> */
# </script>
# <script id="et-core-api-spam-recaptcha-js" src="https://english.kohsukenemoto.com/wp-content/themes/Divi/core/admin/js/recaptcha.js?ver=5.5.3" type="text/javascript"></script>
# <script id="google_gtagjs-js" src="https://www.googletagmanager.com/gtag/js?id=UA-126621516-1" type="text/javascript"></script>
# <script id="google_gtagjs-js-after" type="text/javascript">
# window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-126621516-1');
# </script>
# <link href="https://english.kohsukenemoto.com/wp-json/" rel="https://api.w.org/"/><link href="https://english.kohsukenemoto.com/wp-json/wp/v2/posts/382" rel="alternate" type="application/json"/><link href="https://english.kohsukenemoto.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://english.kohsukenemoto.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.5.3" name="generator"/>
# <link href="https://english.kohsukenemoto.com/?p=382" rel="shortlink"/>
# <link href="https://english.kohsukenemoto.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fenglish.kohsukenemoto.com%2Ftoeic%2Ftoeic-vocabulary%2Flists%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://english.kohsukenemoto.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fenglish.kohsukenemoto.com%2Ftoeic%2Ftoeic-vocabulary%2Flists%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <style type="text/css">div#toc_container {width: 100%;}</style> <style id="bloody-hamburger-color" type="text/css">
#              .mobile_menu_bar:before { color: #87cefa !important; }
#          </style>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/><script src="https://www.googleoptimize.com/optimize.js?id=OPT-KL8K6T7"></script><link href="https://english.kohsukenemoto.com/wp-content/uploads/2018/10/cropped-EnglishMagazine-ロゴ.001-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://english.kohsukenemoto.com/wp-content/uploads/2018/10/cropped-EnglishMagazine-ロゴ.001-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://english.kohsukenemoto.com/wp-content/uploads/2018/10/cropped-EnglishMagazine-ロゴ.001-180x180.png" rel="apple-touch-icon"/>
# <meta content="https://english.kohsukenemoto.com/wp-content/uploads/2018/10/cropped-EnglishMagazine-ロゴ.001-270x270.png" name="msapplication-TileImage"/>
# <link href="https://english.kohsukenemoto.com/wp-content/et-cache/382/et-core-unified-382-16075565601775.min.css" id="et-core-unified-382-cached-inline-styles" onerror="et_core_page_resource_fallback(this, true)" onload="et_core_page_resource_fallback(this)" rel="stylesheet"/></head>
# <body class="post-template-default single single-post postid-382 single-format-standard et_pb_button_helper_class et_non_fixed_nav et_show_nav et_primary_nav_dropdown_animation_fade et_secondary_nav_dropdown_animation_fade et_header_style_centered et_pb_footer_columns3 et_cover_background et_pb_gutter et_pb_gutters3 et_pb_pagebuilder_layout et_no_sidebar et_divi_theme et-db et_minified_js et_minified_css">
# <div id="page-container">
# <header data-height-onload="100" id="main-header">
# <div class="container clearfix et_menu_container">
# <div class="logo_container">
# <span class="logo_helper"></span>
# <a href="https://english.kohsukenemoto.com/">
# <img alt="EnglishMagazine" data-height-percentage="100" id="logo" src="https://english.kohsukenemoto.com/wp-content/uploads/2018/10/englishmagazine.jpg"/>
# </a>
# </div>
# <div data-fixed-height="80" data-height="100" id="et-top-navigation">
# <nav id="top-menu-nav">
# <ul class="nav" id="top-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-62" id="menu-item-62"><a href="https://englishmagazine.me/free-course/">無料英文法コース</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-63" id="menu-item-63"><a href="https://englishmagazine.me/courses/">英語コース一覧</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-156" id="menu-item-156"><a href="https://english.kohsukenemoto.com/sentence-diagramming/">センテンス・ダイアグラミングとは？</a></li>
# </ul> </nav>
# <div id="et_mobile_nav_menu">
# <div class="mobile_nav closed">
# <span class="select_page">ページを選択</span>
# <span class="mobile_menu_bar mobile_menu_bar_toggle"></span>
# </div>
# </div> </div> <!-- #et-top-navigation -->
# </div> <!-- .container -->
# <div class="et_search_outer">
# <div class="container et_search_form_container">
# <form action="https://english.kohsukenemoto.com/" class="et-search-form" method="get" role="search">
# <input class="et-search-field" name="s" placeholder="検索 …" title="検索項目:" type="search" value=""/> </form>
# <span class="et_close_search_field"></span>
# </div>
# </div>
# </header> <!-- #main-header -->
# <div id="et-main-area">
# <div id="main-content">
# <div class="container">
# <div class="clearfix" id="content-area">
# <div id="left-area">
# <article class="et_pb_post post-382 post type-post status-publish format-standard hentry category-toeic-vocabulary" id="post-382">
# <div class="entry-content">
# <div class="et-boc" id="et-boc">
# <div class="et-l et-l--post">
# <div class="et_builder_inner_content et_pb_gutters3"><div class="et_pb_section et_pb_section_0 et_section_regular">
# <div class="et_pb_row et_pb_row_0">
# <div class="et_pb_column et_pb_column_4_4 et_pb_column_0 et_pb_css_mix_blend_mode_passthrough et-last-child">
# <div class="et_pb_module et_pb_post_title et_pb_post_title_0 et_pb_bg_layout_light et_pb_text_align_center">
# <div class="et_pb_title_container">
# <h1 class="entry-title">TOEIC頻出英単語一覧【800点取得したい方必見！】</h1><p class="et_pb_title_meta_container"> 執筆者 <span class="author vcard"><a href="https://english.kohsukenemoto.com/author/kohsukenemoto/" rel="author" title="投稿者 根本耕輔">根本耕輔</a></span> | <span class="published">更新日 2019年07月15日</span> | <a href="https://english.kohsukenemoto.com/category/toeic/toeic-vocabulary/" rel="category tag">TOEIC英単語</a></p>
# </div>
# </div>
# </div> <!-- .et_pb_column -->
# </div> <!-- .et_pb_row --><div class="et_pb_row et_pb_row_1">
# <div class="et_pb_column et_pb_column_1_3 et_pb_column_1 et_pb_css_mix_blend_mode_passthrough">
# <div class="et_pb_module et_pb_image et_pb_image_0">
# <span class="et_pb_image_wrap "><img alt="" height="auto" loading="lazy" src="https://english.kohsukenemoto.com/wp-content/uploads/2019/01/kohsuke小-1.png" title="" width="auto"/></span>
# </div>
# </div> <!-- .et_pb_column --><div class="et_pb_column et_pb_column_2_3 et_pb_column_2 et_pb_css_mix_blend_mode_passthrough et-last-child">
# <div class="et_pb_module et_pb_text et_pb_text_0 et_pb_text_align_left et_pb_bg_layout_light">
# <div class="et_pb_text_inner"><p>こんにちは、根本耕輔です。今日は、「TOEIC頻出英単語一覧」ということで、TOEICによく出てくる英単語を一覧にしておきました。具体的には、、、</p>
# <ul>
# <li>名詞の英単語</li>
# <li>形容詞の英単語</li>
# <li>副詞の英単語</li>
# </ul>
# <p>などをご紹介していきます。800点を目指している方は知っておきたい単語ばかりなので、チェックしてみてください。</p></div>
# </div> <!-- .et_pb_text -->
# </div> <!-- .et_pb_column -->
# </div> <!-- .et_pb_row --><div class="et_pb_row et_pb_row_2">
# <div class="et_pb_column et_pb_column_4_4 et_pb_column_3 et_pb_css_mix_blend_mode_passthrough et-last-child">
# <div class="et_pb_module et_pb_text et_pb_text_1 et_pb_text_align_left et_pb_bg_layout_light">
# <div class="et_pb_text_inner"><div class="yellowbox">
# <p><a href="https://english.kohsukenemoto.com/toeic-vocabulary-ebook">【限定】：TOEICに頻出の英単語&amp;英熟語をまとめたeBook「90日間でマスター！TOEIC頻出英単語&amp;超効率暗記法」をこちらから無料でゲットできます。</a></p>
# </div>
# <div class="toc_white no_bullets" id="toc_container"><p class="toc_title">目次</p><ul class="toc_list"><li><a href="#TOEIC"><span class="toc_number toc_depth_1">1</span> TOEIC頻出英単語一覧-名詞編</a><ul><li><a href="#01"><span class="toc_number toc_depth_2">1.1</span> 理由#01：試験・場面などジャンルによって使われる名詞は異なるから</a></li><li><a href="#02"><span class="toc_number toc_depth_2">1.2</span> 理由#02：名詞は使われる頻度が高い</a></li><li><a href="#03"><span class="toc_number toc_depth_2">1.3</span> 理由#03：種類が多い</a></li></ul></li><li><a href="#TOEIC-2"><span class="toc_number toc_depth_1">2</span> TOEIC頻出英単語一覧-動詞編</a><ul><li><a href="#i"><span class="toc_number toc_depth_2">2.1</span> 自動詞と他動詞の区別</a></li><li><a href="#i-2"><span class="toc_number toc_depth_2">2.2</span> 似た意味の動詞の使い分け</a></li></ul></li><li><a href="#TOEIC-3"><span class="toc_number toc_depth_1">3</span> TOEIC頻出英単語一覧-形容詞編</a><ul><li><a href="#i-3"><span class="toc_number toc_depth_2">3.1</span> 形容詞の役割</a></li><li><a href="#i-4"><span class="toc_number toc_depth_2">3.2</span> 形容詞の接尾語</a></li></ul></li><li><a href="#TOEIC-4"><span class="toc_number toc_depth_1">4</span> TOEIC頻出英単語一覧-副詞編</a><ul><li><a href="#i-5"><span class="toc_number toc_depth_2">4.1</span> 副詞の役割</a></li><li><a href="#i-6"><span class="toc_number toc_depth_2">4.2</span> 副詞の接尾語</a></li></ul></li></ul></div>
# <h2><span id="TOEIC">TOEIC頻出英単語一覧-名詞編</span></h2>
# <p>英単語はどんな順番で覚えていくべきなのか悩んだことはありませんか？「高校時代に、学校の先生から動詞を先に覚えなさいと言われました。」これは、ある受講生からの質問でした。この質問に対して、僕は「名詞」から覚えていきましょう。と答えました。その理由は以下の3つです。</p>
# <h3><span id="01">理由#01：試験・場面などジャンルによって使われる名詞は異なるから</span></h3>
# <p>例えば、医学試験とTOEICで出そうな単語を考えて見てください。医学試験を受けたことがなくても、だいたい医学関係の単語ばかり出題されるだろうなというのはわかりますよね。</p>
# <p>では、TOEICはどうでしょうか。医学関係の単語は出るでしょうか。ほとんど、出ませんよね。TOEICはビジネスや日常的に使用される単語が使用されます。ジャンルが違うと、使用される単語が違ってくるんです。</p>
# <p>「でも、それって名詞に限ったことじゃないですよね？」確かに、名詞に限ったことではありません。動詞だってジャンルによって異なります。しかし、圧倒的に異なるのは名詞なのです。</p>
# <h3><span id="02">理由#02：名詞は使われる頻度が高い</span></h3>
# <p>文型を確認して見ましょう。</p>
# <ul>
# <li>第1文型：S V→S</li>
# <li>第2文型：S V C→S C</li>
# <li>第3文型：S V O→S O</li>
# <li>第4文型：S V O O→S O O</li>
# <li>第5文型：S V O C→S O C</li>
# </ul>
# <p>S、O、Cには名詞を入れることができます。（Cには形容詞も入りますが。）圧倒的に名詞が使用される確率が高いということがわかりますよね。これも名詞を優先的にやっていく理由の1つです。。</p>
# <h3><span id="03">理由#03：種類が多い</span></h3>
# <p>最後の理由は種類が多いということなのですが、名詞は種類が多く、それ故に言い換え（パラフレーズ）ができないものが多いのです。逆に動詞は言い換えができたり、似た表現が多く存在します。例えば、S V that~の形を取る動詞は「Sは~という。」と訳せてしまいます。</p>
# <p>つまり、こういった形を取る動詞は暗記していなくてもthatがあるというだけで訳し方がわかるので、TOEICの場合はそれほど重要ではありません。以上の3つから名詞を優先的に覚えていきましょう。</p>
# <table border="1">
# <tbody>
# <tr>
# <td style="text-align: center;">英単語</td>
# <td style="text-align: center;">意味</td>
# </tr>
# <tr>
# <td style="text-align: center;">agenda</td>
# <td style="text-align: center;">議題</td>
# </tr>
# <tr>
# <td style="text-align: center;">chairperson</td>
# <td style="text-align: center;">議長</td>
# </tr>
# <tr>
# <td style="text-align: center;">handout</td>
# <td style="text-align: center;">配布資料</td>
# </tr>
# <tr>
# <td style="text-align: center;">conference</td>
# <td style="text-align: center;">会議</td>
# </tr>
# <tr>
# <td style="text-align: center;">council</td>
# <td style="text-align: center;">会議</td>
# </tr>
# <tr>
# <td style="text-align: center;">meeting</td>
# <td style="text-align: center;">会議</td>
# </tr>
# <tr>
# <td style="text-align: center;">conversation</td>
# <td style="text-align: center;">会議</td>
# </tr>
# <tr>
# <td style="text-align: center;">majority</td>
# <td style="text-align: center;">大多数</td>
# </tr>
# <tr>
# <td style="text-align: center;">table</td>
# <td style="text-align: center;">表</td>
# </tr>
# <tr>
# <td style="text-align: center;">opinion</td>
# <td style="text-align: center;">意見</td>
# </tr>
# <tr>
# <td style="text-align: center;">issue</td>
# <td style="text-align: center;">問題</td>
# </tr>
# <tr>
# <td style="text-align: center;">minute(s)</td>
# <td style="text-align: center;">議事録</td>
# </tr>
# <tr>
# <td style="text-align: center;">content</td>
# <td style="text-align: center;">内容</td>
# </tr>
# <tr>
# <td style="text-align: center;">detail</td>
# <td style="text-align: center;">詳細</td>
# </tr>
# <tr>
# <td style="text-align: center;">suggestion</td>
# <td style="text-align: center;">提案</td>
# </tr>
# <tr>
# <td style="text-align: center;">argument</td>
# <td style="text-align: center;">議論</td>
# </tr>
# <tr>
# <td style="text-align: center;">committee</td>
# <td style="text-align: center;">委員会</td>
# </tr>
# <tr>
# <td style="text-align: center;">representative</td>
# <td style="text-align: center;">代表者</td>
# </tr>
# <tr>
# <td style="text-align: center;">church</td>
# <td style="text-align: center;">教会</td>
# </tr>
# <tr>
# <td style="text-align: center;">business</td>
# <td style="text-align: center;">商取引</td>
# </tr>
# <tr>
# <td style="text-align: center;">health</td>
# <td style="text-align: center;">健康</td>
# </tr>
# <tr>
# <td style="text-align: center;">fever</td>
# <td style="text-align: center;">熱</td>
# </tr>
# <tr>
# <td style="text-align: center;">persistence</td>
# <td style="text-align: center;">粘り強さ</td>
# </tr>
# <tr>
# <td style="text-align: center;">stimulus</td>
# <td style="text-align: center;">刺激</td>
# </tr>
# <tr>
# <td style="text-align: center;">hospital</td>
# <td style="text-align: center;">病院</td>
# </tr>
# <tr>
# <td style="text-align: center;">hospitality</td>
# <td style="text-align: center;">おもてなし</td>
# </tr>
# <tr>
# <td style="text-align: center;">plague</td>
# <td style="text-align: center;">疫病</td>
# </tr>
# <tr>
# <td style="text-align: center;">breath</td>
# <td style="text-align: center;">呼吸</td>
# </tr>
# <tr>
# <td style="text-align: center;">exercise</td>
# <td style="text-align: center;">運動</td>
# </tr>
# <tr>
# <td style="text-align: center;">workout</td>
# <td style="text-align: center;">運動</td>
# </tr>
# <tr>
# <td style="text-align: center;">ache</td>
# <td style="text-align: center;">痛み、痛む</td>
# </tr>
# <tr>
# <td style="text-align: center;">organ</td>
# <td style="text-align: center;">臓器</td>
# </tr>
# <tr>
# <td style="text-align: center;">appliance</td>
# <td style="text-align: center;">器具</td>
# </tr>
# <tr>
# <td style="text-align: center;">fatal</td>
# <td style="text-align: center;">致命的な</td>
# </tr>
# <tr>
# <td style="text-align: center;">wound</td>
# <td style="text-align: center;">傷</td>
# </tr>
# <tr>
# <td style="text-align: center;">ritual</td>
# <td style="text-align: center;">儀式</td>
# </tr>
# <tr>
# <td style="text-align: center;">restoration</td>
# <td style="text-align: center;">回復</td>
# </tr>
# <tr>
# <td style="text-align: center;">preservation</td>
# <td style="text-align: center;">保存</td>
# </tr>
# <tr>
# <td style="text-align: center;">bite</td>
# <td style="text-align: center;">食事</td>
# </tr>
# <tr>
# <td style="text-align: center;">analysis</td>
# <td style="text-align: center;">分析</td>
# </tr>
# <tr>
# <td style="text-align: center;">weight</td>
# <td style="text-align: center;">重さ、体重</td>
# </tr>
# <tr>
# <td style="text-align: center;">height</td>
# <td style="text-align: center;">高さ</td>
# </tr>
# <tr>
# <td style="text-align: center;">width</td>
# <td style="text-align: center;">幅</td>
# </tr>
# <tr>
# <td style="text-align: center;">length</td>
# <td style="text-align: center;">長さ</td>
# </tr>
# <tr>
# <td style="text-align: center;">consensus</td>
# <td style="text-align: center;">同意</td>
# </tr>
# <tr>
# <td style="text-align: center;">viewpoint</td>
# <td style="text-align: center;">観点</td>
# </tr>
# <tr>
# <td style="text-align: center;">standpoint</td>
# <td style="text-align: center;">観点</td>
# </tr>
# <tr>
# <td style="text-align: center;">perspective</td>
# <td style="text-align: center;">観点</td>
# </tr>
# <tr>
# <td style="text-align: center;">presentation</td>
# <td style="text-align: center;">プレゼンテーション</td>
# </tr>
# <tr>
# <td style="text-align: center;">resolution</td>
# <td style="text-align: center;">決議、決定</td>
# </tr>
# <tr>
# <td style="text-align: center;">subjects</td>
# <td style="text-align: center;">テーマ(主題)</td>
# </tr>
# <tr>
# <td style="text-align: center;">summary</td>
# <td style="text-align: center;">概要、要約</td>
# </tr>
# <tr>
# <td style="text-align: center;">diagram</td>
# <td style="text-align: center;">図</td>
# </tr>
# <tr>
# <td style="text-align: center;">newsletter</td>
# <td style="text-align: center;">会報、ニュースレター</td>
# </tr>
# <tr>
# <td style="text-align: center;">announcement</td>
# <td style="text-align: center;">発表</td>
# </tr>
# <tr>
# <td style="text-align: center;">decision</td>
# <td style="text-align: center;">決定</td>
# </tr>
# <tr>
# <td style="text-align: center;">initiative</td>
# <td style="text-align: center;">主導権</td>
# </tr>
# <tr>
# <td style="text-align: center;">discipline</td>
# <td style="text-align: center;">規律</td>
# </tr>
# <tr>
# <td style="text-align: center;">agreement</td>
# <td style="text-align: center;">協定</td>
# </tr>
# <tr>
# <td style="text-align: center;">material</td>
# <td style="text-align: center;">材料</td>
# </tr>
# <tr>
# <td style="text-align: center;">exit</td>
# <td style="text-align: center;">出口</td>
# </tr>
# <tr>
# <td style="text-align: center;">entrance</td>
# <td style="text-align: center;">入り口、入学</td>
# </tr>
# <tr>
# <td style="text-align: center;">entry</td>
# <td style="text-align: center;">登録</td>
# </tr>
# <tr>
# <td style="text-align: center;">admission</td>
# <td style="text-align: center;">入学</td>
# </tr>
# <tr>
# <td style="text-align: center;">membership</td>
# <td style="text-align: center;">会員</td>
# </tr>
# <tr>
# <td style="text-align: center;">registration</td>
# <td style="text-align: center;">登録</td>
# </tr>
# <tr>
# <td style="text-align: center;">term</td>
# <td style="text-align: center;">条件※期間の意味もあ る</td>
# </tr>
# <tr>
# <td style="text-align: center;">option</td>
# <td style="text-align: center;">選択</td>
# </tr>
# <tr>
# <td style="text-align: center;">procedure</td>
# <td style="text-align: center;">手続き</td>
# </tr>
# <tr>
# <td style="text-align: center;">career</td>
# <td style="text-align: center;">職歴</td>
# </tr>
# <tr>
# <td style="text-align: center;">background</td>
# <td style="text-align: center;">経歴</td>
# </tr>
# <tr>
# <td style="text-align: center;">title</td>
# <td style="text-align: center;">肩書き</td>
# </tr>
# <tr>
# <td style="text-align: center;">deadline</td>
# <td style="text-align: center;">締め切り</td>
# </tr>
# <tr>
# <td style="text-align: center;">interview</td>
# <td style="text-align: center;">面接(する)</td>
# </tr>
# <tr>
# <td style="text-align: center;">license</td>
# <td style="text-align: center;">免許</td>
# </tr>
# <tr>
# <td style="text-align: center;">requirements</td>
# <td style="text-align: center;">資格</td>
# </tr>
# <tr>
# <td style="text-align: center;">qualifications</td>
# <td style="text-align: center;">資格</td>
# </tr>
# <tr>
# <td style="text-align: center;">certificate</td>
# <td style="text-align: center;">証明書</td>
# </tr>
# <tr>
# <td style="text-align: center;">contract</td>
# <td style="text-align: center;">契約</td>
# </tr>
# <tr>
# <td style="text-align: center;">signature</td>
# <td style="text-align: center;">署名</td>
# </tr>
# <tr>
# <td style="text-align: center;">enclosure</td>
# <td style="text-align: center;">同封物</td>
# </tr>
# <tr>
# <td style="text-align: center;">résumé</td>
# <td style="text-align: center;">履歴書</td>
# </tr>
# <tr>
# <td style="text-align: center;">specifications</td>
# <td style="text-align: center;">仕様書</td>
# </tr>
# <tr>
# <td style="text-align: center;">pedestrian</td>
# <td style="text-align: center;">歩行者</td>
# </tr>
# <tr>
# <td style="text-align: center;">university</td>
# <td style="text-align: center;">(総合)大学</td>
# </tr>
# <tr>
# <td style="text-align: center;">college</td>
# <td style="text-align: center;">(単科)大学</td>
# </tr>
# <tr>
# <td style="text-align: center;">cousin</td>
# <td style="text-align: center;">いとこ</td>
# </tr>
# <tr>
# <td style="text-align: center;">aunt</td>
# <td style="text-align: center;">おば</td>
# </tr>
# <tr>
# <td style="text-align: center;">uncle</td>
# <td style="text-align: center;">おじ</td>
# </tr>
# <tr>
# <td style="text-align: center;">daughter</td>
# <td style="text-align: center;">娘</td>
# </tr>
# <tr>
# <td style="text-align: center;">son</td>
# <td style="text-align: center;">息子</td>
# </tr>
# <tr>
# <td style="text-align: center;">platform</td>
# <td style="text-align: center;">“(駅の)プラットフォ<br/> ーム”</td>
# </tr>
# <tr>
# <td style="text-align: center;">partnership</td>
# <td style="text-align: center;">提携</td>
# </tr>
# <tr>
# <td style="text-align: center;">threat</td>
# <td style="text-align: center;">脅威</td>
# </tr>
# <tr>
# <td style="text-align: center;">astronaut</td>
# <td style="text-align: center;">宇宙飛行士</td>
# </tr>
# <tr>
# <td style="text-align: center;">behavior</td>
# <td style="text-align: center;">振る舞い</td>
# </tr>
# <tr>
# <td style="text-align: center;">bush</td>
# <td style="text-align: center;">低木</td>
# </tr>
# <tr>
# <td style="text-align: center;">assignment</td>
# <td style="text-align: center;">任務</td>
# </tr>
# <tr>
# <td style="text-align: center;">sales</td>
# <td style="text-align: center;">販売</td>
# </tr>
# <tr>
# <td style="text-align: center;">notice</td>
# <td style="text-align: center;">通知</td>
# </tr>
# <tr>
# <td style="text-align: center;">unemployment</td>
# <td style="text-align: center;">失業</td>
# </tr>
# <tr>
# <td style="text-align: center;">ability</td>
# <td style="text-align: center;">能力</td>
# </tr>
# <tr>
# <td style="text-align: center;">generosity</td>
# <td style="text-align: center;">気前の良さ</td>
# </tr>
# <tr>
# <td style="text-align: center;">attitude</td>
# <td style="text-align: center;">態度</td>
# </tr>
# <tr>
# <td style="text-align: center;">pleasure</td>
# <td style="text-align: center;">喜び</td>
# </tr>
# <tr>
# <td style="text-align: center;">character</td>
# <td style="text-align: center;">性格</td>
# </tr>
# <tr>
# <td style="text-align: center;">mood</td>
# <td style="text-align: center;">気分</td>
# </tr>
# <tr>
# <td style="text-align: center;">privilege</td>
# <td style="text-align: center;">特権</td>
# </tr>
# <tr>
# <td style="text-align: center;">disappointment</td>
# <td style="text-align: center;">失意</td>
# </tr>
# <tr>
# <td style="text-align: center;">subordinate</td>
# <td style="text-align: center;">同僚</td>
# </tr>
# <tr>
# <td style="text-align: center;">desire</td>
# <td style="text-align: center;">願望</td>
# </tr>
# <tr>
# <td style="text-align: center;">strategy</td>
# <td style="text-align: center;">戦略</td>
# </tr>
# <tr>
# <td style="text-align: center;">affair</td>
# <td style="text-align: center;">問題</td>
# </tr>
# <tr>
# <td style="text-align: center;">controversy</td>
# <td style="text-align: center;">論争</td>
# </tr>
# <tr>
# <td style="text-align: center;">machineries</td>
# <td style="text-align: center;">機械</td>
# </tr>
# <tr>
# <td style="text-align: center;">components</td>
# <td style="text-align: center;">部品</td>
# </tr>
# <tr>
# <td style="text-align: center;">statue</td>
# <td style="text-align: center;">像</td>
# </tr>
# <tr>
# <td style="text-align: center;">drawing</td>
# <td style="text-align: center;">スケッチ</td>
# </tr>
# <tr>
# <td style="text-align: center;">transformation</td>
# <td style="text-align: center;">変化</td>
# </tr>
# <tr>
# <td style="text-align: center;">assembly</td>
# <td style="text-align: center;">組み立て</td>
# </tr>
# <tr>
# <td style="text-align: center;">vacancy</td>
# <td style="text-align: center;">欠員</td>
# </tr>
# <tr>
# <td style="text-align: center;">lack</td>
# <td style="text-align: center;">欠員</td>
# </tr>
# <tr>
# <td style="text-align: center;">(job) opening</td>
# <td style="text-align: center;">欠員</td>
# </tr>
# <tr>
# <td style="text-align: center;">employee</td>
# <td style="text-align: center;">社員</td>
# </tr>
# <tr>
# <td style="text-align: center;">applicant</td>
# <td style="text-align: center;">候補者</td>
# </tr>
# <tr>
# <td style="text-align: center;">candidate</td>
# <td style="text-align: center;">候補者</td>
# </tr>
# <tr>
# <td style="text-align: center;">application</td>
# <td style="text-align: center;">申し込み</td>
# </tr>
# <tr>
# <td style="text-align: center;">panel</td>
# <td style="text-align: center;">委員会</td>
# </tr>
# <tr>
# <td style="text-align: center;">accomplishment</td>
# <td style="text-align: center;">業績</td>
# </tr>
# <tr>
# <td style="text-align: center;">temperature</td>
# <td style="text-align: center;">温度</td>
# </tr>
# <tr>
# <td style="text-align: center;">odor</td>
# <td style="text-align: center;">におい(悪臭)</td>
# </tr>
# <tr>
# <td style="text-align: center;">sink</td>
# <td style="text-align: center;">流し</td>
# </tr>
# <tr>
# <td style="text-align: center;">lawn</td>
# <td style="text-align: center;">芝生</td>
# </tr>
# <tr>
# <td style="text-align: center;">basement</td>
# <td style="text-align: center;">地下室</td>
# </tr>
# <tr>
# <td style="text-align: center;">ladder</td>
# <td style="text-align: center;">はしご</td>
# </tr>
# <tr>
# <td style="text-align: center;">message</td>
# <td style="text-align: center;">伝言</td>
# </tr>
# <tr>
# <td style="text-align: center;">foundation</td>
# <td style="text-align: center;">設立、基礎</td>
# </tr>
# <tr>
# <td style="text-align: center;">remainder</td>
# <td style="text-align: center;">残り</td>
# </tr>
# <tr>
# <td style="text-align: center;">diversity</td>
# <td style="text-align: center;">多様性</td>
# </tr>
# <tr>
# <td style="text-align: center;">luxury</td>
# <td style="text-align: center;">贅沢</td>
# </tr>
# <tr>
# <td style="text-align: center;">prerequisite</td>
# <td style="text-align: center;">必要条件</td>
# </tr>
# <tr>
# <td style="text-align: center;">ethics</td>
# <td style="text-align: center;">倫理</td>
# </tr>
# <tr>
# <td style="text-align: center;">moral</td>
# <td style="text-align: center;">モラル、道徳</td>
# </tr>
# <tr>
# <td style="text-align: center;">policy</td>
# <td style="text-align: center;">主義</td>
# </tr>
# <tr>
# <td style="text-align: center;">stereotype</td>
# <td style="text-align: center;">固定観念</td>
# </tr>
# <tr>
# <td style="text-align: center;">bias</td>
# <td style="text-align: center;">偏見</td>
# </tr>
# <tr>
# <td style="text-align: center;">prejudice</td>
# <td style="text-align: center;">偏見</td>
# </tr>
# <tr>
# <td style="text-align: center;">construction</td>
# <td style="text-align: center;">建設</td>
# </tr>
# <tr>
# <td style="text-align: center;">aisle</td>
# <td style="text-align: center;">通路</td>
# </tr>
# <tr>
# <td style="text-align: center;">defect</td>
# <td style="text-align: center;">欠陥</td>
# </tr>
# <tr>
# <td style="text-align: center;">site</td>
# <td style="text-align: center;">場所</td>
# </tr>
# <tr>
# <td style="text-align: center;">investigation</td>
# <td style="text-align: center;">調査</td>
# </tr>
# <tr>
# <td style="text-align: center;">skyscraper</td>
# <td style="text-align: center;">超高層ビル</td>
# </tr>
# <tr>
# <td style="text-align: center;">inspection</td>
# <td style="text-align: center;">検査</td>
# </tr>
# <tr>
# <td style="text-align: center;">degree</td>
# <td style="text-align: center;">学位、程度</td>
# </tr>
# <tr>
# <td style="text-align: center;">undergraduate</td>
# <td style="text-align: center;">大学生、学部生</td>
# </tr>
# <tr>
# <td style="text-align: center;">graduate</td>
# <td style="text-align: center;">卒業生</td>
# </tr>
# <tr>
# <td style="text-align: center;">accommodation</td>
# <td style="text-align: center;">宿泊施設</td>
# </tr>
# <tr>
# <td style="text-align: center;">admission</td>
# <td style="text-align: center;">入場許可</td>
# </tr>
# <tr>
# <td style="text-align: center;">efficiency</td>
# <td style="text-align: center;">効率性</td>
# </tr>
# <tr>
# <td style="text-align: center;">code</td>
# <td style="text-align: center;">規則</td>
# </tr>
# <tr>
# <td style="text-align: center;">discipline</td>
# <td style="text-align: center;">規則</td>
# </tr>
# <tr>
# <td style="text-align: center;">study</td>
# <td style="text-align: center;">研究</td>
# </tr>
# <tr>
# <td style="text-align: center;">research</td>
# <td style="text-align: center;">研究</td>
# </tr>
# <tr>
# <td style="text-align: center;">diploma</td>
# <td style="text-align: center;">卒業証書</td>
# </tr>
# <tr>
# <td style="text-align: center;">lecture</td>
# <td style="text-align: center;">講義</td>
# </tr>
# <tr>
# <td style="text-align: center;">grade</td>
# <td style="text-align: center;">成績</td>
# </tr>
# <tr>
# <td style="text-align: center;">scholarship</td>
# <td style="text-align: center;">奨学金</td>
# </tr>
# <tr>
# <td style="text-align: center;">scholar</td>
# <td style="text-align: center;">学者</td>
# </tr>
# <tr>
# <td style="text-align: center;">institute</td>
# <td style="text-align: center;">機関</td>
# </tr>
# <tr>
# <td style="text-align: center;">establishment</td>
# <td style="text-align: center;">機関</td>
# </tr>
# <tr>
# <td style="text-align: center;">psychology</td>
# <td style="text-align: center;">心理学</td>
# </tr>
# <tr>
# <td style="text-align: center;">faculty</td>
# <td style="text-align: center;">学部</td>
# </tr>
# <tr>
# <td style="text-align: center;">savings</td>
# <td style="text-align: center;">貯蓄</td>
# </tr>
# <tr>
# <td style="text-align: center;">premise</td>
# <td style="text-align: center;">敷地、仮定</td>
# </tr>
# <tr>
# <td style="text-align: center;">staircase</td>
# <td style="text-align: center;">階段</td>
# </tr>
# <tr>
# <td style="text-align: center;">stairs</td>
# <td style="text-align: center;">階段</td>
# </tr>
# <tr>
# <td style="text-align: center;">stairway</td>
# <td style="text-align: center;">階段</td>
# </tr>
# <tr>
# <td style="text-align: center;">lodging</td>
# <td style="text-align: center;">宿泊施設</td>
# </tr>
# <tr>
# <td style="text-align: center;">directory</td>
# <td style="text-align: center;">住所</td>
# </tr>
# <tr>
# <td style="text-align: center;">government</td>
# <td style="text-align: center;">政府</td>
# </tr>
# <tr>
# <td style="text-align: center;">governor</td>
# <td style="text-align: center;">知事</td>
# </tr>
# <tr>
# <td style="text-align: center;">deregulation</td>
# <td style="text-align: center;">規制緩和</td>
# </tr>
# <tr>
# <td style="text-align: center;">talk</td>
# <td style="text-align: center;">会談</td>
# </tr>
# <tr>
# <td style="text-align: center;">authority</td>
# <td style="text-align: center;">権威</td>
# </tr>
# <tr>
# <td style="text-align: center;">function</td>
# <td style="text-align: center;">機能</td>
# </tr>
# <tr>
# <td style="text-align: center;">customs</td>
# <td style="text-align: center;">税関</td>
# </tr>
# <tr>
# <td style="text-align: center;">assistance</td>
# <td style="text-align: center;">支援</td>
# </tr>
# <tr>
# <td style="text-align: center;">issue</td>
# <td style="text-align: center;">問題</td>
# </tr>
# <tr>
# <td style="text-align: center;">right</td>
# <td style="text-align: center;">権利</td>
# </tr>
# <tr>
# <td style="text-align: center;">nation</td>
# <td style="text-align: center;">国家</td>
# </tr>
# <tr>
# <td style="text-align: center;">data</td>
# <td style="text-align: center;">データ</td>
# </tr>
# <tr>
# <td style="text-align: center;">loyalty</td>
# <td style="text-align: center;">忠誠</td>
# </tr>
# <tr>
# <td style="text-align: center;">statistics</td>
# <td style="text-align: center;">統計</td>
# </tr>
# <tr>
# <td style="text-align: center;">statement</td>
# <td style="text-align: center;">報告書、発言</td>
# </tr>
# <tr>
# <td style="text-align: center;">amendment</td>
# <td style="text-align: center;">修正案</td>
# </tr>
# <tr>
# <td style="text-align: center;">trade</td>
# <td style="text-align: center;">貿易</td>
# </tr>
# <tr>
# <td style="text-align: center;">engagement</td>
# <td style="text-align: center;">婚約</td>
# </tr>
# <tr>
# <td style="text-align: center;">immigrant</td>
# <td style="text-align: center;">移住</td>
# </tr>
# <tr>
# <td style="text-align: center;">public</td>
# <td style="text-align: center;">世間(市民)</td>
# </tr>
# <tr>
# <td style="text-align: center;">fortune</td>
# <td style="text-align: center;">財産</td>
# </tr>
# <tr>
# <td style="text-align: center;">estate</td>
# <td style="text-align: center;">財産</td>
# </tr>
# <tr>
# <td style="text-align: center;">assets</td>
# <td style="text-align: center;">財産</td>
# </tr>
# <tr>
# <td style="text-align: center;">holdings</td>
# <td style="text-align: center;">財産</td>
# </tr>
# <tr>
# <td style="text-align: center;">property</td>
# <td style="text-align: center;">財産</td>
# </tr>
# <tr>
# <td style="text-align: center;">real estate</td>
# <td style="text-align: center;">不動産</td>
# </tr>
# <tr>
# <td style="text-align: center;">railing</td>
# <td style="text-align: center;">手すり</td>
# </tr>
# <tr>
# <td style="text-align: center;">rent</td>
# <td style="text-align: center;">賃貸料</td>
# </tr>
# <tr>
# <td style="text-align: center;">ceiling</td>
# <td style="text-align: center;">天井</td>
# </tr>
# <tr>
# <td style="text-align: center;">furniture</td>
# <td style="text-align: center;">家具</td>
# </tr>
# <tr>
# <td style="text-align: center;">insurance</td>
# <td style="text-align: center;">保険</td>
# </tr>
# <tr>
# <td style="text-align: center;">shot</td>
# <td style="text-align: center;">注射</td>
# </tr>
# <tr>
# <td style="text-align: center;">cough</td>
# <td style="text-align: center;">せき</td>
# </tr>
# <tr>
# <td style="text-align: center;">patient</td>
# <td style="text-align: center;">忍耐</td>
# </tr>
# <tr>
# <td style="text-align: center;">insurance</td>
# <td style="text-align: center;">保険</td>
# </tr>
# <tr>
# <td style="text-align: center;">medicine</td>
# <td style="text-align: center;">薬</td>
# </tr>
# <tr>
# <td style="text-align: center;">illness</td>
# <td style="text-align: center;">病気</td>
# </tr>
# <tr>
# <td style="text-align: center;">disease</td>
# <td style="text-align: center;">病気</td>
# </tr>
# <tr>
# <td style="text-align: center;">sickness</td>
# <td style="text-align: center;">病気</td>
# </tr>
# <tr>
# <td style="text-align: center;">residence</td>
# <td style="text-align: center;">住宅</td>
# </tr>
# <tr>
# <td style="text-align: center;">household</td>
# <td style="text-align: center;">世帯</td>
# </tr>
# <tr>
# <td style="text-align: center;">resident</td>
# <td style="text-align: center;">居住者</td>
# </tr>
# <tr>
# <td style="text-align: center;">yard</td>
# <td style="text-align: center;">庭</td>
# </tr>
# <tr>
# <td style="text-align: center;">garden</td>
# <td style="text-align: center;">庭</td>
# </tr>
# <tr>
# <td style="text-align: center;">housing</td>
# <td style="text-align: center;">住宅</td>
# </tr>
# <tr>
# <td style="text-align: center;">housekeeping</td>
# <td style="text-align: center;">家事</td>
# </tr>
# <tr>
# <td style="text-align: center;">deck</td>
# <td style="text-align: center;">テラス</td>
# </tr>
# <tr>
# <td style="text-align: center;">suburbs</td>
# <td style="text-align: center;">郊外</td>
# </tr>
# <tr>
# <td style="text-align: center;">outskirt</td>
# <td style="text-align: center;">郊外</td>
# </tr>
# <tr>
# <td style="text-align: center;">neighborhood</td>
# <td style="text-align: center;">地域</td>
# </tr>
# <tr>
# <td style="text-align: center;">region</td>
# <td style="text-align: center;"></td>
# </tr>
# <tr>
# <td style="text-align: center;">pension</td>
# <td style="text-align: center;">年金</td>
# </tr>
# <tr>
# <td style="text-align: center;">land</td>
# <td style="text-align: center;">土地</td>
# </tr>
# <tr>
# <td style="text-align: center;">garbage</td>
# <td style="text-align: center;">ゴミ</td>
# </tr>
# <tr>
# <td style="text-align: center;">trash</td>
# <td style="text-align: center;">ゴミ</td>
# </tr>
# <tr>
# <td style="text-align: center;">litter</td>
# <td style="text-align: center;">ゴミ</td>
# </tr>
# <tr>
# <td style="text-align: center;">utilities</td>
# <td style="text-align: center;">公共料金</td>
# </tr>
# <tr>
# <td style="text-align: center;">subway</td>
# <td style="text-align: center;">地下鉄</td>
# </tr>
# <tr>
# <td style="text-align: center;">plan</td>
# <td style="text-align: center;">計画</td>
# </tr>
# <tr>
# <td style="text-align: center;">laundries</td>
# <td style="text-align: center;">洗濯物</td>
# </tr>
# <tr>
# <td style="text-align: center;">uniform</td>
# <td style="text-align: center;">制服</td>
# </tr>
# <tr>
# <td style="text-align: center;">remedy</td>
# <td style="text-align: center;">治療</td>
# </tr>
# <tr>
# <td style="text-align: center;">surgeon</td>
# <td style="text-align: center;">外科医</td>
# </tr>
# <tr>
# <td style="text-align: center;">physician</td>
# <td style="text-align: center;">内科医</td>
# </tr>
# <tr>
# <td style="text-align: center;">appetite</td>
# <td style="text-align: center;">食欲</td>
# </tr>
# <tr>
# <td style="text-align: center;">prescription</td>
# <td style="text-align: center;">処方箋</td>
# </tr>
# <tr>
# <td style="text-align: center;">diagnosis</td>
# <td style="text-align: center;">診断</td>
# </tr>
# <tr>
# <td style="text-align: center;">checkup</td>
# <td style="text-align: center;">検査</td>
# </tr>
# <tr>
# <td style="text-align: center;">cancer</td>
# <td style="text-align: center;">ガン</td>
# </tr>
# <tr>
# <td style="text-align: center;">diabetes</td>
# <td style="text-align: center;">糖尿病</td>
# </tr>
# <tr>
# <td style="text-align: center;">throat</td>
# <td style="text-align: center;">喉</td>
# </tr>
# <tr>
# <td style="text-align: center;">chest</td>
# <td style="text-align: center;">胸</td>
# </tr>
# <tr>
# <td style="text-align: center;">pain</td>
# <td style="text-align: center;">痛み</td>
# </tr>
# <tr>
# <td style="text-align: center;">strain</td>
# <td style="text-align: center;">ストレス</td>
# </tr>
# <tr>
# <td style="text-align: center;">court</td>
# <td style="text-align: center;">裁判所</td>
# </tr>
# <tr>
# <td style="text-align: center;">law</td>
# <td style="text-align: center;">法律 ※lowは「低い」</td>
# </tr>
# <tr>
# <td style="text-align: center;">lawyer</td>
# <td style="text-align: center;">弁護士</td>
# </tr>
# <tr>
# <td style="text-align: center;">attorney</td>
# <td style="text-align: center;">弁護士</td>
# </tr>
# <tr>
# <td style="text-align: center;">(law)suit</td>
# <td style="text-align: center;">訴訟</td>
# </tr>
# <tr>
# <td style="text-align: center;">justification</td>
# <td style="text-align: center;">正当化</td>
# </tr>
# <tr>
# <td style="text-align: center;">education</td>
# <td style="text-align: center;">教育</td>
# </tr>
# <tr>
# <td style="text-align: center;">landscape</td>
# <td style="text-align: center;">風景</td>
# </tr>
# <tr>
# <td style="text-align: center;">view</td>
# <td style="text-align: center;">風景</td>
# </tr>
# <tr>
# <td style="text-align: center;">scenery</td>
# <td style="text-align: center;">風景</td>
# </tr>
# <tr>
# <td style="text-align: center;">sight</td>
# <td style="text-align: center;">風景</td>
# </tr>
# <tr>
# <td style="text-align: center;">channel</td>
# <td style="text-align: center;">経路</td>
# </tr>
# <tr>
# <td style="text-align: center;">lane</td>
# ...
# <p>しかし、-lyがついていても、形容詞の場合もあります。例えば、rapidlyであれば形容詞の「rapid」に「ly」がついているので副詞ですし、effectivelyであれば形容詞の「effective」に「ly」がついて副詞になったものになります。</p>
# <p>では、形容詞になる-lyはどういうものなのでしょうか。それは、名詞+lyの形になっているものになります。例えば、毎月のという意味のmonthly。monthは月という名詞です。これにlyが付いていて、一見副詞に見えますが、形容詞なのです。</p>
# <p>他にもcostlyは、cost=費用にlyが付いているので形容詞になり、高価なという意味を持ちます。結構ややこしいのですが、名詞+lyは形容詞、形容詞+lyは副詞というように覚えておけば、Part5.6で出題された時にしっかりと対処できるようになります。</p>
# <table border="1">
# <tbody>
# <tr>
# <td style="text-align: center;">英単語</td>
# <td style="text-align: center;">意味</td>
# </tr>
# <tr>
# <td style="text-align: center;">plainly</td>
# <td style="text-align: center;">明らかに、わかりやすく</td>
# </tr>
# <tr>
# <td style="text-align: center;">sincerely</td>
# <td style="text-align: center;">心から、心底</td>
# </tr>
# <tr>
# <td style="text-align: center;">gradually</td>
# <td style="text-align: center;">徐々に</td>
# </tr>
# <tr>
# <td style="text-align: center;">slightly</td>
# <td style="text-align: center;">わずかに</td>
# </tr>
# <tr>
# <td style="text-align: center;">diligently</td>
# <td style="text-align: center;">勤勉に</td>
# </tr>
# <tr>
# <td style="text-align: center;">practically</td>
# <td style="text-align: center;">ほとんど</td>
# </tr>
# <tr>
# <td style="text-align: center;">completely</td>
# <td style="text-align: center;">完全に、全く</td>
# </tr>
# <tr>
# <td style="text-align: center;">probably</td>
# <td style="text-align: center;">おそらく</td>
# </tr>
# <tr>
# <td style="text-align: center;">collectively</td>
# <td style="text-align: center;">集団的に</td>
# </tr>
# <tr>
# <td style="text-align: center;">sometimes</td>
# <td style="text-align: center;">時々</td>
# </tr>
# <tr>
# <td style="text-align: center;">occasionally</td>
# <td style="text-align: center;">時々</td>
# </tr>
# <tr>
# <td style="text-align: center;">quite</td>
# <td style="text-align: center;">とても</td>
# </tr>
# <tr>
# <td style="text-align: center;">favorably</td>
# <td style="text-align: center;">好意的に</td>
# </tr>
# <tr>
# <td style="text-align: center;">efficiently</td>
# <td style="text-align: center;">効率的に</td>
# </tr>
# <tr>
# <td style="text-align: center;">apparently</td>
# <td style="text-align: center;">どうやら〜</td>
# </tr>
# <tr>
# <td style="text-align: center;">yet</td>
# <td style="text-align: center;">それにもかかわらず</td>
# </tr>
# <tr>
# <td style="text-align: center;">fortunately</td>
# <td style="text-align: center;">幸いにも</td>
# </tr>
# <tr>
# <td style="text-align: center;">currently</td>
# <td style="text-align: center;">現在は</td>
# </tr>
# <tr>
# <td style="text-align: center;">clearly</td>
# <td style="text-align: center;">明らかに</td>
# </tr>
# <tr>
# <td style="text-align: center;">possibly</td>
# <td style="text-align: center;">ひょっとしたら</td>
# </tr>
# <tr>
# <td style="text-align: center;">tightly</td>
# <td style="text-align: center;">きつく</td>
# </tr>
# <tr>
# <td style="text-align: center;">intermediately</td>
# <td style="text-align: center;">中間にあって、介在して</td>
# </tr>
# <tr>
# <td style="text-align: center;">approximately</td>
# <td style="text-align: center;">おおよそ</td>
# </tr>
# <tr>
# <td style="text-align: center;">roughly</td>
# <td style="text-align: center;">おおよそ</td>
# </tr>
# <tr>
# <td style="text-align: center;">adequately</td>
# <td style="text-align: center;">十分に</td>
# </tr>
# <tr>
# <td style="text-align: center;">lately</td>
# <td style="text-align: center;">最近</td>
# </tr>
# <tr>
# <td style="text-align: center;">steadily</td>
# <td style="text-align: center;">徐々に</td>
# </tr>
# <tr>
# <td style="text-align: center;">afterward</td>
# <td style="text-align: center;">あとで</td>
# </tr>
# <tr>
# <td style="text-align: center;">readily</td>
# <td style="text-align: center;">容易に</td>
# </tr>
# <tr>
# <td style="text-align: center;">temporarily</td>
# <td style="text-align: center;">一時的な</td>
# </tr>
# <tr>
# <td style="text-align: center;">overtime</td>
# <td style="text-align: center;">時間外に</td>
# </tr>
# <tr>
# <td style="text-align: center;">consequently</td>
# <td style="text-align: center;">その結果</td>
# </tr>
# <tr>
# <td style="text-align: center;">seldom</td>
# <td style="text-align: center;">滅多に〜しない</td>
# </tr>
# <tr>
# <td style="text-align: center;">rarely</td>
# <td style="text-align: center;">滅多に〜しない</td>
# </tr>
# <tr>
# <td style="text-align: center;">hardly</td>
# <td style="text-align: center;">ほとんど〜しない</td>
# </tr>
# <tr>
# <td style="text-align: center;">scarcely</td>
# <td style="text-align: center;">ほとんど〜しない</td>
# </tr>
# <tr>
# <td style="text-align: center;">highly</td>
# <td style="text-align: center;">非常に</td>
# </tr>
# <tr>
# <td style="text-align: center;">instead</td>
# <td style="text-align: center;">その代わりに</td>
# </tr>
# <tr>
# <td style="text-align: center;">further</td>
# <td style="text-align: center;">それ以上</td>
# </tr>
# <tr>
# <td style="text-align: center;">aloud</td>
# <td style="text-align: center;">声に出して</td>
# </tr>
# <tr>
# <td style="text-align: center;">certainly</td>
# <td style="text-align: center;">確かに、きっと</td>
# </tr>
# <tr>
# <td style="text-align: center;">surely</td>
# <td style="text-align: center;">確かに、きっと</td>
# </tr>
# <tr>
# <td style="text-align: center;">previously</td>
# <td style="text-align: center;">以前は</td>
# </tr>
# <tr>
# <td style="text-align: center;">formerly</td>
# <td style="text-align: center;">以前は</td>
# </tr>
# <tr>
# <td style="text-align: center;">originally</td>
# <td style="text-align: center;">最初は</td>
# </tr>
# <tr>
# <td style="text-align: center;">annually</td>
# <td style="text-align: center;">毎年</td>
# </tr>
# <tr>
# <td style="text-align: center;">concisely</td>
# <td style="text-align: center;">簡潔に</td>
# </tr>
# <tr>
# <td style="text-align: center;">relatively</td>
# <td style="text-align: center;">比較的</td>
# </tr>
# <tr>
# <td style="text-align: center;">recently</td>
# <td style="text-align: center;">最近</td>
# </tr>
# <tr>
# <td style="text-align: center;">forever</td>
# <td style="text-align: center;">永久に</td>
# </tr>
# <tr>
# <td style="text-align: center;">significantly</td>
# <td style="text-align: center;">著しく</td>
# </tr>
# <tr>
# <td style="text-align: center;">promptly</td>
# <td style="text-align: center;">即座に</td>
# </tr>
# <tr>
# <td style="text-align: center;">nearly</td>
# <td style="text-align: center;">ほとんど</td>
# </tr>
# <tr>
# <td style="text-align: center;">strictly</td>
# <td style="text-align: center;">厳しく</td>
# </tr>
# <tr>
# <td style="text-align: center;">otherwise</td>
# <td style="text-align: center;">さもないと</td>
# </tr>
# <tr>
# <td style="text-align: center;">definitely</td>
# <td style="text-align: center;">確かに</td>
# </tr>
# <tr>
# <td style="text-align: center;">especially</td>
# <td style="text-align: center;">特に</td>
# </tr>
# <tr>
# <td style="text-align: center;">fully</td>
# <td style="text-align: center;">完全に</td>
# </tr>
# <tr>
# <td style="text-align: center;">anyway</td>
# <td style="text-align: center;">とにかく</td>
# </tr>
# <tr>
# <td style="text-align: center;">simply</td>
# <td style="text-align: center;">簡単に、単に</td>
# </tr>
# <tr>
# <td style="text-align: center;">precisely</td>
# <td style="text-align: center;">正確に</td>
# </tr>
# <tr>
# <td style="text-align: center;">rather</td>
# <td style="text-align: center;">かなり</td>
# </tr>
# <tr>
# <td style="text-align: center;">accidentally</td>
# <td style="text-align: center;">偶然に</td>
# </tr>
# <tr>
# <td style="text-align: center;">deliberately</td>
# <td style="text-align: center;">故意に</td>
# </tr>
# <tr>
# <td style="text-align: center;">nevertheless</td>
# <td style="text-align: center;">それにもかかわらず</td>
# </tr>
# <tr>
# <td style="text-align: center;">primarily</td>
# <td style="text-align: center;">主に</td>
# </tr>
# <tr>
# <td style="text-align: center;">extensively</td>
# <td style="text-align: center;">広範囲に</td>
# </tr>
# <tr>
# <td style="text-align: center;">surprisingly</td>
# <td style="text-align: center;">驚くほど</td>
# </tr>
# <tr>
# <td style="text-align: center;">finally</td>
# <td style="text-align: center;">ついに、最終的に</td>
# </tr>
# <tr>
# <td style="text-align: center;">eventually</td>
# <td style="text-align: center;">結局は</td>
# </tr>
# <tr>
# <td style="text-align: center;">increasingly</td>
# <td style="text-align: center;">ますます</td>
# </tr>
# <tr>
# <td style="text-align: center;">exactly</td>
# <td style="text-align: center;">正確に、厳密に</td>
# </tr>
# <tr>
# <td style="text-align: center;">particularly</td>
# <td style="text-align: center;">特に</td>
# </tr>
# <tr>
# <td style="text-align: center;">shortly</td>
# <td style="text-align: center;">間もなく</td>
# </tr>
# <tr>
# <td style="text-align: center;">periodically</td>
# <td style="text-align: center;">定期的に</td>
# </tr>
# <tr>
# <td style="text-align: center;">regularly</td>
# <td style="text-align: center;">定期的に</td>
# </tr>
# <tr>
# <td style="text-align: center;">exclusively</td>
# <td style="text-align: center;">独占的に</td>
# </tr>
# <tr>
# <td style="text-align: center;">unfortunately</td>
# <td style="text-align: center;">残念なことに</td>
# </tr>
# <tr>
# <td style="text-align: center;">therefore</td>
# <td style="text-align: center;">したがって</td>
# </tr>
# <tr>
# <td style="text-align: center;">accordingly</td>
# <td style="text-align: center;">したがって</td>
# </tr>
# <tr>
# <td style="text-align: center;">besides</td>
# <td style="text-align: center;">さらに</td>
# </tr>
# <tr>
# <td style="text-align: center;">furthermore</td>
# <td style="text-align: center;">さらに</td>
# </tr>
# <tr>
# <td style="text-align: center;">moreover</td>
# <td style="text-align: center;">さらに</td>
# </tr>
# <tr>
# <td style="text-align: center;">rapidly</td>
# <td style="text-align: center;">急速に</td>
# </tr>
# <tr>
# <td style="text-align: center;">considerably</td>
# <td style="text-align: center;">かなり</td>
# </tr>
# <tr>
# <td style="text-align: center;">extensively</td>
# <td style="text-align: center;">広範囲にわたり</td>
# </tr>
# <tr>
# <td style="text-align: center;">merely</td>
# <td style="text-align: center;">単なる</td>
# </tr>
# <tr>
# <td style="text-align: center;">finely</td>
# <td style="text-align: center;">細かく</td>
# </tr>
# <tr>
# <td style="text-align: center;">respectively</td>
# <td style="text-align: center;">それぞれ</td>
# </tr>
# <tr>
# <td style="text-align: center;">simultaneously</td>
# <td style="text-align: center;">同時に</td>
# </tr>
# <tr>
# <td style="text-align: center;">absolutely</td>
# <td style="text-align: center;">完全に</td>
# </tr>
# <tr>
# <td style="text-align: center;">frequently</td>
# <td style="text-align: center;">頻繁に</td>
# </tr>
# <tr>
# <td style="text-align: center;">fairly</td>
# <td style="text-align: center;">まあまあ</td>
# </tr>
# <tr>
# <td style="text-align: center;">immediately</td>
# <td style="text-align: center;">すぐに</td>
# </tr>
# <tr>
# <td style="text-align: center;">beforehand</td>
# <td style="text-align: center;">あらかじめ</td>
# </tr>
# <tr>
# <td style="text-align: center;">downstairs</td>
# <td style="text-align: center;">階下へ</td>
# </tr>
# <tr>
# <td style="text-align: center;">upstairs</td>
# <td style="text-align: center;">階上へ</td>
# </tr>
# <tr>
# <td style="text-align: center;">ahead</td>
# <td style="text-align: center;">前へ</td>
# </tr>
# <tr>
# <td style="text-align: center;">conveniently</td>
# <td style="text-align: center;">便利に、都合よく</td>
# </tr>
# <tr>
# <td style="text-align: center;">effectively</td>
# <td style="text-align: center;">効果的に</td>
# </tr>
# </tbody>
# </table>
# <p>→TOEICによく出る英熟語(イディオム)を確認したい方は、「<a href="https://english.kohsukenemoto.com/toeic/toeic-vocabulary/idioms">TOEIC頻出英熟語(イディオム)一覧【800点取得したい方必見！】</a>」をチェックしてみてください。</p></div>
# </div> <!-- .et_pb_text -->
# </div> <!-- .et_pb_column -->
# </div> <!-- .et_pb_row --><div class="et_pb_row et_pb_row_3">
# <div class="et_pb_column et_pb_column_1_2 et_pb_column_4 et_pb_css_mix_blend_mode_passthrough">
# <div class="et_pb_module et_pb_image et_pb_image_1">
# <span class="et_pb_image_wrap "><img alt="" class="wp-image-1932" height="auto" loading="lazy" sizes="(max-width: 1024px) 100vw, 1024px" src="https://english.kohsukenemoto.com/wp-content/uploads/2019/07/toeic_voc.001.png" srcset="https://english.kohsukenemoto.com/wp-content/uploads/2019/07/toeic_voc.001.png 1024w, https://english.kohsukenemoto.com/wp-content/uploads/2019/07/toeic_voc.001-300x225.png 300w, https://english.kohsukenemoto.com/wp-content/uploads/2019/07/toeic_voc.001-768x576.png 768w, https://english.kohsukenemoto.com/wp-content/uploads/2019/07/toeic_voc.001-510x382.png 510w, https://english.kohsukenemoto.com/wp-content/uploads/2019/07/toeic_voc.001-600x450.png 600w" title="" width="auto"/></span>
# </div>
# </div> <!-- .et_pb_column --><div class="et_pb_column et_pb_column_1_2 et_pb_column_5 et_pb_css_mix_blend_mode_passthrough et-last-child">
# <div class="et_pb_module et_pb_text et_pb_text_5 et_pb_text_align_center et_pb_bg_layout_light">
# <div class="et_pb_text_inner"><p style="text-align: left;">【限定】：TOEICに頻出の英単語&amp;英熟語をまとめたeBook「90日間でマスター！TOEIC頻出英単語&amp;超効率暗記法」をこちらから無料でゲットできます。</p></div>
# </div> <!-- .et_pb_text --><div class="et_pb_button_module_wrapper et_pb_button_0_wrapper et_pb_button_alignment_center et_pb_module ">
# <a class="et_pb_button et_pb_button_0 et_pb_bg_layout_light" href="https://english.kohsukenemoto.com/toeic-vocabulary-for-90-days/">無料でゲットする！</a>
# </div>
# </div> <!-- .et_pb_column -->
# </div> <!-- .et_pb_row -->
# </div> <!-- .et_pb_section --> </div><!-- .et_builder_inner_content -->
# </div><!-- .et-l -->
# </div><!-- #et-boc -->
# </div> <!-- .entry-content -->
# <div class="et_post_meta_wrapper">
# </div> <!-- .et_post_meta_wrapper -->
# </article> <!-- .et_pb_post -->
# </div> <!-- #left-area -->
# </div> <!-- #content-area -->
# </div> <!-- .container -->
# </div> <!-- #main-content -->
# <footer id="main-footer">
# <div id="footer-bottom">
# <div class="container clearfix">
# </div> <!-- .container -->
# </div>
# </footer> <!-- #main-footer -->
# </div> <!-- #et-main-area -->
# </div> <!-- #page-container -->
# <meta content="KHLSHKtz1Izi1HV0Sq9FfBhYuA46IKTXZNee5K0jOf8" name="google-site-verification"/><script id="toc-front-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var tocplus = {"visibility_show":"\u8868\u793a","visibility_hide":"\u975e\u8868\u793a","width":"100%"};
# /* ]]> */
# </script>
# <script id="toc-front-js" src="https://english.kohsukenemoto.com/wp-content/plugins/table-of-contents-plus/front.min.js?ver=2002" type="text/javascript"></script>
# <script id="divi-custom-script-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var DIVI = {"item_count":"%d Item","items_count":"%d Items"};
# var et_shortcodes_strings = {"previous":"\u524d","next":"\u6b21"};
# var et_pb_custom = {"ajaxurl":"https:\/\/english.kohsukenemoto.com\/wp-admin\/admin-ajax.php","images_uri":"https:\/\/english.kohsukenemoto.com\/wp-content\/themes\/Divi\/images","builder_images_uri":"https:\/\/english.kohsukenemoto.com\/wp-content\/themes\/Divi\/includes\/builder\/images","et_frontend_nonce":"fc718b4566","subscription_failed":"\u304f\u3060\u3055\u3044\u30c1\u30a7\u30c3\u30af\u306b\u306f\u3001\u4ee5\u4e0b\u306e\u5206\u91ce\u3059\u305a\u6b63\u78ba\u306b\u5165\u529b\u3057\u307e\u3059\u3002","et_ab_log_nonce":"2d41fe5416","fill_message":"\u3001\u6b21\u306e\u30d5\u30a3\u30fc\u30eb\u30c9\u306b\u5165\u529b\u3057\u3066\u304f\u3060\u3055\u3044\uff1a","contact_error_message":"\u6b21\u306e\u30a8\u30e9\u30fc\u3092\u4fee\u6b63\u3057\u3066\u304f\u3060\u3055\u3044\uff1a","invalid":"\u7121\u52b9\u306a\u30e1\u30fc\u30eb","captcha":"\u753b\u50cf\u8a8d\u8a3c","prev":"\u524d\u3078","previous":"\u524d","next":"\u6b21\u3078","wrong_captcha":"\u30ad\u30e3\u30d7\u30c1\u30e3\u306e\u756a\u53f7\u304c\u9055\u3044\u307e\u3059\u3002","wrong_checkbox":"Checkbox","ignore_waypoints":"no","is_divi_theme_used":"1","widget_search_selector":".widget_search","ab_tests":[],"is_ab_testing_active":"","page_id":"382","unique_test_id":"","ab_bounce_rate":"5","is_cache_plugin_active":"no","is_shortcode_tracking":"","tinymce_uri":""}; var et_builder_utils_params = {"condition":{"diviTheme":true,"extraTheme":false},"scrollLocations":["app","top"],"builderScrollLocations":{"desktop":"app","tablet":"app","phone":"app"},"onloadScrollLocation":"app","builderType":"fe"}; var et_frontend_scripts = {"builderCssContainerPrefix":"#et-boc","builderCssLayoutPrefix":"#et-boc .et-l"};
# var et_pb_box_shadow_elements = [];
# var et_pb_motion_elements = {"desktop":[],"tablet":[],"phone":[]};
# var et_pb_sticky_elements = [];
# /* ]]> */
# </script>
# <script id="divi-custom-script-js" src="https://english.kohsukenemoto.com/wp-content/themes/Divi/js/custom.unified.js?ver=4.6.5" type="text/javascript"></script>
# <script id="et-core-common-js" src="https://english.kohsukenemoto.com/wp-content/themes/Divi/core/admin/js/common.js?ver=4.6.5" type="text/javascript"></script>
# <script id="wp-embed-js" src="https://english.kohsukenemoto.com/wp-includes/js/wp-embed.min.js?ver=5.5.3" type="text/javascript"></script>
# </body>
# </html>

# %%
tables = soup.find_all("table")
tables
# Out:
# 4

# %%
word_list_3 = []
for table in tables:
    for i, tr in enumerate(table.find_all("tr")):
        if i == 0:
            continue
        tds = tr.find_all("td")
        word_list_3.append({tds[0].text:tds[1].text})
word_list_3
# Out:
# [{'agenda': '議題'},
#  {'chairperson': '議長'},
#  {'handout': '配布資料'},
#  {'conference': '会議'},
#  {'council': '会議'},
#  {'meeting': '会議'},
#  {'conversation': '会議'},
#  {'majority': '大多数'},
#  {'table': '表'},
#  {'opinion': '意見'},
#  {'issue': '問題'},
#  {'minute(s)': '議事録'},
#  {'content': '内容'},
#  {'detail': '詳細'},
#  {'suggestion': '提案'},
#  {'argument': '議論'},
#  {'committee': '委員会'},
#  {'representative': '代表者'},
#  {'church': '教会'},
#  {'business': '商取引'},
#  {'health': '健康'},
#  {'fever': '熱'},
#  {'persistence': '粘り強さ'},
#  {'stimulus': '刺激'},
#  {'hospital': '病院'},
#  {'hospitality': 'おもてなし'},
#  {'plague': '疫病'},
#  {'breath': '呼吸'},
#  {'exercise': '運動'},
#  {'workout': '運動'},
#  {'ache': '痛み、痛む'},
#  {'organ': '臓器'},
#  {'appliance': '器具'},
#  {'fatal': '致命的な'},
#  {'wound': '傷'},
#  {'ritual': '儀式'},
#  {'restoration': '回復'},
#  {'preservation': '保存'},
#  {'bite': '食事'},
#  {'analysis': '分析'},
#  {'weight': '重さ、体重'},
#  {'height': '高さ'},
#  {'width': '幅'},
#  {'length': '長さ'},
#  {'consensus': '同意'},
#  {'viewpoint': '観点'},
#  {'standpoint': '観点'},
#  {'perspective': '観点'},
#  {'presentation': 'プレゼンテーション'},
#  {'resolution': '決議、決定'},
#  {'subjects': 'テーマ(主題)'},
#  {'summary': '概要、要約'},
#  {'diagram': '図'},
#  {'newsletter': '会報、ニュースレター'},
#  {'announcement': '発表'},
#  {'decision': '決定'},
#  {'initiative': '主導権'},
#  {'discipline': '規律'},
#  {'agreement': '協定'},
#  {'material': '材料'},
#  {'exit': '出口'},
#  {'entrance': '入り口、入学'},
#  {'entry': '登録'},
#  {'admission': '入学'},
#  {'membership': '会員'},
#  {'registration': '登録'},
#  {'term': '条件※期間の意味もあ る'},
#  {'option': '選択'},
#  {'procedure': '手続き'},
#  {'career': '職歴'},
#  {'background': '経歴'},
#  {'title': '肩書き'},
#  {'deadline': '締め切り'},
#  {'interview': '面接(する)'},
#  {'license': '免許'},
#  {'requirements': '資格'},
#  {'qualifications': '資格'},
#  {'certificate': '証明書'},
#  {'contract': '契約'},
#  {'signature': '署名'},
#  {'enclosure': '同封物'},
#  {'résumé': '履歴書'},
#  {'specifications': '仕様書'},
#  {'pedestrian': '歩行者'},
#  {'university': '(総合)大学'},
#  {'college': '(単科)大学'},
#  {'cousin': 'いとこ'},
#  {'aunt': 'おば'},
#  {'uncle': 'おじ'},
#  {'daughter': '娘'},
#  {'son': '息子'},
#  {'platform': '“(駅の)プラットフォ ーム”'},
#  {'partnership': '提携'},
#  {'threat': '脅威'},
#  {'astronaut': '宇宙飛行士'},
#  {'behavior': '振る舞い'},
#  {'bush': '低木'},
#  {'assignment': '任務'},
#  {'sales': '販売'},
#  {'notice': '通知'},
#  {'unemployment': '失業'},
#  {'ability': '能力'},
#  {'generosity': '気前の良さ'},
#  {'attitude': '態度'},
#  {'pleasure': '喜び'},
#  {'character': '性格'},
#  {'mood': '気分'},
#  {'privilege': '特権'},
#  {'disappointment': '失意'},
#  {'subordinate': '同僚'},
#  {'desire': '願望'},
#  {'strategy': '戦略'},
#  {'affair': '問題'},
#  {'controversy': '論争'},
#  {'machineries': '機械'},
#  {'components': '部品'},
#  {'statue': '像'},
#  {'drawing': 'スケッチ'},
#  {'transformation': '変化'},
#  {'assembly': '組み立て'},
#  {'vacancy': '欠員'},
#  {'lack': '欠員'},
#  {'(job) opening': '欠員'},
#  {'employee': '社員'},
#  {'applicant': '候補者'},
#  {'candidate': '候補者'},
#  {'application': '申し込み'},
#  {'panel': '委員会'},
#  {'accomplishment': '業績'},
#  {'temperature': '温度'},
#  {'odor': 'におい(悪臭)'},
#  {'sink': '流し'},
#  {'lawn': '芝生'},
#  {'basement': '地下室'},
#  {'ladder': 'はしご'},
#  {'message': '伝言'},
#  {'foundation': '設立、基礎'},
#  {'remainder': '残り'},
#  {'diversity': '多様性'},
#  {'luxury': '贅沢'},
#  {'prerequisite': '必要条件'},
#  {'ethics': '倫理'},
#  {'moral': 'モラル、道徳'},
#  {'policy': '主義'},
#  {'stereotype': '固定観念'},
#  {'bias': '偏見'},
#  {'prejudice': '偏見'},
#  {'construction': '建設'},
#  {'aisle': '通路'},
#  {'defect': '欠陥'},
#  {'site': '場所'},
#  {'investigation': '調査'},
#  {'skyscraper': '超高層ビル'},
#  {'inspection': '検査'},
#  {'degree': '学位、程度'},
#  {'undergraduate': '大学生、学部生'},
#  {'graduate': '卒業生'},
#  {'accommodation': '宿泊施設'},
#  {'admission': '入場許可'},
#  {'efficiency': '効率性'},
#  {'code': '規則'},
#  {'discipline': '規則'},
#  {'study': '研究'},
#  {'research': '研究'},
#  {'diploma': '卒業証書'},
#  {'lecture': '講義'},
#  {'grade': '成績'},
#  {'scholarship': '奨学金'},
#  {'scholar': '学者'},
#  {'institute': '機関'},
#  {'establishment': '機関'},
#  {'psychology': '心理学'},
#  {'faculty': '学部'},
#  {'savings': '貯蓄'},
#  {'premise': '敷地、仮定'},
#  {'staircase': '階段'},
#  {'stairs': '階段'},
#  {'stairway': '階段'},
#  {'lodging': '宿泊施設'},
#  {'directory': '住所'},
#  {'government': '政府'},
#  {'governor': '知事'},
#  {'deregulation': '規制緩和'},
#  {'talk': '会談'},
#  {'authority': '権威'},
#  {'function': '機能'},
#  {'customs': '税関'},
#  {'assistance': '支援'},
#  {'issue': '問題'},
#  {'right': '権利'},
#  {'nation': '国家'},
#  {'data': 'データ'},
#  {'loyalty': '忠誠'},
#  {'statistics': '統計'},
#  {'statement': '報告書、発言'},
#  {'amendment': '修正案'},
#  {'trade': '貿易'},
#  {'engagement': '婚約'},
#  {'immigrant': '移住'},
#  {'public': '世間(市民)'},
#  {'fortune': '財産'},
#  {'estate': '財産'},
#  {'assets': '財産'},
#  {'holdings': '財産'},
#  {'property': '財産'},
#  {'real estate': '不動産'},
#  {'railing': '手すり'},
#  {'rent': '賃貸料'},
#  {'ceiling': '天井'},
#  {'furniture': '家具'},
#  {'insurance': '保険'},
#  {'shot': '注射'},
#  {'cough': 'せき'},
#  {'patient': '忍耐'},
#  {'insurance': '保険'},
#  {'medicine': '薬'},
#  {'illness': '病気'},
#  {'disease': '病気'},
#  {'sickness': '病気'},
#  {'residence': '住宅'},
#  {'household': '世帯'},
#  {'resident': '居住者'},
#  {'yard': '庭'},
#  {'garden': '庭'},
#  {'housing': '住宅'},
#  {'housekeeping': '家事'},
#  {'deck': 'テラス'},
#  {'suburbs': '郊外'},
#  {'outskirt': '郊外'},
#  {'neighborhood': '地域'},
#  {'region': ''},
#  {'pension': '年金'},
#  {'land': '土地'},
#  {'garbage': 'ゴミ'},
#  {'trash': 'ゴミ'},
#  {'litter': 'ゴミ'},
#  {'utilities': '公共料金'},
#  {'subway': '地下鉄'},
#  {'plan': '計画'},
#  {'laundries': '洗濯物'},
#  {'uniform': '制服'},
#  {'remedy': '治療'},
#  {'surgeon': '外科医'},
#  {'physician': '内科医'},
#  {'appetite': '食欲'},
#  {'prescription': '処方箋'},
#  {'diagnosis': '診断'},
#  {'checkup': '検査'},
#  {'cancer': 'ガン'},
#  {'diabetes': '糖尿病'},
#  {'throat': '喉'},
#  {'chest': '胸'},
#  {'pain': '痛み'},
#  {'strain': 'ストレス'},
#  {'court': '裁判所'},
#  {'law': '法律 ※lowは「低い」'},
#  {'lawyer': '弁護士'},
#  {'attorney': '弁護士'},
#  {'(law)suit': '訴訟'},
#  {'justification': '正当化'},
#  {'education': '教育'},
#  {'landscape': '風景'},
#  {'view': '風景'},
#  {'scenery': '風景'},
#  {'sight': '風景'},
#  {'channel': '経路'},
#  {'lane': '車線'},
#  {'direction': '道順'},
#  {'distance': '距離'},
#  {'passenger': '乗客'},
#  {'transportation': '交通手段'},
#  {'track': '跡'},
#  {'driver’s license': '運転免許証'},
#  {'identification': '身分証'},
#  {'identity': '身元'},
#  {'cab': 'タクシー'},
#  {'vehicle': '乗り物'},
#  {'motorbike': 'バイク'},
#  {'mortercycle': 'バイク'},
#  {'fare': '運賃'},
#  {'lot': '用地'},
#  {'surface mail': '海上便'},
#  {'fuel': '燃料'},
#  {'crew': '乗務員'},
#  {'aircraft': '航空機'},
#  {'one way': '片道'},
#  {'round trip': '往復航空'},
#  {'railway line': '鉄道'},
#  {'departure': '出発'},
#  {'arrival': '到着'},
#  {'destination': '目的地'},
#  {'fine': '罰金'},
#  {'laggage': '手荷物'},
#  {'baggage': '手荷物'},
#  {'location': '場所'},
#  {'blueprint': '設計図'},
#  {'mess': '散らかった状態'},
#  {'sidewalk': '歩道'},
#  {'crosswalk': '横断歩道'},
#  {'pavement': '舗装道路'},
#  {'avenue': '大通り'},
#  {'route': '道、道筋'},
#  {'intersection': '交差点'},
#  {'facility': '施設'},
#  {'factory': '工場'},
#  {'plant': '工場'},
#  {'security': '警備'},
#  {'search': '捜索'},
#  {'finance': '財源'},
#  {'output': '生産高'},
#  {'election': '選挙'},
#  {'concern': '懸念、関心ごと'},
#  {'precaution': '予防策'},
#  {'excess': '超過'},
#  {'depression': '不況'},
#  {'awareness': '意識'},
#  {'service': '貢献'},
#  {'conflict': '対立'},
#  {'approval': '承認'},
#  {'statesman': '政治家'},
#  {'childhood': '子供時代'},
#  {'policy': '政策'},
#  {'minister': '大臣'},
#  {'poll': '世論調査'},
#  {'unemployment': '失業率'},
#  {'congress': '国会'},
#  {'acceptance': '受け入れ'},
#  {'refugee': '難民'},
#  {'intervention': '介入'},
#  {'description': '描写'},
#  {'explanation': '説明'},
#  {'instructions': '取扱説明書、指示'},
#  {'manual': 'マニュアル'},
#  {'prospectus': '案内書'},
#  {'shipment': '発送'},
#  {'complaint': '苦情'},
#  {'claim': '苦情'},
#  {'crack': 'ヒビ'},
#  {'damage': '損害、ダメージ'},
#  {'compensation': '保証'},
#  {'burden': '重荷'},
#  {'warranty': '保証'},
#  {'premiums': '保険金'},
#  {'equipment': '装置'},
#  {'breakdown': '故障'},
#  {'edge': '縁、へり'},
#  {'laptop': 'ノートパソコン'},
#  {'surface': '表面'},
#  {'bottom': '底'},
#  {'frame': '枠、額縁'},
#  {'screen': '画面'},
#  {'experiment': '実験'},
#  {'device': '装置'},
#  {'list': 'リスト、名簿'},
#  {'file': 'ファイル、整理する'},
#  {'operator': '電話交換手、オペレーター'},
#  {'malfunction': '誤作動、(機械などの)不調'},
#  {'terminal': '端末'},
#  {'interruption': '妨害'},
#  {'extension': '内線'},
#  {'completion': '完成'},
#  {'offense': '違反'},
#  {'violation': '違反'},
#  {'defense': '弁護'},
#  {'grace': '猶予、優雅さ'},
#  {'defeat': '敗北'},
#  {'punishment': '処罰'},
#  {'legislation': '法律'},
#  {'guilt': '罪'},
#  {'judgement': '判断'},
#  {'appeal': '訴え'},
#  {'innocence': '無実'},
#  {'case': '事例'},
#  {'clue': '手がかり'},
#  {'witness': '目撃者'},
#  {'assertion': '主張'},
#  {'defendant': '被告人'},
#  {'offender': '犯罪者'},
#  {'criminal': '犯罪者'},
#  {'jury': '陪審員'},
#  {'cost': '費用、経費'},
#  {'system': '制度'},
#  {'variety': '種類'},
#  {'kind': '種類'},
#  {'sort': '種類'},
#  {'trend': '傾向'},
#  {'article(s)': '記事(品物)'},
#  {'cart': 'ショッピングカート'},
#  {'stain': '染み'},
#  {'advertisement': '宣伝、広告'},
#  {'agency': '代理店'},
#  {'scale': 'はかり'},
#  {'change': '小銭'},
#  {'downtown': '都心'},
#  {'dish': '皿'},
#  {'value': '価値'},
#  {'drops': '農作物'},
#  {'produce': '農作物'},
#  {'clothing': '衣服'},
#  {'feature': '特徴'},
#  {'appointment': '約束'},
#  {'appetizer': '前菜'},
#  {'actor': '俳優'},
#  {'actress': '女優'},
#  {'full house': '満員'},
#  {'quality': '質'},
#  {'quantity': '量'},
#  {'manufacturer': '製造会社'},
#  {'production': '製造、生産'},
#  {'shipping': '発送'},
#  {'garment': '衣類'},
#  {'postage': '郵便料金'},
#  {'cashier': 'レジ係'},
#  {'carrier': '配送業者'},
#  {'perishables': '生鮮食品'},
#  {'mall': 'ショッピングセンター'},
#  {'cellphone': '携帯電話'},
#  {'container': '容器'},
#  {'workshop': '講習会'},
#  {'ornament': '装飾品'},
#  {'arrangement': '準備'},
#  {'instrument': '楽器'},
#  {'range': '範囲'},
#  {'advantage': '利点'},
#  {'attention': '注意'},
#  {'chemical': '化学物質'},
#  {'citizen': '市民'},
#  {'relative': '親戚'},
#  {'limit': '限度'},
#  {'party': '一行、集まり'},
#  {'tour': '視察'},
#  {'development': '開発'},
#  {'aid': '支援'},
#  {'fair': '見本市'},
#  {'principle': '主義'},
#  {'sympathy': '同情'},
#  {'population': '人口'},
#  {'growth': '増加'},
#  {'association': '組合'},
#  {'bulletin board': '掲示版'},
#  {'operation': '営業'},
#  {'basis': '基準'},
#  {'element': '要素'},
#  {'advance': '進歩'},
#  {'advancement': '昇進'},
#  {'revision': '修正'},
#  {'donation': '寄付'},
#  {'rumor': '噂'},
#  {'custom(s)': '習慣(税関 )'},
#  {'fate': '運命'},
#  {'destiny': '運命'},
#  {'consequence': '結果'},
#  {'index': '指標'},
#  {'obstacle': '障害物'},
#  {'favor': '願い'},
#  {'permission': '許可'},
#  {'exception': '例外'},
#  {'faith': '信頼'},
#  {'glance': 'ちらっと見ること'},
#  {'sense': '意味'},
#  {'traffic (jam)': '交通渋滞'},
#  {'examination': '試験'},
#  {'respect': '敬意'},
#  {'condition': '状態'},
#  {'extent': '程度'},
#  {'breakthrough': '大発見'},
#  {'applause': '拍手'},
#  {'dependent': '扶養家族'},
#  {'courtesy': '好意'},
#  {'sightseeing': '観光'},
#  {'excursion': '遠足'},
#  {'transition': '移行、移り変わり'},
#  {'sacrifice': '犠牲'},
#  {'reputation': '評判'},
#  {'publicity': '評判、広告'},
#  {'aspect': '側面'},
#  {'affection': '愛情'},
#  {'reliability': '信頼性'},
#  {'opportunity': '機会'},
#  {'chance': '機会'},
#  {'occasion': '機会'},
#  {'exclusion': '除外'},
#  {'cause': '原因'},
#  {'patent': '特許'},
#  {'exhaustion': '極度の疲労'},
#  {'customer': '顧客'},
#  {'client': '顧客'},
#  {'dissatisfaction': '不満'},
#  {'linen': 'テーブルクロス'},
#  {'tablecloth': 'テーブルクロス'},
#  {'retail': '小売り'},
#  {'wholesale': '卸売り'},
#  {'fee': '料金'},
#  {'outlet': '直売店'},
#  {'promotion': '販売促進'},
#  {'time line': '予定'},
#  {'box office': '切符売り場'},
#  {'district': '地区'},
#  {'agent': '業者、代理人'},
#  {'challenge': '難問'},
#  {'capital': '資本'},
#  {'opening hours': '営業時間'},
#  {'parcel': '小包'},
#  {'charge': '料金'},
#  {'line': '在庫商品、回線'},
#  {'clearlance': '在庫処分セール'},
#  {'delivery': '配送'},
#  {'reception': '歓迎会'},
#  {'orientation': 'オリエンテーション、 教育指導'},
#  {'wedding': '結婚'},
#  {'meat': '肉'},
#  {'refreshment': '軽食'},
#  {'caterer': '仕出し業者'},
#  {'anniversary': '~周年記念日'},
#  {'reduction': '削減'},
#  {'ingredient': '成分'},
#  {'satisfaction': '満足'},
#  {'grocery': '食料雑貨店'},
#  {'division': '部門'},
#  {'organization': '組織'},
#  {'institution': '機関'},
#  {'association': '団体'},
#  {'structure': '構造'},
#  {'superior': '上司'},
#  {'boss': '上司'},
#  {'manager': '上司、管理者'},
#  {'subordinate': '部下'},
#  {'personnel': '職員、人事課'},
#  {'position': '地位'},
#  {'post': '地位'},
#  {'status': '地位、状況'},
#  {'colleague': '同僚'},
#  {'coworker': '同僚'},
#  {'associate': '同僚'},
#  {'quarrel': '口論'},
#  {'firm': '会社'},
#  {'corporation': '会社'},
#  {'enterprise': '企業'},
#  {'affiliate': '子会社'},
#  {'subsidiary': '子会社'},
#  {'branch': '支社'},
#  {'introduction': '紹介'},
#  {'remark': '見解'},
#  {'chairman': '委員長'},
#  {'director': '取締役'},
#  {'executive': '重役'},
#  {'board of directors': '役員会'},
#  {'human resource': '人事'},
#  {'section': '課'},
#  {'headquarters': '本社'},
#  {'head office': '本社'},
#  {'chore': '雑用'},
#  {'role': '役割'},
#  {'part': '役割'},
#  {'duty': '役割'},
#  {'responsibility': '責任'},
#  {'efficiency': '効率'},
#  {'correction': '修正'},
#  {'collection': '収集'},
#  {'competition': '競争'},
#  {'competitor': '競争相手'},
#  {'holiday': '休日'},
#  {'vacation': '休日'},
#  {'break': '休憩'},
#  {'leave': '休憩'},
#  {'rest': '休憩'},
#  {'welfare': '福利厚生'},
#  {'fatigue': '疲労'},
#  {'motivation': 'モチベーション、やる気'},
#  {'labor': '労働'},
#  {'commission': '手数料'},
#  {'task': '任務、使命'},
#  {'mission': '任務、使命'},
#  {'clerical': '事務員(事務の)'},
#  {'business trip': '出張'},
#  {'invitation': '招待'},
#  {'farewell': '送別会'},
#  {'convenience': '便利'},
#  {'vision': '理想像'},
#  {'finance': '財政'},
#  {'quarter': '四半期'},
#  {'deficit': '赤字'},
#  {'surplus': '黒字'},
#  {'loss': '損失'},
#  {'expense': '費用'},
#  {'cost': '費用'},
#  {'calculation': '計算'},
#  {'figure(out)': '数字(算出する)'},
#  {'sum(up)': '合計、金額(合計する)'},
#  {'revenue': '歳入'},
#  {'expenditure': '歳出'},
#  {'tax': '税金'},
#  {'fund': '資金'},
#  {'management': '管理、経 営、経営陣'},
#  {'administration': '管理'},
#  {'supervisor': '監督者'},
#  {'visitor': '訪問客'},
#  {'takeover': '企業買収'},
#  {'merger': '合併、買収'},
#  {'consumption': '消費'},
#  {'consumer': '消費者'},
#  {'buyout': '買収'},
#  {'franchise': 'フランチャイズ'},
#  {'beverage': '飲み物'},
#  {'expansion': '拡大'},
#  {'compliance': '法令遵守'},
#  {'scheme': '(事業)計画'},
#  {'purpose': '目的'},
#  {'object': '目的'},
#  {'goal': '目標'},
#  {'target': '目標'},
#  {'objective': '目標'},
#  {'trial': '挑戦、試み'},
#  {'measures': '対策'},
#  {'means': '手段'},
#  {'method': '方法'},
#  {'approach': '取り組み方'},
#  {'priority': '優先事項'},
#  {'profitability': '収益性'},
#  {'aim': '目標'},
#  {'sick leave': '病欠'},
#  {'attendant': '出席者、店員'},
#  {'attendance': '出席'},
#  {'sentiment': '意見'},
#  {'involvement': '関与'},
#  {'participation': '参加'},
#  {'hypothesis': '仮説'},
#  {'discovery': '発見'},
#  {'microscope': '顕微鏡'},
#  {'telescope': '望遠鏡'},
#  {'particle': '粒子'},
#  {'surroundings': '環境'},
#  {'setting': '環境'},
#  {'environment': '環境'},
#  {'circumstances': '事情、環境'},
#  {'influence': '影響'},
#  {'effect': '影響'},
#  {'impact': '影響'},
#  {'inquiry': '問い合わせ'},
#  {'overhead': '諸経費'},
#  {'adventure': '冒険'},
#  {'drought': '干ばつ'},
#  {'climate': '気候'},
#  {'disaster': '災害'},
#  {'weather': '天気'},
#  {'report': '報告(書)'},
#  {'forecast': '予報'},
#  {'bridge': '橋'},
#  {'Antarctic': '南極'},
#  {'Arctic': '北極'},
#  {'heat': '熱'},
#  {'wave': '波'},
#  {'harm': '危機、害'},
#  {'border': '国境'},
#  {'risk': '危険'},
#  {'congestion': '混雑'},
#  {'resources': '資源'},
#  {'species': '種'},
#  {'fountain': '噴水'},
#  {'river': '川'},
#  {'city hall': '市役所'},
#  {'budget': '予算'},
#  {'audit': '会計検査、監査する'},
#  {'auditor': '監査役'},
#  {'liabilities': '負債'},
#  {'debt': '借金'},
#  {'debtor': '債務者'},
#  {'creditor': '債権者'},
#  {'default': '債務不履行'},
#  {'account': '口座'},
#  {'accountant': '会計士'},
#  {'bookkeeping': '簿記、経理'},
#  {'profit': '収益、利益'},
#  {'gains': '収益、利益'},
#  {'returns': '収益、利益'},
#  {'proceeds': '収益、利益'},
#  {'income': '収益、利益'},
#  {'earnings': '収益、利益'},
#  {'yield': '収益、利益'},
#  {'proceedings': '議事録'},
#  {'stuff': 'もの'},
#  {'pollution': '汚染'},
#  {'base': '基地'},
#  {'peace': '平和'},
#  {'museum': '美術館、博物館'},
#  {'extinction': '絶滅'},
#  {'flood': '洪水'},
#  {'warning': '警報、警告'},
#  {'alert': '警報、警告'},
#  {'fault': '責任'},
#  {'era': '時代'},
#  {'period': '期間'},
#  {'allowance': '手当'},
#  {'retirement': '退職'},
#  {'wildlife': '野生生物'},
#  {'desert': '砂漠'},
#  {'hill': '丘'},
#  {'cave': '洞窟'},
#  {'pond': '池'},
#  {'bay': '湾'},
#  {'(sea)shore': '海岸'},
#  {'recognition': '認識'},
#  {'award': '賞'},
#  {'prize': '賞'},
#  {'banquet': '宴会'},
#  {'gratitude': '感謝'},
#  {'candidate': '候補者'},
#  {'compliment': '褒め言葉'},
#  {'employment': '職業、雇用'},
#  {'electrician': '電気技師'},
#  {'architect': '建築家'},
#  {'dentist': '歯科医'},
#  {'secretary': '秘書'},
#  {'clerk': '事務員'},
#  {'athlete': 'スポーツ選手'},
#  {'interpreter': '通訳者'},
#  {'invester': '投資家'},
#  {'consultant': 'コンサルタント、顧問'},
#  {'consultation': '相談'},
#  {'deduction': '控除'},
#  {'difficulty': '困難'},
#  {'balance': '残高'},
#  {'principal': '元金'},
#  {'interest': '利子'},
#  {'deposit': '預金、預金する'},
#  {'loan': 'ローン、貸付'},
#  {'currency': '通貨'},
#  {'stock(-holder)': '株(株主)'},
#  {'share(-holder)': '株(株主)'},
#  {'bond': '債券'},
#  {'investment': '投資'},
#  {'dividend': '配当'},
#  {'credit': '信用貸し'},
#  {'exchange': '交換'},
#  {'down payment': '頭金'},
#  {'bankruptcy': '倒産'},
#  {'check': '小切手'},
#  {'fraction': '一部分'},
#  {'selection': '品揃え'},
#  {'special': '特別料理'},
#  {'pity': '残念なこと'},
#  {'bill': '請求書、手形'},
#  {'compromise': '妥協'},
#  {'negotiation': '交渉'},
#  {'estimate': '見積もり'},
#  {'relationship': '関係'},
#  {'relation': '関係'},
#  {'instructor': '指導者'},
#  {'drill': '訓練'},
#  {'boom': '景気'},
#  {'survey': '調査'},
#  {'recession': '不景気'},
#  {'inflation': 'インフレ'},
#  {'product': '商品'},
#  {'goods': '商品'},
#  {'merchandise': '商品'},
#  {'commodity': '商品'},
#  {'share': 'シェア、共有、市場占有率'},
#  {'formula': '製法'},
#  {'speculation': '推測'},
#  {'penetration': '進出'},
#  {'economy': '経済'},
#  {'monopoly': '独占(権)'},
#  {'market': '市場'},
#  {'demand': '需要'},
#  {'supply': '供給'},
#  {'outlook': '見通し'},
#  {'commerce': '商業'},
#  {'import': '輸入'},
#  {'export': '輸出'},
#  {'novel': '小説'},
#  {'story': '話、物語'},
#  {'masterpiece': '傑作'},
#  {'autobiography': '自伝'},
#  {'journal': '定期刊行物'},
#  {'fact': '事実'},
#  {'literature': '文学'},
#  {'improvement': '改善(点)'},
#  {'expedition': '探検'},
#  {'correspondent': '特派員'},
#  {'atmosphere': '雰囲気、大気'},
#  {'draft': '下書き、草案'},
#  {'manuscript': '原稿'},
#  {'script': '原稿'},
#  {'critic': '評論家'},
#  {'author': '作家'},
#  {'criticism': '批評'},
#  {'plot': '(物語の)筋、小区画'},
#  {'version': '版'},
#  {'circulation': '発行部数'},
#  {'booklet': 'パンフレット'},
#  {'brochure': 'パンフレット'},
#  {'pamphlet': 'パンフレット'},
#  {'nature': '資質、自然'},
#  {'evaluation': '評価'},
#  {'appraisal': '評価'},
#  {'assessment': '評価、診断'},
#  {'honor': '光栄'},
#  {'effort': '努力'},
#  {'endeaver': '努力'},
#  {'supporter': '支持者'},
#  {'harvest': '収穫、〜を収穫する'},
#  {'distribution': '分配'},
#  {'pay': '給料'},
#  {'paycheck': '給料'},
#  {'salary': '給料'},
#  {'wage': '給料'},
#  {'reward': '報酬'},
#  {'remuneration': '報酬'},
#  {'compensation': '補償、埋め合わせ'},
#  {'benefit': '給付'},
#  {'phenomenon': '現象'},
#  {'practice': '習慣'},
#  {'plunge': '急落'},
#  {'refund': '返金'},
#  {'broadcast': '放送'},
#  {'transmission': '変速装置'},
#  {'audience': '聴衆'},
#  {'spectators': '観客'},
#  {'enthusiasm': '熱意'},
#  {'acquaintance': '知人'},
#  {'job': '職業'},
#  {'career': '職業'},
#  {'profession': '職業'},
#  {'occupation': '職業'},
#  {'vocation': '職業'},
#  {'predecessor': '前任者'},
#  {'replacement': '交代'},
#  {'achievement': '業績'},
#  {'performance': '業績'},
#  {'results': '業績、結果'},
#  {'contribution': '業績'},
#  {'cathedral': '大聖堂'},
#  {'barn': '納屋'},
#  {'document': '文書、書類'},
#  {'papers': '文書、書類'},
#  {'original': '原本、元々の'},
#  {'duplicate': '複製'},
#  {'letterhead': 'レターヘッド、タイト ル'},
#  {'margin': '幅、あまり'},
#  {'proposal': '提案'},
#  {'news': '知らせ'},
#  {'evidence': '証拠'},
#  {'sign': '兆候'},
#  {'thought': '考え'},
#  {'idea': '考え'},
#  {'belief': '信念'},
#  {'doubt': '疑い'},
#  {'conclusion': '結論'},
#  {'impression': '印象'},
#  {'hope': '見込み'},
#  {'prospect': '見込み'},
#  {'expectation': '見込み'},
#  {'anticipation': '見込み'},
#  {'possibility': '可能性'},
#  {'press': '報道機関'},
#  {'information': '情報'},
#  {'rate': '率'},
#  {'knowledge': '知識'},
#  {'collar': '襟'},
#  {'path(way)': '経路、小道'},
#  {'drawer': '引き出し'},
#  {'office supplies': '事務用品'},
#  {'stationary': '文房具'},
#  {'scissors': 'ハサミ'},
#  {'eraser': '消しゴム'},
#  {'stapler': 'ホチキス'},
#  {'glue': 'のり'},
#  {'refill': '詰め替え品'},
#  {'memo': '社内連絡'},
#  {'envelope': '封筒'},
#  {'capability': '能力'},
#  {'capacity': '生産能力'},
#  {'transaction': '取引'},
#  {'deal': '取引'},
#  {'auction': 'オークション・競り'},
#  {'sponsor': '広告主'},
#  {'profile': 'プロフィール・紹介'},
#  {'brand': 'ブランド・商標'},
#  {'questionnaire': 'アンケート'},
#  {'tension': '緊張関係'},
#  {'feedback': 'フィードバック、反応、意見'},
#  {'leaflet': 'リーフレット'},
#  {'flier': 'チラシ'},
#  {'handout': '配布資料'},
#  {'logo': 'ロゴ'},
#  {'show': '展示会'},
#  {'exhibition': '展示'},
#  {'marchant': '商人'},
#  {'regulation': '規則'},
#  {'failure': '失敗'},
#  {'industory': '産業'},
#  {'workload': '仕事量'},
#  {'raise': '賃上げ'},
#  {'dock': '波止場'},
#  {'room': '余地'},
#  {'poverty': '貧困'},
#  {'errand': 'お使い'},
#  {'renovation': '改修'},
#  {'quote': '見積もり'},
#  {'vessel': '船'},
#  {'resemble': '〜に似ている'},
#  {'stimulate': '〜を刺激する'},
#  {'breathe': '呼吸する'},
#  {'aid': '〜の助けとなる'},
#  {'examine': '〜を診察する、〜を調べる'},
#  {'bear': '〜に耐える'},
#  {'cure': '〜を治す'},
#  {'treat': '〜を治す'},
#  {'stretch': '（手足などを）〜を伸ばす'},
#  {'inherit': '（財産などを）相続する'},
#  {'farm': '（土地などを）を耕す'},
#  {'bury': 'を埋める'},
#  {'initiate': '〜を始める'},
#  {'begin': '〜を始める'},
#  {'start': '〜を始める'},
#  {'hang': 'かける、吊るす'},
#  {'freeze': '〜を凍結する'},
#  {'bind': '（包帯などで）縛る'},
#  {'surround': '〜を囲む'},
#  {'collapse': '崩壊する【名】崩壊'},
#  {'sue': '訴訟する'},
#  {'regulate': '規制する'},
#  {'deregulate': '規制を緩和する'},
#  {'embezzle': '横領する'},
#  {'delay': '〜を遅らせる'},
#  {'access': '接近、アクセスする'},
#  {'unload': '（荷物など）を降ろす'},
#  {'design': '設計する'},
#  {'threaten': '〜を脅す'},
#  {'miss': '〜に乗り遅れる'},
#  {'board': '搭乗する'},
#  {'seat': '座る'},
#  {'stall': '（車などを）をエンストさせる'},
#  {'construct': '建設する'},
#  {'expand': '〜を拡大する'},
#  {'inspect': '検査する'},
#  {'repair': '〜を修理する'},
#  {'introduce': '〜を導入する'},
#  {'accommodate': '〜をを収容する'},
#  {'extend': '〜を延長する'},
#  {'stack': '〜を積み重ねる'},
#  {'pile': '〜を積み重ねる'},
#  {'adjust': '〜を調節する'},
#  {'assemble': '〜を組み立てる'},
#  {'halt': '〜を停止させる'},
#  {'fix': '〜を修理する'},
#  {'erect': '〜を建てる'},
#  {'build': '〜を建てる'},
#  {'rebuild': '〜を再建する'},
#  {'remodel': '〜を改築する'},
#  {'complete': '〜を完成させる'},
#  {'resist': '〜に耐える'},
#  {'capture': '〜を捕まえる'},
#  {'deepen': '〜を深める'},
#  {'prolong': '〜を延長する'},
#  {'tap': '〜を開発する'},
#  {'eliminate': '〜を除外する'},
#  {'sustain': '〜を維持する'},
#  {'utilize': '〜を利用する'},
#  {'rinse': '〜をゆすぐ'},
#  {'import': '〜を輸入する'},
#  {'export': '〜を輸出する'},
#  {'reflect': '〜を映す、〜を反映させる'},
#  {'release': '〜を公表する'},
#  {'announce': '〜を公表する'},
#  {'address': '演説する'},
#  {'gain': '〜を得る'},
#  {'preserve': '〜を保護する'},
#  {'protect': '〜を保護する'},
#  {'gather': '集まる'},
#  {'note': '〜ということに気をつける'},
#  {'oppose': '〜に反対する'},
#  {'vote': '投票する'},
#  {'host': '〜を主催する'},
#  {'immigrate': '〜から移住する'},
#  {'emigrate': '〜へ移住する'},
#  {'hail': '〜を呼び止める'},
#  {'highlight': '〜を強調する'},
#  {'complicate': '〜を複雑にする'},
#  {'matter': '重要である'},
#  {'decide': '〜を決定する'},
#  {'determine': '〜を決定する'},
#  {'solve': '〜を解決する'},
#  {'settle': '〜を解決する、〜に住む'},
#  {'withhold': '〜を保留する'},
#  {'reserve': '〜を保留する'},
#  {'dispute': '論争する'},
#  {'debate': '討論する'},
#  {'grasp': '〜を理解する、〜を掴む'},
#  {'understand': '〜を理解する'},
#  {'commence': '〜を開始する'},
#  {'finalize': '〜を仕上げる、終わらせる'},
#  {'question': '〜を疑う'},
#  {'doubt': '〜を疑う'},
#  {'postpone': '〜を延期する'},
#  {'cancel': '〜を中止する'},
#  {'interrupt': '〜を遮る（邪魔する）'},
#  {'pass': '（議案）を可決する'},
#  {'double': '〜を2倍にする'},
#  ...]

# %%
url = "http://www.eigo-duke.com/tango/TOEIC1-300.html"
res = requests.get(url)
soup = BeautifulSoup(res.content, "lxml")
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html>
# <head>
# <meta content="JustSystems Homepage Builder Version 21.0.1.0 for Windows" name="GENERATOR"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="width=device-width" name="viewport"/>
# <title>TOEIC単語3000語の一覧：頻出1－300語</title>
# <meta content="TOEIC単語の良く出る1－300語を一覧で紹介。単語をかくす/チェックで保存など単語帳アプリ機能付きで効率的な覚え方が出来ます。TOEICテストに良く出る3000語を全て無料で公開しています。" name="description"/>
# <meta content="TOEIC,単語,単語帳,勉強法,アプリ,テスト,一覧,覚え方" name="keywords"/>
# <link href="table.css" id="_HPB_TABLE_CSS_ID_" rel="stylesheet" type="text/css"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-2238716-5"></script>
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-2238716-5');
# </script>
# </head>
# <body>
# <table align="center">
# <tbody>
# <tr>
# <td align="center" valign="top">
# <img alt="TOEIC頻出英単語の一覧・全て無料で覚えられ、単語をかくして覚えたり単語帳として表示でき、単語テストのアプリ機能もあります。" border="0" class="topimg" src="img/toeicm.gif" usemap="#Map"/><br/>
# <map name="Map">
# <area alt="英単語一覧ページへ" coords="5,10,100,50" href="https://eigo-duke.com/tango/tangoindex.html" shape="rect"/>
# </map><br/>
# <h1><span class="title">TOEIC英単語:1-300語</span></h1>
# <br/>
# <div class="point">
# <span class="box-title">このページで出来ること</span> 1.<a href="#test">TOEIC頻出1-300語テスト<br/>
# </a>2.<a href="#card">分からない単語で単語帳作成</a><br/>
#       3.<a href="#1">TOEIC単語の一覧</a>(聞き流す・覚える)<br/>
#             (<a href="#1">1-100語↓</a> <a href="#2">101-200語↓</a> <a href="#3">201-300語↓</a>)</div>
# <a id="test" name="test"></a>
# <table class="maintable">
# <tbody>
# <tr>
# <th>TOEIC頻出1－300語テスト</th>
# </tr>
# </tbody>
# </table>
# <div class="quiz_area">
# <div class="quiz_set">
#         第<span class="quiz_no">0</span>問/10問<br/>
# <div class="quiz_question"></div>
# <div class="quiz_ans_area">
# <ul></ul>
# </div>
# <div class="quiz_area_bg"></div>
# <div class="quiz_area_icon"></div>
# </div>
# <div class="quiz_result"></div>
# </div>
# <br/>
# <a href="TOEIC1-1000.html">TOEIC最重要1000語を覚える</a><br/>※頻出3000語からさらに絞り込み<br/>
# <br/>
# <table class="maintable">
# <tbody>
# <tr>
# <th><h2>ＴＯＥＩＣ頻出英単語</h2></th>
# </tr>
# <tr>
# <td style="text-align:center;"><font size="2"><a href="TOEIC1-300.html">1～300語</a>⇒<a href="TOEIC301-600.html">301～600語</a>⇒<a href="TOEIC601-900.html">601～900語</a>⇒<a href="TOEIC901-1200.html">901～1200語</a>⇒<a href="TOEIC1201-1500.html">1201～1500語</a>⇒<a href="TOEIC1501-1800.html">1501～1800語</a>⇒<a href="TOEIC1801-2100.html">1801～2100語</a>⇒<a href="TOEIC2101-2400.html">2101～2400語</a>⇒<a href="TOEIC2401-2700.html">2401～2700語</a>⇒<a href="TOEIC2701-3000.html">2701～3000語</a></font></td>
# </tr>
# </tbody>
# </table>
# <br/><!-- EIgo-duke Tango Sita text -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-3234684892462480" data-ad-format="auto" data-ad-slot="9794517919" data-full-width-responsive="false" style="display:block"></ins>
# <script>
#                 (adsbygoogle = window.adsbygoogle || []).push({});
#            </script>
# <br/>
# <a id="card" name="card"></a><br/>
# <table class="maintable">
# <tbody>
# <tr>
# <th>英単語帳</th>
# </tr>
# </tbody>
# </table>
# <br/><a hidden="" href="" id="tweetLink" style=""></a>
# <button class="btn-sticky" id="state1-button" onclick="showDisp3()" type="button">チェックした単語を表示する</button><br/>
# <button class="btn-sticky" id="state1-button" onclick="showDisp2()" type="button">英語だけ表示</button>
# <button class="btn-sticky" id="state1-button" onclick="showDisp()" type="button">日本語だけ表示</button>
# <br/>
# <br/>
# <div align="left" class="note" id="showArea">　　　　ここに単語が表示されます。</div>
# <div style="display:inline-flex">
# <input alt="SNSで英単語をシェア" height="50" id="shareBtn" src="share.png" style="display:none;" type="image" width="50"/>
#           <input alt="メールで英単語をシェア" id="sendMailBtn" onclick="sendMail()" src="mail.png" style="display:none;" type="image"/>
#           <input alt="LINEで英単語をシェア" class="nonepc" id="sendLineBtn" onclick="sendLine()" src="LINE.png" style="display:none;" type="image"/>
#           <input alt="twitterで英単語をシェア" class="nonepc" id="tweetBtn" onclick="tweet()" src="twitter.png" style="display:none;" type="image"/>
#       </div>
# <br/>
# <div class="love" onclick="hoge(event)">
# <input onclick="markerScroll($('#targetField'))" type="button" value="ﾏｰｶｰへ"/>
# <button name="jap" type="button">英語かくす</button>
# <button name="eng" type="button">日本語かくす</button>
# <button name="eng:jap" type="button">もどす</button>
# </div>
# <a id="1" name="1"></a>
# <hr/>
# TOEIC頻出1-300語の一覧<br/><font size="-1">
#  ・音声再生ボタンで<font color="#ff0000" size="-1">英語の発音</font>が聞けます。<br/>
#  ・チェックボタンで単語が記憶され、まとめて単語帳として表示できます。<br/>
#  ・画面タッチ＆クリックで<font color="#ff0000" size="-1">黄色ﾏｰｶｰを引く</font>ことが出来ます。
#  </font><br/><br/>
# <div id="targetField">
# <p>
# <span id="item_list">
# <table class="table">
# <tbody>
# <tr><th colspan="5"><h2>TOEIC頻出英単語：1－100語</h2></th></tr>
# <tr><td align="center" colspan="5" style="text-align : center;">聞き流し<br/>
# <font size="-1">*聞き流しは再生ボタンで最大2M程のデータ消費<br/>
#       (必要に応じＷｉｆｉ環境でお使い下さい)</font><br/>
# <audio controls="" preload="none" src="sound/toeic/alltoeic1-100.mp3"></audio></td></tr>
# <tr><td align="center" style="text-align : center;"><img alt="英単語の音声" height="24" src="sound.gif" width="24"/></td>
# <td align="center" style="text-align : center;">順</td>
# <td align="center" style="text-align : center;">英語</td>
# <td align="center" style="text-align : center;">日本語</td>
# <td align="center" style="text-align : center;"><img alt="分からない英単語チェック" height="18" src="check.gif" width="18"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/the.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>1</td><td><div class="eng">the</div></td><td><div class="jap">その</div></td><td><input class="save-state1" data-savekey="その" id="the" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/to.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>2</td><td><div class="eng">to</div></td><td><div class="jap">～へ</div></td><td><input class="save-state1" data-savekey="～へ" id="to" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/a.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>3</td><td><div class="eng">a</div></td><td><div class="jap">1つの</div></td><td><input class="save-state1" data-savekey="1つの" id="a" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/of.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>4</td><td><div class="eng">of</div></td><td><div class="jap">の</div></td><td><input class="save-state1" data-savekey="の" id="of" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/in.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>5</td><td><div class="eng">in</div></td><td><div class="jap">～の中</div></td><td><input class="save-state1" data-savekey="～の中" id="in" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/is.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>6</td><td><div class="eng">is</div></td><td><div class="jap">～である、いる</div></td><td><input class="save-state1" data-savekey="～である、いる" id="is" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/and.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>7</td><td><div class="eng">and</div></td><td><div class="jap">～と、そして</div></td><td><input class="save-state1" data-savekey="～と、そして" id="and" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/for.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>8</td><td><div class="eng">for</div></td><td><div class="jap">～のために</div></td><td><input class="save-state1" data-savekey="～のために" id="for" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/it.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>9</td><td><div class="eng">it</div></td><td><div class="jap">それ</div></td><td><input class="save-state1" data-savekey="それ" id="it" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/that.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>10</td><td><div class="eng">that</div></td><td><div class="jap">あの</div></td><td><input class="save-state1" data-savekey="あの" id="that" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/this.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>11</td><td><div class="eng">this</div></td><td><div class="jap">この</div></td><td><input class="save-state1" data-savekey="この" id="this" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/be.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>12</td><td><div class="eng">be</div></td><td><div class="jap">～である、いる</div></td><td><input class="save-state1" data-savekey="～である、いる" id="be" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/will.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>13</td><td><div class="eng">will</div></td><td><div class="jap">～するつもり</div></td><td><input class="save-state1" data-savekey="～するつもり" id="will" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/he.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>14</td><td><div class="eng">he</div></td><td><div class="jap">彼</div></td><td><input class="save-state1" data-savekey="彼" id="he" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/you.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>15</td><td><div class="eng">you</div></td><td><div class="jap">あなた</div></td><td><input class="save-state1" data-savekey="あなた" id="you" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/on.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>16</td><td><div class="eng">on</div></td><td><div class="jap">～の上</div></td><td><input class="save-state1" data-savekey="～の上" id="on" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/what.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>17</td><td><div class="eng">what</div></td><td><div class="jap">何</div></td><td><input class="save-state1" data-savekey="何" id="what" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/I.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>18</td><td><div class="eng">I</div></td><td><div class="jap">わたし</div></td><td><input class="save-state1" data-savekey="わたし" id="I" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/have.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>19</td><td><div class="eng">have</div></td><td><div class="jap">持っている、食べる</div></td><td><input class="save-state1" data-savekey="持っている、食べる" id="have" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/at.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>20</td><td><div class="eng">at</div></td><td><div class="jap">～で</div></td><td><input class="save-state1" data-savekey="～で" id="at" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/are.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>21</td><td><div class="eng">are</div></td><td><div class="jap">～である、いる</div></td><td><input class="save-state1" data-savekey="～である、いる" id="are" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/was.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>22</td><td><div class="eng">was</div></td><td><div class="jap">～であった</div></td><td><input class="save-state1" data-savekey="～であった" id="was" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/they.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>23</td><td><div class="eng">they</div></td><td><div class="jap">彼ら</div></td><td><input class="save-state1" data-savekey="彼ら" id="they" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/with.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>24</td><td><div class="eng">with</div></td><td><div class="jap">～とともに</div></td><td><input class="save-state1" data-savekey="～とともに" id="with" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/as.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>25</td><td><div class="eng">as</div></td><td><div class="jap">～のように</div></td><td><input class="save-state1" data-savekey="～のように" id="as" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/by.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>26</td><td><div class="eng">by</div></td><td><div class="jap">～によって、～で</div></td><td><input class="save-state1" data-savekey="～によって、～で" id="by" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/from.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>27</td><td><div class="eng">from</div></td><td><div class="jap">～から</div></td><td><input class="save-state1" data-savekey="～から" id="from" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/she.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>28</td><td><div class="eng">she</div></td><td><div class="jap">彼女</div></td><td><input class="save-state1" data-savekey="彼女" id="she" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/not.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>29</td><td><div class="eng">not</div></td><td><div class="jap">～でない</div></td><td><input class="save-state1" data-savekey="～でない" id="not" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/about.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>30</td><td><div class="eng">about</div></td><td><div class="jap">～について</div></td><td><input class="save-state1" data-savekey="～について" id="about" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/all.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>31</td><td><div class="eng">all</div></td><td><div class="jap">すべての</div></td><td><input class="save-state1" data-savekey="すべての" id="all" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/we.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>32</td><td><div class="eng">we</div></td><td><div class="jap">わたしたち</div></td><td><input class="save-state1" data-savekey="わたしたち" id="we" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/has.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>33</td><td><div class="eng">has</div></td><td><div class="jap">もっている</div></td><td><input class="save-state1" data-savekey="もっている" id="has" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/can.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>34</td><td><div class="eng">can</div></td><td><div class="jap">～できる</div></td><td><input class="save-state1" data-savekey="～できる" id="can" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/new.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>35</td><td><div class="eng">new</div></td><td><div class="jap">新しい</div></td><td><input class="save-state1" data-savekey="新しい" id="new" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/your.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>36</td><td><div class="eng">your</div></td><td><div class="jap">あなたの</div></td><td><input class="save-state1" data-savekey="あなたの" id="your" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/would.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>37</td><td><div class="eng">would</div></td><td><div class="jap">～だろう</div></td><td><input class="save-state1" data-savekey="～だろう" id="would" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/an.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>38</td><td><div class="eng">an</div></td><td><div class="jap">一つの、ある</div></td><td><input class="save-state1" data-savekey="一つの、ある" id="an" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/how.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>39</td><td><div class="eng">how</div></td><td><div class="jap">どのように</div></td><td><input class="save-state1" data-savekey="どのように" id="how" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/do.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>40</td><td><div class="eng">do</div></td><td><div class="jap">～する</div></td><td><input class="save-state1" data-savekey="～する" id="do" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/his.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>41</td><td><div class="eng">his</div></td><td><div class="jap">彼の</div></td><td><input class="save-state1" data-savekey="彼の" id="his" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/or.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>42</td><td><div class="eng">or</div></td><td><div class="jap">または、もしくは</div></td><td><input class="save-state1" data-savekey="または、もしくは" id="or" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/our.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>43</td><td><div class="eng">our</div></td><td><div class="jap">わたしたちの</div></td><td><input class="save-state1" data-savekey="わたしたちの" id="our" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/company.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>44</td><td><div class="eng">company</div></td><td><div class="jap">会社</div></td><td><input class="save-state1" data-savekey="会社" id="company" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/if.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>45</td><td><div class="eng">if</div></td><td><div class="jap">もし</div></td><td><input class="save-state1" data-savekey="もし" id="if" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/does.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>46</td><td><div class="eng">does</div></td><td><div class="jap">する</div></td><td><input class="save-state1" data-savekey="する" id="does" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/had.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>47</td><td><div class="eng">had</div></td><td><div class="jap">持っていた</div></td><td><input class="save-state1" data-savekey="持っていた" id="had" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/more.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>48</td><td><div class="eng">more</div></td><td><div class="jap">よりたくさんの</div></td><td><input class="save-state1" data-savekey="よりたくさんの" id="more" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/when.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>49</td><td><div class="eng">when</div></td><td><div class="jap">いつ</div></td><td><input class="save-state1" data-savekey="いつ" id="when" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/been.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>50</td><td><div class="eng">been</div></td><td><div class="jap">beの過去分詞</div></td><td><input class="save-state1" data-savekey="beの過去分詞" id="been" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/time.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>51</td><td><div class="eng">time</div></td><td><div class="jap">時間</div></td><td><input class="save-state1" data-savekey="時間" id="time" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/their.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>52</td><td><div class="eng">their</div></td><td><div class="jap">彼らの</div></td><td><input class="save-state1" data-savekey="彼らの" id="their" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/but.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>53</td><td><div class="eng">but</div></td><td><div class="jap">しかし</div></td><td><input class="save-state1" data-savekey="しかし" id="but" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/were.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>54</td><td><div class="eng">were</div></td><td><div class="jap">なった</div></td><td><input class="save-state1" data-savekey="なった" id="were" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/should.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>55</td><td><div class="eng">should</div></td><td><div class="jap">～するべきである</div></td><td><input class="save-state1" data-savekey="～するべきである" id="should" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/who.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>56</td><td><div class="eng">who</div></td><td><div class="jap">誰</div></td><td><input class="save-state1" data-savekey="誰" id="who" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/there.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>57</td><td><div class="eng">there</div></td><td><div class="jap">そこに</div></td><td><input class="save-state1" data-savekey="そこに" id="there" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/her.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>58</td><td><div class="eng">her</div></td><td><div class="jap">彼女の</div></td><td><input class="save-state1" data-savekey="彼女の" id="her" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/people.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>59</td><td><div class="eng">people</div></td><td><div class="jap">人々</div></td><td><input class="save-state1" data-savekey="人々" id="people" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/up.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>60</td><td><div class="eng">up</div></td><td><div class="jap">上へ</div></td><td><input class="save-state1" data-savekey="上へ" id="up" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/which.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>61</td><td><div class="eng">which</div></td><td><div class="jap">どちら</div></td><td><input class="save-state1" data-savekey="どちら" id="which" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/than.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>62</td><td><div class="eng">than</div></td><td><div class="jap">～よりも</div></td><td><input class="save-state1" data-savekey="～よりも" id="than" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/only.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>63</td><td><div class="eng">only</div></td><td><div class="jap">唯一の</div></td><td><input class="save-state1" data-savekey="唯一の" id="only" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/some.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>64</td><td><div class="eng">some</div></td><td><div class="jap">いくつかの</div></td><td><input class="save-state1" data-savekey="いくつかの" id="some" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/man.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>65</td><td><div class="eng">man</div></td><td><div class="jap">男、男性</div></td><td><input class="save-state1" data-savekey="男、男性" id="man" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/no.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>66</td><td><div class="eng">no</div></td><td><div class="jap">いいえ</div></td><td><input class="save-state1" data-savekey="いいえ" id="no" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/work.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>67</td><td><div class="eng">work</div></td><td><div class="jap">働く</div></td><td><input class="save-state1" data-savekey="働く" id="work" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/did.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>68</td><td><div class="eng">did</div></td><td><div class="jap">した</div></td><td><input class="save-state1" data-savekey="した" id="did" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/many.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>69</td><td><div class="eng">many</div></td><td><div class="jap">たくさんの</div></td><td><input class="save-state1" data-savekey="たくさんの" id="many" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/so.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>70</td><td><div class="eng">so</div></td><td><div class="jap">だから、とても</div></td><td><input class="save-state1" data-savekey="だから、とても" id="so" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/out.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>71</td><td><div class="eng">out</div></td><td><div class="jap">はずれて</div></td><td><input class="save-state1" data-savekey="はずれて" id="out" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/because.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>72</td><td><div class="eng">because</div></td><td><div class="jap">なぜなら</div></td><td><input class="save-state1" data-savekey="なぜなら" id="because" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/Mr.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>73</td><td><div class="eng">Mr</div></td><td><div class="jap">ミスター</div></td><td><input class="save-state1" data-savekey="ミスター" id="Mr" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/why.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>74</td><td><div class="eng">why</div></td><td><div class="jap">なぜ</div></td><td><input class="save-state1" data-savekey="なぜ" id="why" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/office.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>75</td><td><div class="eng">office</div></td><td><div class="jap">オフィス</div></td><td><input class="save-state1" data-savekey="オフィス" id="office" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/most.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>76</td><td><div class="eng">most</div></td><td><div class="jap">一番たくさんの</div></td><td><input class="save-state1" data-savekey="一番たくさんの" id="most" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/where.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>77</td><td><div class="eng">where</div></td><td><div class="jap">どこ</div></td><td><input class="save-state1" data-savekey="どこ" id="where" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/woman.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>78</td><td><div class="eng">woman</div></td><td><div class="jap">女、女性</div></td><td><input class="save-state1" data-savekey="女、女性" id="woman" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/very.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>79</td><td><div class="eng">very</div></td><td><div class="jap">とても</div></td><td><input class="save-state1" data-savekey="とても" id="very" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/take.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>80</td><td><div class="eng">take</div></td><td><div class="jap">取る</div></td><td><input class="save-state1" data-savekey="取る" id="take" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/just.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>81</td><td><div class="eng">just</div></td><td><div class="jap">ちょうど</div></td><td><input class="save-state1" data-savekey="ちょうど" id="just" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/get.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>82</td><td><div class="eng">get</div></td><td><div class="jap">手に入れる</div></td><td><input class="save-state1" data-savekey="手に入れる" id="get" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/much.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>83</td><td><div class="eng">much</div></td><td><div class="jap">たくさんの</div></td><td><input class="save-state1" data-savekey="たくさんの" id="much" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/could.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>84</td><td><div class="eng">could</div></td><td><div class="jap">～することができた</div></td><td><input class="save-state1" data-savekey="～することができた" id="could" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/them.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>85</td><td><div class="eng">them</div></td><td><div class="jap">彼らに(を)</div></td><td><input class="save-state1" data-savekey="彼らに(を)" id="them" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/these.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>86</td><td><div class="eng">these</div></td><td><div class="jap">これらの</div></td><td><input class="save-state1" data-savekey="これらの" id="these" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/think.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>87</td><td><div class="eng">think</div></td><td><div class="jap">考える</div></td><td><input class="save-state1" data-savekey="考える" id="think" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/go.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>88</td><td><div class="eng">go</div></td><td><div class="jap">行く</div></td><td><input class="save-state1" data-savekey="行く" id="go" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/other.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>89</td><td><div class="eng">other</div></td><td><div class="jap">その他の</div></td><td><input class="save-state1" data-savekey="その他の" id="other" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/before.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>90</td><td><div class="eng">before</div></td><td><div class="jap">～の前に</div></td><td><input class="save-state1" data-savekey="～の前に" id="before" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/over.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>91</td><td><div class="eng">over</div></td><td><div class="jap">～を超えて</div></td><td><input class="save-state1" data-savekey="～を超えて" id="over" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/year.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>92</td><td><div class="eng">year</div></td><td><div class="jap">年</div></td><td><input class="save-state1" data-savekey="年" id="year" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/make.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>93</td><td><div class="eng">make</div></td><td><div class="jap">作る</div></td><td><input class="save-state1" data-savekey="作る" id="make" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/my.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>94</td><td><div class="eng">my</div></td><td><div class="jap">わたしの</div></td><td><input class="save-state1" data-savekey="わたしの" id="my" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/any.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>95</td><td><div class="eng">any</div></td><td><div class="jap">どれでも</div></td><td><input class="save-state1" data-savekey="どれでも" id="any" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/may.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>96</td><td><div class="eng">may</div></td><td><div class="jap">～かもしれない</div></td><td><input class="save-state1" data-savekey="～かもしれない" id="may" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/first.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>97</td><td><div class="eng">first</div></td><td><div class="jap">最初の</div></td><td><input class="save-state1" data-savekey="最初の" id="first" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/after.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>98</td><td><div class="eng">after</div></td><td><div class="jap">～の後で</div></td><td><input class="save-state1" data-savekey="～の後で" id="after" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/him.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>99</td><td><div class="eng">him</div></td><td><div class="jap">彼に(を)</div></td><td><input class="save-state1" data-savekey="彼に(を)" id="him" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/today.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>100</td><td><div class="eng">today</div></td><td><div class="jap">本日</div></td><td><input class="save-state1" data-savekey="本日" id="today" type="checkbox" value="1"/></td></tr>
# </tbody>
# </table>
# <a id="2" name="2"></a><br/>
# <table class="table">
# <tbody>
# <tr><th colspan="5"><h2>TOEIC頻出英単語：101－200語</h2></th></tr>
# <tr><td align="center" colspan="5" style="text-align : center;">聞き流し<br/>
# <font size="-1">*聞き流しは再生ボタンで最大2M程のデータ消費<br/>
#       (必要に応じＷｉｆｉ環境でお使い下さい)</font><br/>
# <audio controls="" preload="none" src="sound/toeic/alltoeic101-200.mp3"></audio></td></tr>
# <tr><td align="center" style="text-align : center;"><img alt="英単語の音声" height="24" src="sound.gif" width="24"/></td>
# <td align="center" style="text-align : center;">順</td>
# <td align="center" style="text-align : center;">英語</td>
# <td align="center" style="text-align : center;">日本語</td>
# <td align="center" style="text-align : center;"><img alt="分からない英単語チェック" height="18" src="check.gif" width="18"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/business.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>101</td><td><div class="eng">business</div></td><td><div class="jap">ビジネス</div></td><td><input class="save-state1" data-savekey="ビジネス" id="business" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/weeks.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>102</td><td><div class="eng">weeks</div></td><td><div class="jap">週（複数）</div></td><td><input class="save-state1" data-savekey="週（複数）" id="weeks" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/computer.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>103</td><td><div class="eng">computer</div></td><td><div class="jap">コンピュータ</div></td><td><input class="save-state1" data-savekey="コンピュータ" id="computer" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/like.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>104</td><td><div class="eng">like</div></td><td><div class="jap">好き</div></td><td><input class="save-state1" data-savekey="好き" id="like" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/those.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>105</td><td><div class="eng">those</div></td><td><div class="jap">あれらの</div></td><td><input class="save-state1" data-savekey="あれらの" id="those" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/yes.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>106</td><td><div class="eng">yes</div></td><td><div class="jap">はい</div></td><td><input class="save-state1" data-savekey="はい" id="yes" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/next.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>107</td><td><div class="eng">next</div></td><td><div class="jap">次の</div></td><td><input class="save-state1" data-savekey="次の" id="next" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/good.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>108</td><td><div class="eng">good</div></td><td><div class="jap">良い</div></td><td><input class="save-state1" data-savekey="良い" id="good" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/know.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>109</td><td><div class="eng">know</div></td><td><div class="jap">知っている</div></td><td><input class="save-state1" data-savekey="知っている" id="know" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/made.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>110</td><td><div class="eng">made</div></td><td><div class="jap">作られた、作った</div></td><td><input class="save-state1" data-savekey="作られた、作った" id="made" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/day.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>111</td><td><div class="eng">day</div></td><td><div class="jap">日</div></td><td><input class="save-state1" data-savekey="日" id="day" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/well.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>112</td><td><div class="eng">well</div></td><td><div class="jap">上手に、うまく</div></td><td><input class="save-state1" data-savekey="上手に、うまく" id="well" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/its.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>113</td><td><div class="eng">its</div></td><td><div class="jap">その</div></td><td><input class="save-state1" data-savekey="その" id="its" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/city.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>114</td><td><div class="eng">city</div></td><td><div class="jap">市、街</div></td><td><input class="save-state1" data-savekey="市、街" id="city" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/meeting.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>115</td><td><div class="eng">meeting</div></td><td><div class="jap">ミーティング</div></td><td><input class="save-state1" data-savekey="ミーティング" id="meeting" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/use.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>116</td><td><div class="eng">use</div></td><td><div class="jap">使用、使う</div></td><td><input class="save-state1" data-savekey="使用、使う" id="use" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/last.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>117</td><td><div class="eng">last</div></td><td><div class="jap">最後の</div></td><td><input class="save-state1" data-savekey="最後の" id="last" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/me.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>118</td><td><div class="eng">me</div></td><td><div class="jap">わたしに(を)</div></td><td><input class="save-state1" data-savekey="わたしに(を)" id="me" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/month.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>119</td><td><div class="eng">month</div></td><td><div class="jap">月</div></td><td><input class="save-state1" data-savekey="月" id="month" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/now.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>120</td><td><div class="eng">now</div></td><td><div class="jap">今、現在</div></td><td><input class="save-state1" data-savekey="今、現在" id="now" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/please.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>121</td><td><div class="eng">please</div></td><td><div class="jap">どうぞ、お願い</div></td><td><input class="save-state1" data-savekey="どうぞ、お願い" id="please" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/must.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>122</td><td><div class="eng">must</div></td><td><div class="jap">～しなければならない</div></td><td><input class="save-state1" data-savekey="～しなければならない" id="must" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/best.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>123</td><td><div class="eng">best</div></td><td><div class="jap">最高の</div></td><td><input class="save-state1" data-savekey="最高の" id="best" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/car.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>124</td><td><div class="eng">car</div></td><td><div class="jap">車</div></td><td><input class="save-state1" data-savekey="車" id="car" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/during.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>125</td><td><div class="eng">during</div></td><td><div class="jap">～の間</div></td><td><input class="save-state1" data-savekey="～の間" id="during" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/number.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>126</td><td><div class="eng">number</div></td><td><div class="jap">数、番号</div></td><td><input class="save-state1" data-savekey="数、番号" id="number" type="checkbox" value="1"/></td></tr>
# ...
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/already.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>258</td><td><div class="eng">already</div></td><td><div class="jap">すでに</div></td><td><input class="save-state1" data-savekey="すでに" id="already" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/also.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>259</td><td><div class="eng">also</div></td><td><div class="jap">同様に</div></td><td><input class="save-state1" data-savekey="同様に" id="also" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/card.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>260</td><td><div class="eng">card</div></td><td><div class="jap">カード</div></td><td><input class="save-state1" data-savekey="カード" id="card" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/didn’t.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>261</td><td><div class="eng">didn’t</div></td><td><div class="jap">しなかった</div></td><td><input class="save-state1" data-savekey="しなかった" id="didn’t" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/got.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>262</td><td><div class="eng">got</div></td><td><div class="jap">手に入れた</div></td><td><input class="save-state1" data-savekey="手に入れた" id="got" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/price.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>263</td><td><div class="eng">price</div></td><td><div class="jap">価格</div></td><td><input class="save-state1" data-savekey="価格" id="price" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/put.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>264</td><td><div class="eng">put</div></td><td><div class="jap">置く</div></td><td><input class="save-state1" data-savekey="置く" id="put" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/water.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>265</td><td><div class="eng">water</div></td><td><div class="jap">水</div></td><td><input class="save-state1" data-savekey="水" id="water" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/amount.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>266</td><td><div class="eng">amount</div></td><td><div class="jap">量</div></td><td><input class="save-state1" data-savekey="量" id="amount" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/computers.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>267</td><td><div class="eng">computers</div></td><td><div class="jap">コンピュータ（複数）</div></td><td><input class="save-state1" data-savekey="コンピュータ（複数）" id="computers" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/say.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>268</td><td><div class="eng">say</div></td><td><div class="jap">言う</div></td><td><input class="save-state1" data-savekey="言う" id="say" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/both.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>269</td><td><div class="eng">both</div></td><td><div class="jap">両方</div></td><td><input class="save-state1" data-savekey="両方" id="both" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/done.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>270</td><td><div class="eng">done</div></td><td><div class="jap">完了した</div></td><td><input class="save-state1" data-savekey="完了した" id="done" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/past.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>271</td><td><div class="eng">past</div></td><td><div class="jap">過去</div></td><td><input class="save-state1" data-savekey="過去" id="past" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/send.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>272</td><td><div class="eng">send</div></td><td><div class="jap">送る</div></td><td><input class="save-state1" data-savekey="送る" id="send" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/through.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>273</td><td><div class="eng">through</div></td><td><div class="jap">～を通って、～を経て</div></td><td><input class="save-state1" data-savekey="～を通って、～を経て" id="through" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/university.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>274</td><td><div class="eng">university</div></td><td><div class="jap">大学</div></td><td><input class="save-state1" data-savekey="大学" id="university" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/buy.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>275</td><td><div class="eng">buy</div></td><td><div class="jap">買う</div></td><td><input class="save-state1" data-savekey="買う" id="buy" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/experience.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>276</td><td><div class="eng">experience</div></td><td><div class="jap">経験</div></td><td><input class="save-state1" data-savekey="経験" id="experience" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/however.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>277</td><td><div class="eng">however</div></td><td><div class="jap">しかしながら</div></td><td><input class="save-state1" data-savekey="しかしながら" id="however" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/m.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>278</td><td><div class="eng">m</div></td><td><div class="jap">メートル</div></td><td><input class="save-state1" data-savekey="メートル" id="m" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/plan.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>279</td><td><div class="eng">plan</div></td><td><div class="jap">計画</div></td><td><input class="save-state1" data-savekey="計画" id="plan" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/still.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>280</td><td><div class="eng">still</div></td><td><div class="jap">まだ</div></td><td><input class="save-state1" data-savekey="まだ" id="still" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/survey.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>281</td><td><div class="eng">survey</div></td><td><div class="jap">調査</div></td><td><input class="save-state1" data-savekey="調査" id="survey" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/using.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>282</td><td><div class="eng">using</div></td><td><div class="jap">使用している</div></td><td><input class="save-state1" data-savekey="使用している" id="using" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/asked.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>283</td><td><div class="eng">asked</div></td><td><div class="jap">質問した</div></td><td><input class="save-state1" data-savekey="質問した" id="asked" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/bank.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>284</td><td><div class="eng">bank</div></td><td><div class="jap">銀行</div></td><td><input class="save-state1" data-savekey="銀行" id="bank" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/change.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>285</td><td><div class="eng">change</div></td><td><div class="jap">変化、変える</div></td><td><input class="save-state1" data-savekey="変化、変える" id="change" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/every.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>286</td><td><div class="eng">every</div></td><td><div class="jap">すべての</div></td><td><input class="save-state1" data-savekey="すべての" id="every" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/letter.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>287</td><td><div class="eng">letter</div></td><td><div class="jap">手紙</div></td><td><input class="save-state1" data-savekey="手紙" id="letter" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/movie.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>288</td><td><div class="eng">movie</div></td><td><div class="jap">映画</div></td><td><input class="save-state1" data-savekey="映画" id="movie" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/coffee.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>289</td><td><div class="eng">coffee</div></td><td><div class="jap">コーヒー</div></td><td><input class="save-state1" data-savekey="コーヒー" id="coffee" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/cost.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>290</td><td><div class="eng">cost</div></td><td><div class="jap">費用</div></td><td><input class="save-state1" data-savekey="費用" id="cost" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/less.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>291</td><td><div class="eng">less</div></td><td><div class="jap">より少ない</div></td><td><input class="save-state1" data-savekey="より少ない" id="less" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/manager.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>292</td><td><div class="eng">manager</div></td><td><div class="jap">管理者、マネージャー</div></td><td><input class="save-state1" data-savekey="管理者、マネージャー" id="manager" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/own.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>293</td><td><div class="eng">own</div></td><td><div class="jap">自身の</div></td><td><input class="save-state1" data-savekey="自身の" id="own" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/without.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>294</td><td><div class="eng">without</div></td><td><div class="jap">～なしで</div></td><td><input class="save-state1" data-savekey="～なしで" id="without" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/check.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>295</td><td><div class="eng">check</div></td><td><div class="jap">点検する、会計</div></td><td><input class="save-state1" data-savekey="点検する、会計" id="check" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/current.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>296</td><td><div class="eng">current</div></td><td><div class="jap">現在の</div></td><td><input class="save-state1" data-savekey="現在の" id="current" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/doesn’t.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>297</td><td><div class="eng">doesn’t</div></td><td><div class="jap">ではない</div></td><td><input class="save-state1" data-savekey="ではない" id="doesn’t" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/factory.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>298</td><td><div class="eng">factory</div></td><td><div class="jap">工場</div></td><td><input class="save-state1" data-savekey="工場" id="factory" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/given.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>299</td><td><div class="eng">given</div></td><td><div class="jap">与えられた</div></td><td><input class="save-state1" data-savekey="与えられた" id="given" type="checkbox" value="1"/></td></tr>
# <tr><td><button class="listenToAudio" data-mp3="sound/toeic/leave.mp3"><img alt="英単語再生/停止" height="18" src="soundbar.gif" width="18"/></button></td><td>300</td><td><div class="eng">leave</div></td><td><div class="jap">去る、残す</div></td><td><input class="save-state1" data-savekey="去る、残す" id="leave" type="checkbox" value="1"/></td></tr>
# </tbody>
# </table>
# </span>
# </p>
# </div>
# <ins class="adsbygoogle" data-ad-client="ca-pub-3234684892462480" data-ad-format="autorelaxed" data-ad-slot="3522844244" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <br/>
# <br/> <a href="https://eigo-duke.com/tango/tangoindex.html"><font size="2">英語漬け.com単語ホームへ戻る</font></a><br/>
# <br/>
# <br/>
# <br/>
# </td>
# </tr>
# </tbody>
# </table>
# <div id="pagetop">
# <a href="#">↑Top</a>
# </div>
# <script src="js/hide.js"></script>
# <script src="js/wordlist.js"></script>
# <script src="js/savestate.js"></script>
# <script src="js/scrolltest.js"></script>
# <script src="js/sound.js"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js?ver=1.12.4"></script>
# <script src="js/toeic1-300quiz.js"></script>
# <script src="js/jquery.yourhere.js" type="text/javascript"></script>
# <script type="text/javascript">
# 		$(document).ready(function(){
#             /*
#             ここでマーカーを使用したいフィールドを指定します。
#             jqueryは「#」がタグのIDを「.」がクラスをさします。
#             今回はIDなので「#」+「ID名」で#targetFieldとなります。
#             */
# 			$('#targetField').yourhere({
# 				markerBackground: 'url(images/marker.png) no-repeat center center',
# 				markerWidth: '13px',
# 				tempMarkerBackground: 'url(images/tempMarker.png) no-repeat center center'
# 			});
#         });
#     </script>
# </body>
# </html>

# %%
hrefs = [a["href"] for a in soup.find("table").find_all("table")[1].find("td").find_all("a")]
hrefs
# Out:
# ['TOEIC1-300.html',
#  'TOEIC301-600.html',
#  'TOEIC601-900.html',
#  'TOEIC901-1200.html',
#  'TOEIC1201-1500.html',
#  'TOEIC1501-1800.html',
#  'TOEIC1801-2100.html',
#  'TOEIC2101-2400.html',
#  'TOEIC2401-2700.html',
#  'TOEIC2701-3000.html']

# %%
word_list_4 = []
for href in hrefs[4:5]:
    time.sleep(1)
    url = "http://www.eigo-duke.com/tango/" + href
    res = requests.get(url)
    soup = BeautifulSoup(res.content, "lxml")
    for i in range(3,6):
        print(len(soup.find("table").find_all("table")[i].find_all("tr")[3:]))
        for tr in soup.find("table").find_all("table")[i].find_all("tr")[3:]:
            tds = tr.find_all("td")
    #         print(tds[2].text, tds[3].text)
            word_list_4.append({tds[2].text:tds[3].text})
word_list_4
# Out:
# 101
# 100
# 100
# [{'英語': '日本語'},
#  {'originally': 'もともと'},
#  {'discovered': '発見した'},
#  {'hall': 'ホール、玄関'},
#  {'sufficient': '十分な'},
#  {'homes': '住宅、家(複数)'},
#  {'boring': '退屈にする'},
#  {'gold': '金'},
#  {'nevertheless': 'それでもなお'},
#  {'handle': '操作する'},
#  {'good': '良い'},
#  {'apologize': '謝罪する'},
#  {'automation': '自動化'},
#  {'events': 'イベント'},
#  {'compared': '比較した'},
#  {'red': '赤'},
#  {'facility': '施設'},
#  {'loan': '融資する、融資'},
#  {'lunchroom': '食堂'},
#  {'cream': 'クリーム'},
#  {'Johnson': 'ジョンソン'},
#  {'Japanese': '日本語、日本人の'},
#  {'laptop': 'ノートパソコン'},
#  {'chairs': '椅子(複数)'},
#  {'delays': '遅延する（三単現）'},
#  {'express': '表現する'},
#  {'beyond': '～を超えて'},
#  {'valuable': '貴重な'},
#  {'pier': '桟橋'},
#  {'twice': '2回'},
#  {'boots': 'ブーツ'},
#  {'metal': '金属'},
#  {'difference': '差、違い'},
#  {'seem': '見える'},
#  {'terrible': 'ひどい'},
#  {'owners': '所有者(複数)'},
#  {'Denison': 'デニソン'},
#  {'breakfast': '朝食'},
#  {'normally': '普通に、正常に'},
#  {'appropriate': '適切な'},
#  {'individual': '個々の'},
#  {'vote': '投票、投票する'},
#  {'law': '法'},
#  {'submit': '提出する'},
#  {'shopping': 'ショッピング'},
#  {'political': '政治の'},
#  {'prefer': '好む'},
#  {'included': '含まれていた'},
#  {'firm': '固い'},
#  {'goals': '目標(複数)'},
#  {'positive': '積極的な、前向きな'},
#  {'reach': '到着する'},
#  {'looked': '見えた'},
#  {'gave': 'を与えた'},
#  {'printer': 'プリンター'},
#  {'labor': '労働'},
#  {'method': 'メソッド、方法'},
#  {'learn': '学ぶ'},
#  {'moving': '移動している'},
#  {'Sir': '男性の敬称'},
#  {'packages': 'パッケージ(複数)'},
#  {'vehicles': '車(複数)'},
#  {'condition': '条件'},
#  {'greater': 'より大きい'},
#  {'increases': '増加'},
#  {'medium': '中間の'},
#  {'cancer': '癌'},
#  {'proposal': '提案'},
#  {'mentions': '言及する、述べる(三単現)'},
#  {'site': 'サイト、場所'},
#  {'signed': '署名した'},
#  {'replaced': '置き換えた'},
#  {'pleased': '喜んで'},
#  {'ferry': 'フェリー'},
#  {'story': '物語'},
#  {'rates': '割合、レート(複数)'},
#  {'offering': 'を提案している'},
#  {'activity': '活動'},
#  {'unable': 'できない'},
#  {'smoke': '吸う、煙'},
#  {'details': '詳細(複数)'},
#  {'charges': '料金(複数)'},
#  {'reasons': '理由(複数)'},
#  {'promote': '推進する、昇進する'},
#  {'minimum': '最小の'},
#  {'placed': '配置した'},
#  {'sometimes': '時々'},
#  {'perfect': '完璧な'},
#  {'pacific': '太平洋の'},
#  {'respond': '返答する'},
#  {'direct': '直接'},
#  {'contains': 'を含む(三単現)'},
#  {'accounts': 'アカウント、口座(複数)'},
#  {'statement': '声明'},
#  {'festival': '祭り'},
#  {'river': '川'},
#  {'comfort': '快適さ'},
#  {'covered': '覆われた'},
#  {'arrives': '到着(三単現)'},
#  {'umbrellas': '傘(複数)'},
#  {'filing': '満たしている'},
#  {'starting': '開始している'},
#  {'ran': '走った'},
#  {'affect': 'に影響を与える'},
#  {'quick': '速い'},
#  {'relationship': '関係'},
#  {'message': 'メッセージ'},
#  {'David': 'デビッド'},
#  {'cities': '都市(複数)'},
#  {'ahead': '控え'},
#  {'coverage': 'カバレッジ'},
#  {'chips': 'チップ(複数)'},
#  {'welcome': '歓迎'},
#  {'smoking': '喫煙している、喫煙'},
#  {'Hong Kong': '香港'},
#  {'choice': '選択'},
#  {'king': '王'},
#  {'skiing': 'スキーをしている'},
#  {'hospital': '病院'},
#  {'via': '～経由で'},
#  {'ready': '準備ができている'},
#  {'global': 'グローバル'},
#  {'compare': '比較する'},
#  {'teaching': '教えている'},
#  {'worried': '心配した'},
#  {'pounds': 'ポンド(複数)'},
#  {'cell': '細胞'},
#  {'sheet': '用紙'},
#  {'previously': '以前は'},
#  {'huge': '巨大な'},
#  {'provided': '提供した'},
#  {'remind': '思い出させる'},
#  {'points': 'ポイント(複数)'},
#  {'besides': '加えて'},
#  {'institutions': '機関(複数)'},
#  {'national': '国家の'},
#  {'subject': '主題'},
#  {'northern': '北部の'},
#  {'husband': '夫'},
#  {'Shanghai': '上海'},
#  {'uses': '使用する(三単現)'},
#  {'Singapore': 'シンガポール'},
#  {'temperature': '温度'},
#  {'microwave': '電子レンジ'},
#  {'odor': '臭い'},
#  {'pet': 'ペット'},
#  {'gain': '得る'},
#  {'hire': '雇う'},
#  {'spot': 'スポット'},
#  {'climate': '気候'},
#  {'fail': '失敗する'},
#  {'residents': '住民(複数) '},
#  {'tests': 'テスト(複数)'},
#  {'capable': '容量のある'},
#  {'stock': '在庫'},
#  {'turned': '振り返った'},
#  {'advised': '忠告した'},
#  {'British': '英国人'},
#  {'animal': '動物'},
#  {'box': 'ボックス'},
#  {'groups': 'グループ(複数)'},
#  {'poor': '貧しい'},
#  {'bags': 'かばん(複数) '},
#  {'receipt': '領収書'},
#  {'severe': '厳しい、シビア、真面目な'},
#  {'cheaper': 'より安い'},
#  {'add': '追加する'},
#  {'technical': '技術的な'},
#  {'gather': '集まる'},
#  {'growth': '成長'},
#  {'profit': '利益'},
#  {'electronic': '電子'},
#  {'buses': 'バス(複数) '},
#  {'eating': '食べている'},
#  {'ride': '乗る、乗車'},
#  {'Australia': 'オーストラリア'},
#  {'tours': 'ツアー(複数)'},
#  {'enjoyed': '楽しんだ'},
#  {'automobile': '自動車'},
#  {'stand': '立つ'},
#  {'member': 'メンバー'},
#  {'remember': '思い出す'},
#  {'manufacturing': '製造している'},
#  {'drivers': 'ドライバー(複数) '},
#  {'term': '用語'},
#  {'instructions': '指示(複数)'},
#  {'energy': 'エネルギー'},
#  {'register': '登録する'},
#  {'believed': '信じた'},
#  {'inform': '知らせる'},
#  {'demand': '需要'},
#  {'worms': '虫(複数) '},
#  {'obtain': '保つ'},
#  {'nation': '国'},
#  {'programming': 'プログラミング'},
#  {'zoo': '動物園'},
#  {'invented': '発明した'},
#  {'volunteers': 'ボランティア(複数)'},
#  {'professional': 'プロの'},
#  {'holiday': '休日'},
#  {'superior': '優れた'},
#  {'sooner': '早く'},
#  {'letters': '手紙(複数)'},
#  {'audience': '観客'},
#  {'match': '試合'},
#  {'knife': 'ナイフ'},
#  {'view': '視野、観る'},
#  {'floods': '洪水(複数) '},
#  {'moved': '移動した、感動した'},
#  {'website': 'ウェブサイト'},
#  {'broke': '壊れた'},
#  {'operating': '作動している'},
#  {'select': '選択する'},
#  {'unusual': '珍しい'},
#  {'July': '7月'},
#  {'generally': '一般的に'},
#  {'confirm': '確認する'},
#  {'license': 'ライセンス(複数) '},
#  {'courses': 'コース(複数)'},
#  {'manufacturer': 'メーカー、製造者'},
#  {'speed': '速度'},
#  {'review': 'レビュー、復習'},
#  {'opportunity': '機会'},
#  {'cell phone': '携帯電話'},
#  {'function': '関数、機能'},
#  {'tasks': 'タスク、仕事(複数)'},
#  {'England': 'イングランド'},
#  {'compete': '競争'},
#  {'goes': '行く(三単現)'},
#  {'author': '著者'},
#  {'maintenance': 'メンテナンス'},
#  {'changed': '変わった'},
#  {'eastern': '東部の'},
#  {'devices': 'デバイス、装置(複数)'},
#  {'green': '緑'},
#  {'silk': '絹'},
#  {'friend': '友人'},
#  {'dinner': '夕食'},
#  {'wedding': '結婚式'},
#  {'supplier': 'サプライヤー'},
#  {'Kennedy': 'ケネディ'},
#  {'speakers': 'スピーカー(複数)'},
#  {'lack': '不足'},
#  {'markets': '市場(複数)'},
#  {'missing': '喪失'},
#  {'ok': 'OK'},
#  {'focus': '注目する'},
#  {'force': '力'},
#  {'retirement': '退職'},
#  {'sun': '太陽'},
#  {'branch': '枝'},
#  {'rise': '上る'},
#  {'salespeople': '販売員(複数)'},
#  {'basis': '基礎'},
#  {'corporate': '協力する'},
#  {'miss': '失敗する'},
#  {'Michigan': 'ミシガン'},
#  {'consequently': '結果的に'},
#  {'spa': 'スパ'},
#  {'efforts': '努力(複数)'},
#  {'central': '中心の'},
#  {'bonus': 'ボーナス'},
#  {'increasing': '増加している'},
#  {'speech': '演説'},
#  {'rest': '休む'},
#  {'developing': '開発している'},
#  {'ocean': '海'},
#  {'advance': '進む、進歩'},
#  {'delay': '遅れる'},
#  {'fall': '落ちる'},
#  {'Chinese': '中国語、中国人'},
#  {'toothbrush': '歯ブラシ'},
#  {'Wilson': 'ウィルソン'},
#  {'convenience': '便利'},
#  {'motorcycle': 'オートバイ'},
#  {'fast': '速い'},
#  {'kitchen': '台所'},
#  {'stores': '店舗(複数)'},
#  {'base': '基地'},
#  {'December': '12月'},
#  {'clay': '粘土'},
#  {'newest': '最新の'},
#  {'whole': '全体の'},
#  {'association': '協会'},
#  {'transfer': '転送する、乗り換える'},
#  {'sitting': '座っている'},
#  {'alike': '似た'},
#  {'skill': '技術'},
#  {'careful': '注意した'},
#  {'committee': '委員会'},
#  {'hoped': '望んだ、期待した'},
#  {'birds': '鳥(複数)'},
#  {'storm': '嵐'},
#  {'floppy': 'フロッピー'},
#  {'Nellie': 'ネリー'},
#  {'everything': 'すべて'},
#  {'models': 'モデル(複数)'},
#  {'finding': '探している'},
#  {'seriously': '真剣に'},
#  {'daily': '毎日の'},
#  {'Miami': 'マイアミ'}]

# %%
len(word_list_4)
# Out:
# 3001

# %%
{'英語': '日本語'} in word_list_4
# Out:
# True

# %%
word_list_4.remove({'英語': '日本語'})

# %%
{'英語': '日本語'} in word_list_4
# Out:
# False

# %%
word_list = []
word_list = word_list_1 + word_list_2 + word_list_3 + word_list_4
len(word_list)
# Out:
# 5100

# %%
list(word_list[0].keys())[0]
# Out:
# 'survey'

# %%
word_dict = {list(d.keys())[0]:list(d.values())[0] for d in word_list}
word_dict
# Out:
# {'survey': '調査',
#  'interview': '面接(する)',
#  'exhibition': '展示',
#  'conference': '会議',
#  'available': '利用可能な、入手可能な',
#  'annual': '毎年の',
#  'equipment': '装置',
#  'department': '部門、売り場',
#  'refund': '返金',
#  'receipt': '領収書',
#  'schedule': '〜を予定する',
#  'meeting': '会議',
#  'customer': '顧客',
#  'employee': '社員',
#  'actually': '実際は',
#  'according to': '~によると、~に従って',
#  'change': '小銭',
#  'contact': '〜と連絡を取る',
#  'purchase': '購入する／購入品',
#  'provide': '提供する',
#  'building': '建物',
#  'probably': 'おそらく',
#  'delay': '遅れる',
#  'opportunity': '機会',
#  'agree': '賛成する',
#  'invoice': '請求書、送り状',
#  'appointment': '約束',
#  'increase': '増加する',
#  'piece': '作品',
#  'participate in': '参加する',
#  'collect': '集める',
#  'once': 'いったん…すると',
#  'currently': '現在は',
#  'process': '〜を処理する',
#  'problem': '問題',
#  'experience': '〜を経験する',
#  'tour': '視察',
#  'while': '〜している間に／…の一方で',
#  'center': '中心地／センター',
#  'supervisor': '監督者',
#  'suggestion': '提案',
#  'coupon': 'クーポン',
#  'receive': '受け取る',
#  'participant': '参加者、関係者',
#  'note that': 'ご注意ください',
#  'confirm': '確認する',
#  'meet': '（要求）を満たす',
#  'reduce': '（費用を）削減する',
#  'concern': '懸念、関心ごと',
#  'way': '方法／道',
#  'special': '特別料理',
#  'prepare': '〜を準備する',
#  'renovation': '改修',
#  'early': '早い',
#  'view': '視野、観る',
#  'return': '〜を返す',
#  'approve': '〜を認める、許可する',
#  'budget': '予算',
#  'team': 'チーム',
#  'recently': '最近',
#  'shop': '買い物をする',
#  'fine': '罰金',
#  'home': '家',
#  'reservation': '予約',
#  'additional': '追加の',
#  'medical': '医療の',
#  'move': '引っ越す',
#  'resource': '資源',
#  'show': '展示会',
#  'design': '設計する',
#  'total': '合計の',
#  'presentation': 'プレゼンテーション',
#  'bring': '持ってくる／もたらす',
#  'improve': '〜を改善する',
#  'several': 'いくつか',
#  'news': '知らせ',
#  'service': '貢献',
#  'through': '…を通して',
#  'until': '…まで',
#  'passenger': '乗客',
#  'produce': '〜を生産する',
#  'allow': '〜を許す',
#  'representative': '代表者',
#  'check': '小切手',
#  'leave': '〜を残す',
#  'issue': '問題',
#  'price': '価格、値段／~に値段をつける',
#  'last': '続く、待つ',
#  'promote': '推進する、昇進する',
#  'hold': '開催する',
#  'idea': '考え',
#  'industry': '産業、業界',
#  'feature': '〜を呼び物にする',
#  'replacement': '交代',
#  'pay': '給料',
#  'update': '〜を更新する',
#  'director': '取締役',
#  'hire': '雇う',
#  'floor': '階',
#  'course': '課程',
#  'museum': '美術館、博物館',
#  'recommend': '〜を勧める',
#  'great': '優れた',
#  'install': '〜をインストールする',
#  'member': 'メンバー',
#  'size': '大きさ',
#  'management': '管理、経 営、経営陣',
#  'review': 'レビュー、復習',
#  'sincerely': '心から、心底',
#  'logo': 'ロゴ',
#  'revise': '～を修正する、改訂する',
#  'corporate': '協力する',
#  'construction': '建設',
#  'deadline': '締め切り',
#  'sign': '〜に署名する',
#  'replace': '〜を交換する',
#  'find': '気づく、発見する',
#  'register': '登録する',
#  'merchandise': '商品',
#  'important': '重要な',
#  'open': '開ける',
#  'facility': '施設',
#  'identification': '身分証',
#  'instead': 'その代わりに',
#  'before': '〜よりも前に',
#  'remember': '思い出す',
#  'public': '公共の',
#  'submit': '提出する',
#  'vacation': '休日',
#  'guest': '客',
#  'award': '賞',
#  'discuss': '〜を話し合う',
#  'cost': '費用',
#  'wait': '待つ',
#  'entrance': '入り口、入学',
#  'program': '番組',
#  'read': '読む',
#  'choose': '選ぶ',
#  'however': 'しかしながら',
#  'free': '無料の／自由な',
#  'ticket': '入場券',
#  'expand': '〜を拡大する',
#  'application': '申し込み',
#  'item': '項目、品物',
#  'résumé': '履歴書',
#  'vehicle': '乗り物',
#  'park': '公園／駐車する',
#  'council': '会議',
#  'book': '予約する',
#  'candidate': '候補者',
#  'complete': '〜を完成させる',
#  'discount': '割引／~を無視する',
#  'quality': '質',
#  'payment': '支払い',
#  'arrange': '〜を整理する',
#  'different': '違う',
#  'project': '〜を予想する',
#  'few': 'わずかな',
#  'after': '〜の後で',
#  'subject': '主題',
#  'already': '既に',
#  'require': '要求する',
#  'due': '支払期日が来て',
#  'consider': '〜を考慮する',
#  'ship': '〜を発送する',
#  'possible': '可能な',
#  'local': '地元の',
#  'area': '地域',
#  'into': '…の中に',
#  'delivery': '配送',
#  'professional': 'プロの',
#  'buy': '買う',
#  'carry': '〜を扱っている',
#  'belong': '…に付属する',
#  'type': '種類／類型',
#  'since': '…以来',
#  'colleague': '同僚',
#  'request': '要求する',
#  'material': '材料',
#  'fee': '料金',
#  'each': 'それぞれの',
#  'benefit': '給付',
#  'furniture': '家具',
#  'again': '再び',
#  'set': '配置する',
#  'during': '…の間に',
#  'sorry': 'すまなく思って',
#  'financial': '財政の',
#  'be interested in': '…に興味を持っている',
#  'attend': '出席する、参加する',
#  'maintenance': 'メンテナンス',
#  'supply': '供給',
#  'welcome': '歓迎',
#  'conduct': '〜を行う',
#  'report': '報告(書)',
#  'begin': '〜を始める',
#  'whether': '~かどうか',
#  'upcoming': '今度の',
#  'purpose': '目的',
#  'research': '研究',
#  'large': '大きい／広い',
#  'encourage': '勧める、促す',
#  'finish': '…を終える',
#  'send': '送る',
#  'charge': '料金',
#  'decision': '決定',
#  'inventory': '在庫',
#  'publish': '〜を出版する',
#  'think': '…と思う',
#  'reception': '歓迎会',
#  'display': '〜を展示する',
#  'both': '両方の',
#  'advance': '進む、進歩',
#  'always': '常に',
#  'plan': '計画',
#  'ready': '準備ができている',
#  'visit': '訪問する',
#  'document': '文書、書類',
#  'successful': '成功した、うまく行く',
#  'class': 'クラス／種類',
#  'library': '図書館、蔵書、コレクション',
#  'seminar': '研究会',
#  'sell': '売れる',
#  'close': '近い',
#  'expect': '〜を期待する',
#  'arrive': '到着する',
#  'remove': '〜を剥がす',
#  'position': '地位',
#  'talk': '会談',
#  'describe': '〜を描写する、説明する',
#  'flight': '飛行',
#  'repair': '〜を修理する',
#  'training': '訓練',
#  'a lot of': 'たくさんの',
#  'learn': '学ぶ',
#  'unfortunately': '残念なことに',
#  'people': '人々',
#  'cancel': '〜を中止する',
#  'include': '含む',
#  'location': '場所',
#  'client': '顧客',
#  'place': '置く',
#  'travel': '行く',
#  'though': 'けれども／たとえ…しても',
#  'board': '搭乗する',
#  'write': '書く',
#  'feedback': 'フィードバック、反応、意見',
#  'performance': '業績',
#  'soon': 'すぐ後',
#  'per': '…につき',
#  'catering': '仕出し、出前、ケータリング',
#  'ensure': '〜を保証する',
#  'estimate': '見積もり',
#  'potential': '潜在的な',
#  'remind': '思い出させる',
#  'intend': '意図する',
#  'delighted': 'とても喜んでいる',
#  'despite': '~にもかかわらず',
#  'specialize in': '…を専門に扱う',
#  'complimentary': '無料の',
#  'although': '…だけれども',
#  'beverage': '飲み物',
#  'honor': '光栄',
#  'mayor': '町長、市長',
#  'venue': '会場、開催地',
#  'immediately': 'すぐに',
#  'sound': '適切な',
#  'contemporary': '現代の',
#  'badge': 'バッジ',
#  'appliance': '器具',
#  'assist': '助ける',
#  'inspection': '検査',
#  'expire': '契約が終了する、切れる',
#  'necessary': '必要な',
#  'associate': '同僚',
#  'paperwork': '書類、書類作業',
#  'Excuse me.': 'すいません',
#  'Let’s': '…しよう',
#  'remain': '〜のまま',
#  'correct': '正確な',
#  'continue': '続ける',
#  'certainly': '確かに、きっと',
#  'fabric': '生地、織物',
#  'patient': '忍耐',
#  'applicant': '候補者',
#  'architect': '建築家',
#  'attach': '添付する、取り付ける',
#  'variety': '種類',
#  'anyway': 'とにかく',
#  'conversation': '会議',
#  'forget': '忘れる',
#  'shuttle': '往復運転で運ぶ',
#  'appear': '〜のように見える（思える）',
#  'crew': '乗務員',
#  'vote': '投票、投票する',
#  'busy': '忙しい',
#  'coworker': '同僚',
#  'excellent': '優れた',
#  'grocery': '食料雑貨店',
#  'save': '〜を貯蓄する、取っておく',
#  'cause': '〜を引き起こす',
#  'attract': '~をひきつける、魅了する',
#  'launch': '開始、発売／開始する、発売する',
#  'status': '地位、状況',
#  'procedure': '手続き',
#  'invitation': '招待',
#  'lobby': '玄関ホール',
#  'realize': '〜を実現する',
#  'effort': '努力',
#  'mainly': '主に',
#  'campaign': 'キャンペーン',
#  'key': '手がかり',
#  'proposal': '提案',
#  'greet': '挨拶する、出迎える',
#  'negotiate': '交渉する、協議する',
#  'quantity': '量',
#  'behind': '…の後ろに',
#  'comfortable': 'くつろいだ、快適な',
#  'expensive': '高価な',
#  'head': '〜を率いる',
#  'appreciate': '感謝する、高く評価する',
#  'branch': '枝',
#  'investment': '投資',
#  'deposit': '預金、預金する',
#  'difficult': '難しい',
#  'temporary': '一時の',
#  'protection': '保護',
#  'wish': '…すればよいのだが',
#  'film': '映画',
#  'condition': '条件',
#  'device': '装置',
#  'personnel': '職員、人事課',
#  'professor': '教授',
#  'complaint': '苦情',
#  'multiple': '複数の',
#  'exchange': '交換',
#  'manage': '経営する',
#  'favorite': 'お気に入りの、大好きな',
#  'quite': 'とても',
#  'distance': '距離',
#  'luggage': '旅行かばん、手荷物',
#  'admission': '入場許可',
#  'inquire': '尋ねる、問い合わせる',
#  'ingredient': '成分',
#  'technique': 'テクニック',
#  'attention': '注意',
#  'consultant': 'コンサルタント、顧問',
#  'postpone': '〜を延期する',
#  'revenue': '歳入',
#  'speech': '演説',
#  'highly': '非常に',
#  'term': '用語',
#  'agenda': '議題',
#  'demonstration': '実演',
#  'competition': '競争',
#  'specific': '特定の',
#  'rather': 'かなり',
#  'impress': '〜に感銘を与える',
#  'fact': '事実',
#  'signature': '署名',
#  'payroll': '給与、給与管理、賃金台帳',
#  'acknowledge': '知らせる、認める',
#  'win': '勝つ／獲得する',
#  'seem': '見える',
#  'trouble': '故障／不調',
#  'convention': '総会、大会',
#  'task': '任務、使命',
#  'without': '…なしで',
#  'reschedule': '〜を予定変更する',
#  'teach': '教える',
#  'handle': '操作する',
#  'distribute': '配布する、分配する',
#  'suitable': '適した、ふさわしい',
#  'between': '…の間に',
#  'throughout': 'くまなく',
#  'choice': '選択',
#  'official': '役人、職員',
#  'region': '',
#  'notify': '〜に通知する',
#  'exercise': '行使する',
#  'brochure': 'パンフレット',
#  'recognize': '認める、見分ける、認識する',
#  'similar': '似ている',
#  'usual': '普通の',
#  'artwork': '芸術作品',
#  'secure': '~を確保する、固定する／安全な',
#  'lease': '賃貸借（契約）／賃貸借する',
#  'excite': 'わくわくさせる',
#  'damage': '損害、ダメージ',
#  'environment': '環境',
#  'except': '~を除いて、~を除外して',
#  'famous': '有名な',
#  'nearly': 'ほとんど',
#  'renew': '〜を更新する',
#  'manual': 'マニュアル',
#  'exceed': '超える',
#  'worry': '心配する',
#  'mind': '気にする',
#  'figure': '数字、人物',
#  'analysis': '分析',
#  'search': '捜索',
#  'ability': '能力',
#  'ideal': '理想的な',
#  'industrial': '産業の',
#  'advise': '助言する、意見する、忠告する',
#  'hard': '難しい',
#  'transfer': '転送する、乗り換える',
#  'expo': '博覧会',
#  'landscape': '風景',
#  'initiative': '主導権',
#  'dining': '食事をすること',
#  'laboratory': '研究所、実験室',
#  'traditional': '伝統的な',
#  'accommodate': '〜をを収容する',
#  'title': '肩書き',
#  'further': 'それ以上',
#  'vendor': '業者、露天商、販売店',
#  'specialist': '専門家',
#  'raise': '賃上げ',
#  'spend': '〜を費やす',
#  'consumer': '消費者',
#  'gain': '得る',
#  'various': '様々な',
#  'often': 'たびたび',
#  'convenient': '便利な',
#  'wear': '〜を着ている',
#  'previous': '以前の',
#  'fix': '〜を修理する',
#  'standard': '基準／標準の',
#  'solution': '解決策、解決',
#  'else': 'その他に',
#  'understand': '〜を理解する',
#  'tier': '階層',
#  'together': '一緒に',
#  'committee': '委員会',
#  'congratulations': '祝いの言葉',
#  'extend': '〜を延長する',
#  'avoid': '避ける',
#  'strategy': '戦略',
#  'inform': '知らせる',
#  'especially': '特に',
#  'mistake': '誤り',
#  'commercial': '商業の',
#  'therefore': 'したがって',
#  'recruit': '〜を募集する',
#  'topic': '話題',
#  'contain': '〜を含む',
#  'organization': '組織',
#  'responsible': '担当している、責任がある',
#  'bill': '請求書、手形',
#  'either': 'いずれか／どちらかの',
#  'prefer': '好む',
#  'interior': '内側',
#  'involve': '（人を）巻き込む、伴う、含む',
#  'executive': '重役',
#  'traffic': '交通、通行',
#  'assign': '〜を割り当てる',
#  'far from': '…から遠くに',
#  'warranty': '保証',
#  'seek': '捜し求める',
#  'nearby': '近くの',
#  'effective': '効果的な',
#  'permit': '〜を認める、許可する',
#  'attempt': '努力する',
#  'example': '例',
#  'properly': 'ちゃんと、適切に',
#  'base': '基地',
#  'clear': '空いている',
#  'under': '…の下に',
#  'response': '返答、返事',
#  'surprise': '驚かす',
#  'verify': '実証する',
#  'better': 'より良い',
#  'reliable': '信頼できる',
#  'subscribe': '購読する、加入する',
#  'questionnaire': 'アンケート',
#  'itinerary': '旅程表',
#  'degree': '学位、程度',
#  'certificate': '証明書',
#  'deal with': '処理する',
#  'highlight': '〜を強調する',
#  'neighborhood': '地域',
#  'prior to': '…より前に',
#  'significant': '重要な',
#  'prescription': '処方箋',
#  'eatery': '食堂',
#  'be supposed to': '…であると思う',
#  'eligible': '資格のある',
#  'I’m afraid…': '申し訳ありませんが…',
#  'broadcast': '放送',
#  'definitely': '確かに',
#  'implement': '実行する',
#  'on behalf of': '~を代表して',
#  'finally': 'ついに、最終的に',
#  'exclusive': '独占的な',
#  'occur': '起こる',
#  'predict': '予測する',
#  'terminal': '端末',
#  'in the meantime': 'その間に、話変わって',
#  'affordable': '手ごろな、理にかなった',
#  'ceiling': '天井',
#  'major': '主な',
#  'directory': '住所',
#  'regularly': '定期的に',
#  'otherwise': 'さもないと',
#  'depart': '（~を）出発する',
#  'introduction': '紹介',
#  'impact': '影響',
#  'worth': '価値がある',
#  'decrease': '減少する',
#  'beyond': '～を超えて',
#  'whenever': '…する時はいつでも',
#  'willing': '~することを嫌がらない、~する気がある',
#  'college': '(単科)大学',
#  'showcase': '披露する／お披露目の場、ショーケース',
#  'formal': '正式の、堅苦しい',
#  'adjust': '〜を調節する',
#  'relevant': '関連した',
#  'absolutely': '完全に',
#  'district': '地区',
#  'maximum': '最大量／最大数',
#  'cuisine': '料理',
#  'yield': '収益、利益',
#  'approximate': 'およそ',
#  'clerk': '事務員',
#  'fund': '資金',
#  'decline': '〜を断る',
#  'autograph': '有名人のサイン',
#  'particular': '特別な',
#  'uniform': '制服',
#  'apologize': '謝罪する',
#  'accessible': '入手できる',
#  'instrument': '楽器',
#  'photocopy': 'コピー',
#  'administrative': '管理の',
#  'contribute': '貢献する、寄付する',
#  'digest': '要約／情報を消化する',
#  'classic': '見事な／定番の',
#  'equally': '同じように、均等に',
#  'enroll': '〜に登録する',
#  'achievement': '業績',
#  'in writing': '書面で',
#  'donate': '寄付する',
#  'decade': '10年、10年間',
#  'temperature': '温度',
#  'reflect': '〜を映す、〜を反映させる',
#  'owe': '借りている',
#  'normally': '普通に、正常に',
#  'audience': '観客',
#  'practical': '実際の',
#  'hurry': '急ぐ',
#  'unique': '独特な',
#  'guarantee': '〜を保証する',
#  'undergo': '経験する',
#  'institute': '機関',
#  'hardly': 'ほとんど〜しない',
#  'outstanding': '優れた、目立った',
#  'aside from': '…は別として',
#  'inside': '…の中へ',
#  'baggage': '手荷物',
#  'method': 'メソッド、方法',
#  'in a row': '連続して',
#  'profile': 'プロフィール・紹介',
#  'emphasize': '〜を強調する',
#  'handbook': '入門書',
#  'satisfaction': '満足',
#  'defect': '欠陥',
#  'moment': '瞬間',
#  'foundation': '設立、基礎',
#  'clarify': '明らかにする、はっきりさせる',
#  'auditorium': '講堂',
#  'exit': '出口',
#  'recipient': '受領者、受取人',
#  'progress': '前進、進行',
#  'decorate': '飾る',
#  'guess': '推測する',
#  'unless': '~しない限り、~の場合を除き',
#  'efficiency': '効率',
#  'ladder': 'はしご',
#  'quick': '速い',
#  'workplace': '職場',
#  'durable': '耐久性のある',
#  'merger': '合併、買収',
#  'priority': '優先事項',
#  'primary': '最も重要な',
#  'input': '〜を入力する',
#  'monitor': '監視する／（コンピュータの）モニター',
#  'entire': '全体の',
#  'structure': '構造',
#  'individual': '個々の',
#  'finalize': '〜を仕上げる、終わらせる',
#  'evidence': '証拠',
#  'stack': '〜を積み重ねる',
#  'qualify': '資格を得る、~に資格を与える',
#  'regulation': '規則',
#  'summary': '概要、要約',
#  'compact': '小型の',
#  'constant': '絶え間なく続く',
#  'gather': '集まる',
#  'shortly': '間もなく',
#  'incorporate': '取り入れる、組み込む',
#  'projector': 'プロジェクター',
#  'panel': '委員会',
#  'layout': 'レイアウト',
#  'fare': '運賃',
#  'determine': '〜を決定する',
#  'accomplishment': '業績',
#  'simple': '単純な',
#  'aware': '気付いて',
#  'tenant': '賃借人、入居者',
#  'pleasure': '喜び',
#  'demand': '需要',
#  'blueprint': '設計図',
#  'advantage': '利点',
#  'dental': '歯科の',
#  'metro': '地下鉄',
#  'overhead': '諸経費',
#  'waterproof': '防水の',
#  'language': '言語',
#  'perfect': '完璧な',
#  'above': '…の上方に',
#  'luck': '幸運',
#  'exactly': '正確に、厳密に',
#  'influence': '影響',
#  'urgent': '緊急の',
#  'valuable': '貴重な',
#  'assess': '〜を評価する',
#  'cashier': 'レジ係',
#  'dedicate': '捧げる',
#  'earn': '〜を稼ぐ、得る',
#  'from scratch': 'ゼロから',
#  'a couple of': '2つの',
#  'social': '社会の',
#  'connect': '接続する、つなぐ',
#  'plenty of': 'たくさん',
#  'overnight': '翌日配達の',
#  'clearance': '在庫一掃、清算、許可',
#  'onto': '…の上へ',
#  'sponsorship': '資金援助',
#  'flexible': '柔軟な',
#  'automatically': '自動的に',
#  'alone': 'ただ一人の',
#  'nutrition': '栄養',
#  'familiar': 'よく知っている、おなじみの',
#  'patron': '愛用者、利用者',
#  'entry': '登録',
#  'broad': '広い',
#  'steady': 'しっかりとした',
#  'transaction': '取引',
#  'delicious': 'とてもおいしい',
#  'checkout': 'レジ、チェックアウト',
#  'wheelbarrow': '手押し車',
#  'explore': '〜を探検（調査）する',
#  'promise': '約束する',
#  'anticipate': '〜を見越す、予想する',
#  'cafeteria': '社員食堂',
#  'society': '社会',
#  'anniversary': '~周年記念日',
#  'evaluation': '評価',
#  'handout': '配布資料',
#  'direct': '直接',
#  'appropriate': '適切な',
#  'common': '一般的な',
#  'general': '全体的な',
#  'whole': '全体の',
#  'proud': '多大な',
#  'compare': '比較する',
#  'numerous': 'たくさんの',
#  'networking': 'ネットワークづくり',
#  'acquire': '買収する、得る、獲得する',
#  'establish': '設立する',
#  'overseas': '海外の',
#  'discover': '発見する',
#  'envelope': '封筒',
#  'newly': '新たに',
#  'expose': '〜を暴露する',
#  'means': '手段',
#  'quarter': '四半期',
#  'internship': 'インターンシップ',
#  'walkway': '歩道',
#  'medication': '薬、医薬',
#  'format': 'フォーマット／構成',
#  'conservation': '保護、保存',
#  'below': '…より下に',
#  'profit': '利益',
#  'volume': '容量',
#  'restore': '復旧させる、取り戻す',
#  'satisfy': '〜を満足させる',
#  'knowledge': '知識',
#  'compliment': '褒め言葉',
#  'oversee': '監督する',
#  'judge': '判断する、裁く、評価する／裁判官',
#  'retire': '〜を退職する',
#  'huge': '巨大な',
#  'frequent': '頻繁な',
#  'initial': '初めの、当初の',
#  'expert': '専門家／専門的な',
#  'approach': '〜に近づく',
#  'refreshment': '軽食',
#  'incredible': 'すばらしい',
#  'furthermore': 'さらに',
#  'municipal': '地方自治体の',
#  'overview': '概要',
#  'sufficient': '十分な',
#  'refill': '詰め替え品',
#  'talent': '才能',
#  'aspect': '側面',
#  'nevertheless': 'それでもなお',
#  'tuition': '授業料',
#  'persuade': '説得する',
#  'regardless of': '…にかまわず',
#  'comprehensive': '総合的な、包括的な、理解力のある',
#  'eliminate': '〜を除外する',
#  'enhance': '向上させる、強化する',
#  'perhaps': 'おそらく',
#  'premise': '敷地、仮定',
#  'remark': '〜を述べる',
#  'scheme': '(事業)計画',
#  'generate': '生み出す',
#  'conclude': '結論をを出す',
#  'adjacent to': '隣接した',
#  'likewise': '同様に',
#  'prospect': '見込み',
#  'capability': '能力',
#  'enormous': '莫大な、巨大な',
#  'checkup': '検査',
#  'substitute': '代替する',
#  'failure': '失敗',
#  'massive': '巨大な',
#  'enlarge': '拡張する、増築する',
#  'moderate': '適度な',
#  'reject': '〜を拒絶する',
#  'interruption': '妨害',
#  'fluctuate': '変動する',
#  'generous': '気前のいい',
#  'consecutive': '連続した',
#  'intermediate': '中級の、中間の',
#  'aisle': '通路',
#  'deserve': '（賞賛・処罰）〜に値する',
#  'sightseeing': '観光',
#  'readability': '読みさすさ',
#  'meanwhile': 'その間に、それまでは',
#  'majority': '大多数',
#  'postal': '郵便の',
#  'voice': '意見',
#  'foreign': '外国の',
#  'fieldwork': '現地調査',
#  'checklist': '一覧表',
#  'keynote': '基調となる',
#  'minimum': '最小の',
#  'expertise': '専門知識',
#  'flaw': '欠陥、欠点',
#  'token': '印',
#  'outcome': '結果',
#  'enterprise': '企業',
#  'prevent': '防ぐ、阻む',
#  'scholarship': '奨学金',
#  'import': '〜を輸入する',
#  'amazing': '驚くべき',
#  'fortunate': '幸運な',
#  'illustrate': '〜を説明する',
#  'urgency': '緊急',
#  'hesitate': 'ためらう、躊躇する',
#  'represent': '〜を代表する',
#  'surpass': '超える',
#  'destination': '目的地',
#  'behavior': '振る舞い',
#  'proficiency': '熟達、スキルの高さ、高い能力',
#  'function': '関数、機能',
#  'recreation': '休養、娯楽',
#  'recall': '〜を思い出す、〜を回収する',
#  'beforehand': 'あらかじめ',
#  'downstairs': '階下へ',
#  'sustain': '〜を維持する',
#  'translate': '翻訳する',
#  'transcript': '成績証明書',
#  'confident': '確信している、自信がある',
#  'overcome': '乗り越える、克服する',
#  'anymore': 'もはや',
#  'utility': '公共料金、公共サービス',
#  'allocate': '割り当てる',
#  'whereas': '~の一方で',
#  'accustom': '慣れさせる',
#  'forecast': '予報',
#  'resign': '〜を辞職する',
#  'reasonable': '手ごろな、理にかなった',
#  'incline': '…に気が向く',
#  'spokesperson': '代弁者',
#  'utensil': '台所用品',
#  'accurate': '正確な',
#  'bid': '入札／入札する',
#  'prototype': '試作品、原型',
#  'fiscal': '会計の',
#  'spectator': '観客',
#  'inconvenience': '不自由',
#  'income': '収益、利益',
#  'situation': '状況',
#  'moreover': 'さらに',
#  'fantastic': 'すばらしい',
#  'detour': '迂回路',
#  'amateur': 'アマチュア',
#  'genre': 'ジャンル',
#  'thus': 'このようにして、したがって',
#  'tend to do': '…する傾向がある',
#  'overflow': '溢れる',
#  'browse': '見て回る、拾い読みする',
#  'validate': '…だ正しいことを証明する',
#  'examine': '〜を診察する、〜を調べる',
#  'quote': '見積もり',
#  'reward': '報酬',
#  'typical': '典型的な',
#  'guidebook': 'ガイドブック',
#  'mission': '任務、使命',
#  'average': '平均の',
#  'asset': '財産、強み',
#  'usage': '使い方',
#  'respectively': 'それぞれ',
#  'instant': '即時の、緊急の',
#  'archive': '公文書保管所、書庫',
#  'vacancy': '欠員',
#  'enthusiastic': '熱心な',
#  'mere': '単なる',
#  'seldom': '滅多に〜しない',
#  'workforce': '全従業員、労働力',
#  'occupy': '占有する',
#  'competence': '能力',
#  'opposite': '反対側の',
#  'utilize': '〜を利用する',
#  'intensive': '集中的な',
#  'insight': '洞察、洞察力',
#  'skip': '〜を抜かす',
#  'explanation': '説明',
#  'devote': '捧げる',
#  'discontinue': '生産や販売の継続を止める',
#  'truly': '本当に',
#  'kickoff': '開始',
#  'entertainment': '娯楽',
#  'neutral': '中立の',
#  'biography': '伝記',
#  'precise': '正確な',
#  'factor': '要因、要素',
#  'conform': '従う、一致する',
#  'eventually': '結局は',
#  'reputation': '評判',
#  'curb': '縁石',
#  'innovative': '革新的な',
#  'malfunction': '誤作動、(機械などの)不調',
#  'crucial': '非常に重要な',
#  'prerequisite': '必要条件',
#  'reluctant': '気が進まない',
#  'principle': '主義',
#  'perceive': '理解する',
#  'cooperation': '協力、協業',
#  'controversial': '議論の余地のある',
#  'reinforce': '強化する',
#  'worldwide': '世界的な／世界中で',
#  'empty': '〜を空にする',
#  'fundamental': '基本的な',
#  'heritage': '伝統、遺産',
#  'sensitive': 'デリケートな、感受性の鋭い',
#  'execute': '実行する',
#  'gradually': '徐々に',
#  'declare': '〜を宣言する',
#  'beside': '…のそばに',
#  'struggle': '奮闘する',
#  'domestic': '国内の',
#  'duration': '継続期間',
#  'complicated': '複雑な',
#  'maintain': '〜を維持する',
#  'origin': '起源',
#  'infrastructure': '社会基盤',
#  'dramatic': '劇的な',
#  'engagement': '婚約',
#  'calculate': '〜を計算する',
#  'installment': '分割払いの1回分',
#  'population': '人口',
#  'manuscript': '原稿',
#  'imagine': '〜を想像する',
#  'encounter': '直面する、遭う、出くわす',
#  'milestone': '段階',
#  'concept': '概念／コンセプト',
#  'reimburse': '〜を返済する',
#  'freelance': 'フリーランス',
#  'useful': '役に立つ',
#  'excessive': '過度な',
#  'absence': '欠席／欠如',
#  'reply': '〜に応答する、返答する',
#  'shortage': '不足',
#  'scope': '範囲、余地',
#  'landlord': '家主',
#  'background': '経歴',
#  'bargain': 'お買い得品、取引',
#  'invaluable': '貴重な',
#  'remote': '人里離れた、可能性が低い',
#  'cite': '〜に言及する',
#  'coincidence': '偶然',
#  'rapid': '急速な',
#  'feasible': '実現可能な',
#  'streamline': '合理化する、簡略化する',
#  'quota': '販売ノルマ',
#  'attribute': '起因すると考えられる、おかげであるとする',
#  'forthcoming': '今度の',
#  'overwhelming': '圧倒的な',
#  'adequate': '十分な',
#  'mandatory': '義務の、強制の',
#  'redeem': '(現金に)換える',
#  'apprenticeship': '見習い期間',
#  'culinary': '料理の',
#  'applause': '拍手',
#  'discard': '捨てる',
#  'overlook': '〜を見落とす',
#  'proceeds': '収益、利益',
#  'aboard': '船に乗って',
#  'adhere': '忠実である、実行する、接着する',
#  'commission': '手数料',
#  'specification': '仕様書',
#  'convince': '確信させる、納得させる',
#  'specify': '明記する',
#  'disclosure': '公開',
#  'projection': '予測',
#  'outlay': '出資金',
#  'prohibit': '禁じる',
#  'expedite': '早める、促進させる',
#  'mentor': '助言者',
#  'offset': '埋め合わせる',
#  'remodel': '〜を改築する',
#  'nursery': '園芸店',
#  'resolve': '解決する',
#  'dismantle': '解体する',
#  'chronicle': '年代記',
#  'turnout': '参加者数',
#  'bulk': '大部分',
#  'resume': '再開する',
#  'inlay': 'はめ込む',
#  'obstacle': '障害物',
#  'retrieve': '〜を取り戻す、〜を回収する',
#  'compliance': '法令遵守',
#  'undertake': '〜を引き受ける',
#  'endeavor': '努力する',
#  'unload': '（荷物など）を降ろす',
#  'adopt': '採用する、導入する',
#  'adapt': '適応する、適応させる、改作する',
#  'abandon': '捨てる',
#  'congestion': '混雑',
#  'prestigious': '権威のある、誉れ高い',
#  'acclaim': 'ほめたたえる',
#  'deliberate': '故意の、入念な',
#  'designate': '〜を…に任命する',
#  'attest': '証明する',
#  'stroll': '散歩する',
#  'amend': '修正する',
#  'praise': 'ほめる、賞賛する',
#  'nominate': '〜を指名する',
#  'retain': '保管する、持ち続ける',
#  'slate': '予定する',
#  'novice': '初心者',
#  'alternative': '代わりの／代案、選択肢',
#  'admire': '〜に感心する',
#  'gratitude': '感謝',
#  'compile': '取りまとめる、編集する',
#  'duplicate': '複製',
#  'affiliate': '子会社',
#  'tailor': '仕立屋、テーラー',
#  'aspire': '熱望する',
#  'tutor': '教師',
#  'alike': '似た',
#  'compensate': '補償する',
#  'periodic': '定期的な',
#  'disturb': '〜をかき乱す、〜を混乱させる',
#  'candid': '率直な',
#  'anonymous': '匿名の',
#  'assure': '〜を保証する',
#  'thoroughly': '徹底的に',
#  'imprint': '刻み込む',
#  'disrupt': '混乱させる',
#  'afterward': 'あとで',
#  'originate': '起源とする',
#  'versatile': '多才な',
#  'bypass': '迂回路',
#  'awning': '日よけ',
#  'ample': '広大な',
#  'contrast': '対照、はっきりした違い／対照的である',
#  'fragile': '壊れやすい',
#  'coin': '(新語を)造り出す',
#  'promptly': '即座に',
#  'unconventional': '型にはまらない',
#  'conditional': '条件付きの',
#  'accountable': '責任がある',
#  'landmark': 'ランドマーク、目印、名所',
#  'steep': '険しい、急激な',
#  'await': '待つ',
#  'intermittent': '断続的な',
#  'pursue': '追及する、遂行する、続行する',
#  'exposition': '説明／展示会',
#  'cozy': '居心地のよい',
#  'overhaul': '改善',
#  'rundown': '手短な報告',
#  'roundup': '総括',
#  'neither': 'どちらも…でない',
#  'enclose': '〜を同封する',
#  ...}

# %%
word_df = pd.DataFrame(list(word_dict.items()), columns=["単語", "意味"])
word_df.head()
# Out:
#            単語           意味
# 0      survey           調査
# 1   interview       面接(する)
# 2  exhibition           展示
# 3  conference           会議
# 4   available  利用可能な、入手可能な

# %%
word_df.to_csv("collect_word.csv", encoding="utf-8-sig")
